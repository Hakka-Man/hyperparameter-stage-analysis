# %%
from stage import getStage, fullPrint
import pandas as pd
import datetime
from datetime import date, datetime
import yahoo_fin.stock_info as yf

# %%
coef = [0.12670742563044157, 1.3452537366729918, 0.3412355334740049, 0.9200419740552854, 1.3452226595229195, 1.1040652469472896, 0.8494658205377208, 0.8112883127968283, 1.377102695533595, 0.9876890207638959, -0.07062041016478565, 0.8782739433090022, 1.0107646230781666, 0.8655665054131219, 0.9883863405639555]

# %%
SectorDict = {
    "Energy":"XLE","Technology":"XLK",
    "Communication Services":"XLC",
    "Consumer Staples":"XLP",
    "Health Care":"XLV",
    "Consumer Cyclical":"XLY",
    "Industrial":"XLI",
    "Utilities":"XLU",
    "Materials":"XLB",
    "Financial":"XLF",
    "Real Estate":"XLRE"}
sectorDfList = []
for sector in SectorDict.values():
    sectorDfList.append(pd.read_pickle("stockData/sectorCharts/"+sector+".pkl"))
goodSectorDf = sectorDfList[0].drop(['open','high','low','adjclose','close','ticker','volume','percent','MA30','MA30Slope','RS'],axis=1)
goodSectorDf['Sectors'] = [[] for _ in range(len(goodSectorDf))]
goodSectorDf.index = sectorDfList[0].index
index = 0
for date in sectorDfList[0].index:
    listOfSector = []
    for df in sectorDfList:
        try:
            #print(df.at[date,'MA30Slope'],df.at[date,'RS'])
            #!!!!!!!! or for new params
            #!!!!!!!!
            #!!!!!!!!
            #!!!!!!!!
            if  df.at[date,'MA30Slope'] > coef[9] and df.loc[date,'RS'] > coef[10]:
                if df.at[date,'close'] > df.at[date,'MA30']:
                    #print(df.at[date,'ticker'])
                    listOfSector.append(df.at[date,'ticker'])
        except: 
            pass
        # print(listOfSector)
    goodSectorDf.iat[index,0] = set(listOfSector)
    index = index + 1
    #print(goodSectorDf.at[date,'Sectors'])
fullPrint(goodSectorDf)
# Out:
#                                                       Sectors
# 1999-01-08                                                 {}
# 1999-01-15                                                 {}
# 1999-01-22                                                 {}
# 1999-01-29                                                 {}
# 1999-02-05                                                 {}
# 1999-02-12                                                 {}
# 1999-02-19                                                 {}
# 1999-02-26                                                 {}
# 1999-03-05                                                 {}
# 1999-03-12                                                 {}
# 1999-03-19                                                 {}
# 1999-03-26                                                 {}
# 1999-04-09                                                 {}
# 1999-04-16                                                 {}
# 1999-04-23                                                 {}
# 1999-04-30                                                 {}
# 1999-05-07                                                 {}
# 1999-05-14                                                 {}
# 1999-05-21                                                 {}
# 1999-05-28                                                 {}
# 1999-06-04                                                 {}
# 1999-06-11                                                 {}
# 1999-06-18                                                 {}
# 1999-06-25                                                 {}
# 1999-07-02                                                 {}
# 1999-07-09                                                 {}
# 1999-07-16                                                 {}
# 1999-07-23                                                 {}
# 1999-07-30                                                 {}
# 1999-08-06                                                 {}
# 1999-08-13                                                 {}
# 1999-08-20                          {XLI, XLU, XLE, XLB, XLK}
# 1999-08-27                               {XLB, XLE, XLK, XLI}
# 1999-09-03                          {XLI, XLU, XLE, XLB, XLK}
# 1999-09-10                               {XLB, XLE, XLK, XLI}
# 1999-09-17                                    {XLE, XLK, XLI}
# 1999-09-24                                              {XLK}
# 1999-10-01                                         {XLU, XLK}
# 1999-10-08                                         {XLI, XLK}
# 1999-10-15                                              {XLK}
# 1999-10-22                                              {XLK}
# 1999-10-29                               {XLY, XLU, XLF, XLK}
# 1999-11-05                                         {XLF, XLK}
# 1999-11-12                                    {XLV, XLF, XLK}
# 1999-11-19                                         {XLE, XLK}
# 1999-11-26                                              {XLK}
# 1999-12-03                                         {XLV, XLK}
# 1999-12-10                                         {XLV, XLK}
# 1999-12-17                                    {XLY, XLV, XLK}
# 1999-12-31                               {XLY, XLV, XLK, XLB}
# 2000-01-07                               {XLY, XLV, XLK, XLB}
# 2000-01-14                                    {XLY, XLV, XLK}
# 2000-01-21                               {XLY, XLV, XLE, XLK}
# 2000-01-28                                         {XLV, XLK}
# 2000-02-04                                         {XLV, XLK}
# 2000-02-11                                         {XLV, XLK}
# 2000-02-18                                              {XLK}
# 2000-02-25                                              {XLK}
# 2000-03-03                                              {XLK}
# 2000-03-10                                              {XLK}
# 2000-03-17                                    {XLY, XLV, XLK}
# 2000-03-24                                         {XLV, XLK}
# 2000-03-31                                    {XLY, XLV, XLK}
# 2000-04-07                                    {XLY, XLV, XLK}
# 2000-04-14                                         {XLY, XLE}
# 2000-04-28                               {XLY, XLV, XLF, XLK}
# 2000-05-05                                    {XLE, XLK, XLI}
# 2000-05-12                               {XLY, XLE, XLF, XLI}
# 2000-05-19                                    {XLE, XLF, XLI}
# 2000-05-26                               {XLE, XLF, XLI, XLP}
# 2000-06-02                          {XLV, XLF, XLI, XLE, XLK}
# 2000-06-09                               {XLV, XLE, XLK, XLI}
# 2000-06-16                               {XLV, XLE, XLK, XLI}
# 2000-06-23                               {XLU, XLE, XLK, XLP}
# 2000-06-30                               {XLE, XLK, XLI, XLP}
# 2000-07-07                {XLV, XLF, XLI, XLU, XLE, XLK, XLP}
# 2000-07-14                          {XLV, XLF, XLI, XLE, XLK}
# 2000-07-21                          {XLF, XLI, XLE, XLK, XLP}
# 2000-07-28                               {XLF, XLE, XLU, XLP}
# 2000-08-04                     {XLV, XLF, XLI, XLU, XLE, XLP}
# 2000-08-11                     {XLV, XLF, XLI, XLU, XLE, XLP}
# 2000-08-18                          {XLF, XLI, XLU, XLE, XLP}
# 2000-08-25                     {XLF, XLI, XLU, XLE, XLK, XLP}
# 2000-09-01                          {XLF, XLI, XLU, XLE, XLK}
# 2000-09-08                          {XLF, XLI, XLU, XLE, XLP}
# 2000-09-15                          {XLF, XLI, XLU, XLE, XLP}
# 2000-09-22                          {XLF, XLI, XLU, XLE, XLP}
# 2000-09-29                          {XLF, XLI, XLU, XLE, XLP}
# 2000-10-06                          {XLF, XLI, XLU, XLE, XLP}
# 2000-10-13                          {XLF, XLI, XLU, XLE, XLP}
# 2000-10-20                               {XLF, XLE, XLU, XLP}
# 2000-10-27                          {XLF, XLI, XLU, XLE, XLP}
# 2000-11-03                     {XLV, XLF, XLI, XLU, XLE, XLP}
# 2000-11-10                          {XLF, XLI, XLU, XLE, XLP}
# 2000-11-17                          {XLF, XLI, XLU, XLE, XLP}
# 2000-11-24                               {XLE, XLU, XLI, XLP}
# 2000-12-01                          {XLF, XLI, XLU, XLB, XLP}
# 2000-12-08                               {XLF, XLI, XLU, XLP}
# 2000-12-15                               {XLF, XLI, XLU, XLP}
# 2000-12-22                     {XLF, XLI, XLU, XLE, XLB, XLP}
# 2000-12-29                {XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2001-01-05                {XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2001-01-12                {XLV, XLF, XLI, XLU, XLY, XLB, XLP}
# 2001-01-19                {XLV, XLF, XLI, XLU, XLY, XLB, XLP}
# 2001-01-26           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2001-02-02           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2001-02-09                {XLV, XLF, XLU, XLY, XLE, XLB, XLP}
# 2001-02-16                {XLV, XLF, XLU, XLY, XLE, XLB, XLP}
# 2001-02-23                               {XLY, XLU, XLB, XLP}
# 2001-03-02                          {XLU, XLY, XLE, XLB, XLP}
# 2001-03-09                               {XLY, XLE, XLB, XLP}
# 2001-03-16                                         {XLY, XLB}
# 2001-03-23                                              {XLB}
# 2001-03-30                                         {XLY, XLB}
# 2001-04-06                                         {XLY, XLB}
# 2001-04-20                               {XLY, XLV, XLE, XLB}
# 2001-04-27                {XLV, XLF, XLI, XLU, XLY, XLE, XLB}
# 2001-05-04                {XLV, XLF, XLI, XLU, XLY, XLE, XLB}
# 2001-05-11                     {XLV, XLI, XLU, XLY, XLE, XLB}
# 2001-05-18                {XLV, XLF, XLI, XLU, XLY, XLE, XLB}
# 2001-05-25                {XLV, XLF, XLI, XLU, XLY, XLE, XLB}
# 2001-06-01                {XLV, XLF, XLI, XLU, XLY, XLE, XLB}
# 2001-06-08                     {XLV, XLF, XLI, XLY, XLE, XLB}
# 2001-06-15                               {XLY, XLV, XLE, XLB}
# 2001-06-22                               {XLY, XLV, XLF, XLB}
# 2001-06-29                               {XLY, XLV, XLF, XLB}
# 2001-07-06                                         {XLV, XLB}
# 2001-07-13                               {XLY, XLV, XLF, XLB}
# 2001-07-20                                    {XLY, XLV, XLB}
# 2001-07-27                                    {XLY, XLV, XLB}
# 2001-08-03                               {XLY, XLV, XLF, XLB}
# 2001-08-10                                         {XLY, XLB}
# 2001-08-17                                         {XLB, XLP}
# 2001-08-24                                    {XLV, XLB, XLP}
# 2001-08-31                                              {XLB}
# 2001-09-07                                                 {}
# 2001-09-21                                                 {}
# 2001-09-28                                                 {}
# 2001-10-05                                              {XLP}
# 2001-10-12                                              {XLP}
# 2001-10-19                                              {XLP}
# 2001-10-26                                              {XLP}
# 2001-11-02                                              {XLP}
# 2001-11-09                                              {XLP}
# 2001-11-16                                    {XLY, XLB, XLP}
# 2001-11-23                                    {XLY, XLB, XLP}
# 2001-11-30                                    {XLY, XLB, XLP}
# 2001-12-07                          {XLV, XLY, XLK, XLB, XLP}
# 2001-12-14                                              {XLY}
# 2001-12-21                                    {XLY, XLI, XLP}
# 2001-12-28                     {XLV, XLF, XLI, XLY, XLB, XLP}
# 2002-01-04                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2002-01-11                                    {XLY, XLV, XLK}
# 2002-01-18                                    {XLY, XLV, XLF}
# 2002-01-25                               {XLY, XLV, XLF, XLB}
# 2002-02-01                               {XLY, XLV, XLB, XLP}
# 2002-02-08                                    {XLY, XLV, XLB}
# 2002-02-15                               {XLY, XLV, XLB, XLP}
# 2002-02-22                               {XLY, XLV, XLB, XLP}
# 2002-03-01                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2002-03-08                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2002-03-15                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2002-03-22                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2002-04-05                     {XLV, XLF, XLI, XLY, XLE, XLB}
# 2002-04-12                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2002-04-19                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2002-04-26                          {XLV, XLF, XLY, XLE, XLB}
# 2002-05-03                          {XLV, XLF, XLY, XLE, XLB}
# 2002-05-10                          {XLV, XLF, XLY, XLE, XLB}
# 2002-05-17                          {XLV, XLF, XLY, XLE, XLB}
# 2002-05-24                          {XLV, XLF, XLY, XLE, XLB}
# 2002-05-31                          {XLV, XLF, XLY, XLE, XLB}
# 2002-06-07                                         {XLV, XLB}
# 2002-06-14                                              {XLB}
# 2002-06-21                                              {XLB}
# 2002-06-28                                              {XLB}
# 2002-07-05                                              {XLB}
# 2002-07-12                                                 {}
# 2002-07-19                                                 {}
# 2002-07-26                                                 {}
# 2002-08-02                                                 {}
# 2002-08-09                                                 {}
# 2002-08-16                                                 {}
# 2002-08-23                                                 {}
# 2002-08-30                                                 {}
# 2002-09-06                                                 {}
# 2002-09-13                                                 {}
# 2002-09-20                                                 {}
# 2002-09-27                                                 {}
# 2002-10-04                                                 {}
# 2002-10-11                                                 {}
# 2002-10-18                                              {XLV}
# 2002-10-25                                                 {}
# 2002-11-01                                                 {}
# 2002-11-08                                              {XLV}
# 2002-11-15                                         {XLV, XLK}
# 2002-11-22                                    {XLV, XLF, XLK}
# 2002-11-29                               {XLV, XLF, XLK, XLB}
# 2002-12-06                                         {XLV, XLK}
# 2002-12-13                                              {XLK}
# 2002-12-20                                              {XLK}
# 2002-12-27                                              {XLK}
# 2003-01-03                          {XLV, XLF, XLE, XLK, XLB}
# 2003-01-10                               {XLV, XLF, XLK, XLB}
# 2003-01-17                               {XLV, XLF, XLK, XLB}
# 2003-01-24                                                 {}
# 2003-01-31                                                 {}
# 2003-02-07                                                 {}
# 2003-02-14                                                 {}
# 2003-02-21                                         {XLE, XLK}
# 2003-02-28                                              {XLE}
# 2003-03-07                                              {XLE}
# 2003-03-14                                                 {}
# 2003-03-21                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2003-03-28                                    {XLV, XLE, XLK}
# 2003-04-04                          {XLV, XLF, XLY, XLE, XLK}
# 2003-04-11                          {XLV, XLF, XLU, XLY, XLE}
# 2003-04-25           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-05-02                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-05-09                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-05-16           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-05-23           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-05-30           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-06-06           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-06-13           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-06-20           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-06-27      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2003-07-11           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2003-07-18           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-07-25                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-08-01                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-08-08           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-08-15           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-08-22                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-08-29                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-09-05                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-09-12                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2003-09-19                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-09-26                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-10-03                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-10-10                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-10-17                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-10-24                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-10-31                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-11-07                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-11-14                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-11-21                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2003-11-28                {XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2003-12-05           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2003-12-12           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2003-12-19                {XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2003-12-26                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2004-01-02                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2004-01-09                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2004-01-16                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2004-01-23                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2004-01-30                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2004-02-06           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-02-13           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-02-20      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-02-27      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-03-05           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-03-12      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-03-19           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2004-03-26                {XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2004-04-02      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-04-16           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2004-04-23      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-04-30                     {XLV, XLI, XLU, XLY, XLE, XLP}
# 2004-05-07                               {XLV, XLE, XLI, XLP}
# 2004-05-14                                    {XLV, XLE, XLP}
# 2004-05-21                                    {XLV, XLE, XLP}
# 2004-05-28           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2004-06-04                {XLV, XLF, XLI, XLU, XLY, XLE, XLP}
# 2004-06-18           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2004-06-25           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-07-02                          {XLI, XLU, XLE, XLB, XLP}
# 2004-07-09                          {XLI, XLU, XLE, XLB, XLP}
# 2004-07-16                          {XLI, XLU, XLE, XLB, XLP}
# 2004-07-23                                         {XLE, XLI}
# 2004-07-30                               {XLB, XLE, XLU, XLI}
# 2004-08-06                                         {XLE, XLU}
# 2004-08-13                                         {XLE, XLU}
# 2004-08-20                               {XLB, XLE, XLU, XLI}
# 2004-08-27                          {XLF, XLI, XLU, XLE, XLB}
# 2004-09-03                     {XLF, XLI, XLU, XLE, XLB, XLP}
# 2004-09-10                     {XLF, XLI, XLU, XLY, XLE, XLB}
# 2004-09-17                     {XLF, XLI, XLU, XLY, XLE, XLB}
# 2004-09-24                          {XLI, XLU, XLY, XLE, XLB}
# 2004-10-01                     {XLF, XLI, XLU, XLY, XLE, XLB}
# 2004-10-08                     {XLF, XLI, XLU, XLY, XLE, XLB}
# 2004-10-15                          {XLI, XLU, XLY, XLE, XLB}
# 2004-10-22                          {XLI, XLU, XLY, XLE, XLB}
# 2004-10-29                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2004-11-05           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-11-12           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-11-19           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-11-26           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2004-12-03                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2004-12-10                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2004-12-17                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2004-12-31                {XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2005-01-07           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-01-14           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-01-21                {XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2005-01-28                {XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2005-02-04           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-02-11           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-02-18      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-02-25      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-03-04           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2005-03-11           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2005-03-18                     {XLV, XLI, XLU, XLY, XLE, XLB}
# 2005-04-01                     {XLV, XLI, XLU, XLE, XLB, XLP}
# 2005-04-08                     {XLV, XLI, XLU, XLE, XLB, XLP}
# 2005-04-15                               {XLV, XLE, XLU, XLP}
# 2005-04-22                                    {XLV, XLE, XLU}
# 2005-04-29                               {XLV, XLE, XLU, XLP}
# 2005-05-06                               {XLV, XLE, XLU, XLP}
# 2005-05-13                                    {XLV, XLE, XLU}
# 2005-05-20                          {XLV, XLI, XLU, XLE, XLP}
# 2005-05-27                {XLV, XLF, XLI, XLU, XLE, XLK, XLP}
# 2005-06-03                     {XLV, XLI, XLU, XLE, XLK, XLP}
# 2005-06-10                          {XLV, XLU, XLE, XLK, XLP}
# 2005-06-17           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2005-06-24                                    {XLV, XLE, XLU}
# 2005-07-01                               {XLV, XLE, XLU, XLF}
# 2005-07-08                     {XLV, XLF, XLU, XLY, XLE, XLK}
# 2005-07-15                {XLV, XLF, XLU, XLY, XLE, XLK, XLP}
# 2005-07-22           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2005-07-29           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2005-08-05                     {XLV, XLF, XLU, XLY, XLE, XLK}
# 2005-08-12                {XLV, XLF, XLI, XLU, XLY, XLE, XLK}
# 2005-08-19                     {XLV, XLF, XLU, XLY, XLE, XLK}
# 2005-08-26                          {XLV, XLU, XLY, XLE, XLK}
# 2005-09-02                          {XLV, XLF, XLU, XLE, XLK}
# 2005-09-09           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2005-09-16                     {XLV, XLF, XLI, XLU, XLE, XLK}
# 2005-09-23                          {XLV, XLF, XLU, XLE, XLK}
# 2005-09-30                {XLV, XLF, XLI, XLU, XLE, XLK, XLP}
# 2005-10-07                                    {XLU, XLE, XLK}
# 2005-10-14                                              {XLE}
# 2005-10-21                                         {XLE, XLF}
# 2005-10-28                                    {XLE, XLF, XLP}
# 2005-11-04                          {XLF, XLI, XLE, XLK, XLP}
# 2005-11-11                {XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2005-11-18           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2005-11-25           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-12-02           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-12-09           {XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-12-16      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2005-12-23           {XLV, XLF, XLI, XLU, XLE, XLK, XLB, XLP}
# 2005-12-30                {XLV, XLF, XLI, XLE, XLK, XLB, XLP}
# 2006-01-06      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-01-13      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-01-20                {XLV, XLF, XLI, XLU, XLE, XLK, XLB}
# 2006-01-27      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-02-03                     {XLV, XLF, XLI, XLE, XLB, XLK}
# 2006-02-10                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2006-02-17           {XLV, XLF, XLI, XLU, XLE, XLK, XLB, XLP}
# 2006-02-24           {XLV, XLF, XLI, XLU, XLE, XLK, XLB, XLP}
# 2006-03-03      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-03-10                     {XLV, XLF, XLI, XLK, XLB, XLP}
# 2006-03-17      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-03-24                {XLV, XLF, XLI, XLE, XLK, XLB, XLP}
# 2006-03-31           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2006-04-07                {XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2006-04-21                {XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2006-04-28                {XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2006-05-05                {XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2006-05-12                     {XLF, XLI, XLY, XLE, XLB, XLP}
# 2006-05-19                     {XLF, XLI, XLY, XLE, XLB, XLP}
# 2006-05-26                     {XLF, XLI, XLY, XLE, XLB, XLP}
# 2006-06-02                {XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2006-06-09                               {XLF, XLI, XLU, XLP}
# 2006-06-16                                    {XLI, XLU, XLP}
# 2006-06-23                                         {XLI, XLP}
# 2006-06-30                          {XLI, XLU, XLE, XLB, XLP}
# 2006-07-07                          {XLI, XLU, XLE, XLB, XLP}
# 2006-07-14                                    {XLE, XLU, XLP}
# 2006-07-21                                         {XLU, XLP}
# 2006-07-28                          {XLV, XLF, XLU, XLE, XLP}
# 2006-08-04                          {XLV, XLF, XLU, XLE, XLP}
# 2006-08-11                          {XLV, XLF, XLU, XLE, XLP}
# 2006-08-18                          {XLV, XLF, XLU, XLE, XLP}
# 2006-08-25                          {XLV, XLF, XLU, XLE, XLP}
# 2006-09-01                {XLV, XLF, XLU, XLE, XLK, XLB, XLP}
# 2006-09-08                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2006-09-15                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2006-09-22                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2006-09-29                {XLV, XLF, XLI, XLU, XLY, XLK, XLP}
# 2006-10-06           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2006-10-13           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2006-10-20           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2006-10-27      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-11-03      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-11-10      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-11-17                {XLV, XLF, XLI, XLU, XLY, XLK, XLP}
# 2006-11-24      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-12-01           {XLV, XLF, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-12-08           {XLV, XLF, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-12-15           {XLV, XLF, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-12-22           {XLV, XLF, XLU, XLY, XLE, XLK, XLB, XLP}
# 2006-12-29           {XLV, XLF, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-01-05           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2007-01-12                {XLV, XLF, XLU, XLY, XLK, XLB, XLP}
# 2007-01-19                {XLV, XLF, XLU, XLY, XLK, XLB, XLP}
# 2007-01-26                {XLV, XLF, XLU, XLY, XLK, XLB, XLP}
# 2007-02-02           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2007-02-09           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2007-02-16                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2007-02-23           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2007-03-02                          {XLI, XLU, XLY, XLB, XLP}
# 2007-03-09           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2007-03-16                          {XLI, XLU, XLY, XLK, XLB}
# 2007-03-23           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2007-03-30           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-04-13           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-04-20      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-04-27      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-05-04      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-05-11      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-05-18      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-05-25      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-06-01      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-06-08      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-06-15      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-06-22                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2007-06-29           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-07-06           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-07-13           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-07-20           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2007-07-27                               {XLB, XLE, XLK, XLI}
# 2007-08-03                                    {XLE, XLK, XLI}
# 2007-08-10                               {XLE, XLK, XLI, XLP}
# 2007-08-17                                    {XLE, XLK, XLI}
# 2007-08-24                          {XLI, XLE, XLB, XLK, XLP}
# 2007-08-31                                    {XLE, XLK, XLI}
# 2007-09-07                                    {XLE, XLK, XLI}
# 2007-09-14                          {XLI, XLE, XLB, XLK, XLP}
# 2007-09-21                {XLV, XLI, XLU, XLE, XLK, XLB, XLP}
# 2007-09-28                     {XLV, XLI, XLE, XLK, XLB, XLP}
# 2007-10-05                {XLV, XLI, XLU, XLE, XLK, XLB, XLP}
# 2007-10-12                {XLV, XLI, XLU, XLE, XLK, XLB, XLP}
# 2007-10-19                          {XLI, XLE, XLB, XLK, XLP}
# 2007-10-26                {XLV, XLI, XLU, XLE, XLK, XLB, XLP}
# 2007-11-02                     {XLI, XLU, XLE, XLK, XLB, XLP}
# 2007-11-09                               {XLE, XLU, XLB, XLP}
# 2007-11-16                          {XLV, XLU, XLE, XLK, XLP}
# 2007-11-23                                    {XLE, XLU, XLP}
# 2007-11-30                     {XLV, XLU, XLE, XLK, XLB, XLP}
# 2007-12-07                {XLV, XLI, XLU, XLE, XLK, XLB, XLP}
# 2007-12-14                     {XLV, XLU, XLE, XLK, XLB, XLP}
# 2007-12-21                     {XLV, XLU, XLE, XLK, XLB, XLP}
# 2007-12-28                     {XLV, XLU, XLE, XLK, XLB, XLP}
# 2008-01-04                                    {XLE, XLU, XLP}
# 2008-01-11                               {XLV, XLE, XLU, XLP}
# 2008-01-18                                                 {}
# 2008-01-25                                                 {}
# 2008-02-01                                              {XLB}
# 2008-02-08                                                 {}
# 2008-02-15                                                 {}
# 2008-02-22                                         {XLE, XLB}
# 2008-02-29                                         {XLE, XLB}
# 2008-03-07                                                 {}
# 2008-03-14                                              {XLE}
# 2008-03-28                                                 {}
# 2008-04-04                                    {XLE, XLB, XLP}
# 2008-04-11                                         {XLE, XLB}
# 2008-04-18                               {XLB, XLE, XLU, XLI}
# 2008-04-25                                    {XLE, XLB, XLI}
# 2008-05-02                     {XLI, XLU, XLY, XLE, XLB, XLP}
# 2008-05-09                                    {XLE, XLB, XLI}
# 2008-05-16                {XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2008-05-23                               {XLE, XLU, XLB, XLP}
# 2008-05-30                {XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2008-06-06                                    {XLE, XLK, XLB}
# 2008-06-13                          {XLU, XLE, XLK, XLB, XLP}
# 2008-06-20                                    {XLE, XLU, XLB}
# 2008-06-27                                              {XLE}
# 2008-07-11                                         {XLE, XLU}
# 2008-07-18                                                 {}
# 2008-07-25                                                 {}
# 2008-08-01                                                 {}
# 2008-08-08                                         {XLV, XLP}
# 2008-08-15                               {XLY, XLV, XLK, XLP}
# 2008-08-22                                         {XLV, XLP}
# 2008-08-29                                         {XLV, XLP}
# 2008-09-05                                              {XLP}
# 2008-09-12                                    {XLY, XLV, XLP}
# 2008-09-19                                                 {}
# 2008-09-26                                                 {}
# 2008-10-03                                                 {}
# 2008-10-10                                                 {}
# 2008-10-17                                                 {}
# 2008-10-24                                                 {}
# 2008-10-31                                                 {}
# 2008-11-07                                                 {}
# 2008-11-14                                                 {}
# 2008-11-21                                                 {}
# 2008-11-28                                                 {}
# 2008-12-05                                                 {}
# 2008-12-12                                                 {}
# 2008-12-19                                                 {}
# 2008-12-26                                                 {}
# 2009-01-02                                                 {}
# 2009-01-09                                                 {}
# 2009-01-16                                                 {}
# 2009-01-23                                                 {}
# 2009-01-30                                                 {}
# 2009-02-06                                                 {}
# 2009-02-13                                                 {}
# 2009-02-20                                                 {}
# 2009-02-27                                                 {}
# 2009-03-06                                                 {}
# 2009-03-13                                                 {}
# 2009-03-20                                                 {}
# 2009-03-27                                                 {}
# 2009-04-03                                              {XLK}
# 2009-04-17                                              {XLK}
# 2009-04-24                                         {XLY, XLK}
# 2009-05-01                                         {XLY, XLK}
# 2009-05-08                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-05-15                     {XLV, XLI, XLY, XLE, XLK, XLB}
# 2009-05-22                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-05-29                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-06-05                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-06-12           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2009-06-19                     {XLV, XLI, XLY, XLE, XLK, XLB}
# 2009-06-26                     {XLV, XLF, XLY, XLE, XLK, XLB}
# 2009-07-10                          {XLV, XLY, XLK, XLB, XLP}
# 2009-07-17                     {XLV, XLY, XLE, XLK, XLB, XLP}
# 2009-07-24                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-07-31           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-08-07                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2009-08-14           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-08-21                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2009-08-28                          {XLF, XLI, XLY, XLK, XLB}
# 2009-09-04                          {XLF, XLI, XLY, XLK, XLB}
# 2009-09-11                          {XLF, XLI, XLY, XLK, XLB}
# 2009-09-18                          {XLF, XLI, XLY, XLK, XLB}
# 2009-09-25                          {XLF, XLI, XLY, XLK, XLB}
# 2009-10-02                          {XLF, XLI, XLY, XLK, XLB}
# 2009-10-09                          {XLF, XLI, XLY, XLK, XLB}
# 2009-10-16                          {XLF, XLI, XLY, XLK, XLB}
# 2009-10-23                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2009-10-30                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2009-11-06                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2009-11-13                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2009-11-20           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-11-27           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2009-12-04                {XLV, XLF, XLI, XLY, XLK, XLB, XLP}
# 2009-12-11                {XLV, XLI, XLU, XLY, XLK, XLB, XLP}
# 2009-12-18                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2010-01-08                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2010-01-15                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2010-01-22           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2010-01-29                     {XLV, XLF, XLI, XLY, XLK, XLP}
# 2010-02-05                     {XLV, XLI, XLY, XLE, XLK, XLP}
# 2010-02-12                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-02-19                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2010-02-26           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-03-05           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-03-12           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-03-19           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-03-26           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-04-09           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-04-16           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-04-23                {XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-04-30           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2010-05-07                                    {XLY, XLI, XLF}
# 2010-05-14                     {XLF, XLI, XLU, XLY, XLK, XLP}
# 2010-05-21                                         {XLY, XLI}
# 2010-05-28                                         {XLY, XLI}
# 2010-06-04                                              {XLY}
# 2010-06-11                                         {XLY, XLI}
# 2010-06-18                               {XLY, XLU, XLI, XLK}
# 2010-06-25                                                 {}
# 2010-07-02                                                 {}
# 2010-07-09                                              {XLU}
# 2010-07-16                                                 {}
# 2010-07-23                     {XLI, XLU, XLY, XLK, XLB, XLP}
# 2010-07-30                               {XLI, XLU, XLB, XLP}
# 2010-08-06                     {XLI, XLU, XLY, XLK, XLB, XLP}
# 2010-08-13                                              {XLU}
# 2010-08-20                                              {XLU}
# 2010-08-27                                              {XLU}
# 2010-09-03                          {XLI, XLU, XLY, XLB, XLP}
# 2010-09-10                          {XLI, XLU, XLY, XLB, XLP}
# 2010-09-17                     {XLI, XLU, XLY, XLK, XLB, XLP}
# 2010-09-24                {XLV, XLI, XLU, XLY, XLK, XLB, XLP}
# 2010-10-01           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-10-08           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-10-15           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-10-22           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-10-29           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-11-05           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-11-12           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-11-19           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-11-26           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-12-03           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-12-10      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-12-17           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2010-12-31      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2011-01-07                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2011-01-14                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2011-01-21           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-01-28                     {XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-02-04                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2011-02-11                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2011-02-18                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2011-02-25                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2011-03-04                     {XLV, XLI, XLY, XLE, XLK, XLB}
# 2011-03-11           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-03-18                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2011-03-25                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2011-04-01                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2011-04-08                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2011-04-15                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-04-29                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-05-06           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-05-13                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-05-20                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-05-27                {XLV, XLI, XLY, XLE, XLK, XLB, XLP}
# 2011-06-03                     {XLV, XLI, XLU, XLY, XLE, XLP}
# 2011-06-10                               {XLV, XLE, XLU, XLP}
# 2011-06-17                                    {XLV, XLU, XLP}
# 2011-06-24                                    {XLV, XLU, XLP}
# 2011-07-01           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2011-07-08           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2011-07-15                {XLV, XLU, XLY, XLE, XLK, XLB, XLP}
# 2011-07-22           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2011-07-29                          {XLV, XLU, XLY, XLE, XLP}
# 2011-08-05                                                 {}
# 2011-08-12                                                 {}
# 2011-08-19                                                 {}
# 2011-08-26                                              {XLU}
# 2011-09-02                                              {XLU}
# 2011-09-09                                              {XLU}
# 2011-09-16                                         {XLU, XLP}
# 2011-09-23                                              {XLU}
# 2011-09-30                                              {XLU}
# 2011-10-07                                              {XLU}
# 2011-10-14                               {XLY, XLU, XLK, XLP}
# 2011-10-21                               {XLY, XLU, XLK, XLP}
# 2011-10-28                     {XLV, XLU, XLY, XLE, XLK, XLP}
# 2011-11-04                          {XLU, XLY, XLE, XLK, XLP}
# 2011-11-11                     {XLV, XLU, XLY, XLE, XLK, XLP}
# 2011-11-18                                         {XLU, XLP}
# 2011-11-25                                                 {}
# 2011-12-02                     {XLI, XLU, XLY, XLE, XLK, XLP}
# 2011-12-09                {XLV, XLI, XLU, XLY, XLE, XLK, XLP}
# 2011-12-16                                         {XLU, XLP}
# 2011-12-23                {XLV, XLI, XLU, XLY, XLE, XLK, XLP}
# 2011-12-30                {XLV, XLI, XLU, XLY, XLE, XLK, XLP}
# 2012-01-06                {XLV, XLI, XLU, XLY, XLE, XLK, XLP}
# 2012-01-13           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2012-01-20           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2012-01-27           {XLV, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2012-02-03      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2012-02-10           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2012-02-17                {XLV, XLF, XLI, XLU, XLY, XLK, XLP}
# 2012-02-24      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2012-03-02      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2012-03-09           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2012-03-16                     {XLV, XLF, XLI, XLY, XLE, XLK}
# 2012-03-23                     {XLV, XLF, XLI, XLY, XLK, XLP}
# 2012-03-30                          {XLV, XLF, XLI, XLY, XLK}
# 2012-04-13                     {XLV, XLF, XLI, XLY, XLK, XLP}
# 2012-04-20                     {XLV, XLF, XLI, XLY, XLK, XLP}
# 2012-04-27                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2012-05-04                {XLV, XLF, XLI, XLY, XLK, XLB, XLP}
# 2012-05-11                     {XLV, XLF, XLI, XLY, XLK, XLP}
# 2012-05-18                          {XLV, XLU, XLY, XLK, XLP}
# 2012-05-25                          {XLV, XLU, XLY, XLK, XLP}
# 2012-06-01                                         {XLU, XLP}
# 2012-06-08                          {XLV, XLU, XLY, XLK, XLP}
# 2012-06-15                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2012-06-22                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2012-06-29                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2012-07-06                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2012-07-13                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2012-07-20                          {XLV, XLU, XLY, XLK, XLP}
# 2012-07-27                {XLV, XLF, XLI, XLU, XLY, XLK, XLP}
# 2012-08-03                {XLV, XLF, XLI, XLU, XLY, XLK, XLP}
# 2012-08-10           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2012-08-17           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2012-08-24           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2012-08-31                {XLV, XLF, XLU, XLY, XLE, XLK, XLP}
# 2012-09-07                {XLV, XLF, XLU, XLY, XLE, XLK, XLP}
# 2012-09-14      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2012-09-21                     {XLV, XLF, XLY, XLK, XLB, XLP}
# 2012-09-28                     {XLV, XLF, XLU, XLY, XLK, XLP}
# 2012-10-05           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2012-10-12      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2012-10-19           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2012-10-26           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2012-11-02                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2012-11-09                               {XLY, XLV, XLI, XLF}
# 2012-11-16                                    {XLY, XLV, XLF}
# 2012-11-23                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2012-11-30                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2012-12-07                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2012-12-14                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2012-12-21                     {XLV, XLF, XLI, XLY, XLE, XLB}
# 2012-12-28                          {XLV, XLF, XLI, XLY, XLB}
# 2013-01-04           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-01-11           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-01-18                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2013-01-25                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2013-02-01                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2013-02-08           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-02-15                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2013-02-22                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2013-03-01                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2013-03-08                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2013-03-15                {XLV, XLF, XLI, XLY, XLE, XLB, XLP}
# 2013-03-22           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2013-04-05           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2013-04-12           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2013-04-19                     {XLV, XLF, XLI, XLU, XLY, XLP}
# 2013-04-26           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2013-05-03           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2013-05-10           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2013-05-17           {XLV, XLF, XLI, XLU, XLY, XLE, XLB, XLP}
# 2013-05-24           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-05-31           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-06-07           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-06-14           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-06-21                {XLV, XLF, XLI, XLY, XLE, XLK, XLP}
# 2013-06-28                {XLV, XLF, XLI, XLU, XLY, XLE, XLP}
# 2013-07-05                     {XLV, XLF, XLI, XLY, XLE, XLP}
# 2013-07-12                     {XLV, XLF, XLI, XLY, XLE, XLP}
# 2013-07-19                     {XLV, XLF, XLI, XLY, XLE, XLP}
# 2013-07-26                {XLV, XLF, XLI, XLU, XLY, XLE, XLP}
# 2013-08-02                     {XLV, XLF, XLI, XLY, XLE, XLP}
# 2013-08-09           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLP}
# 2013-08-16                {XLV, XLF, XLI, XLY, XLE, XLK, XLP}
# 2013-08-23                {XLV, XLF, XLI, XLY, XLE, XLK, XLP}
# 2013-08-30                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2013-09-06                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2013-09-13           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-09-20           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-09-27                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2013-10-04                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2013-10-11           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-10-18           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-10-25           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-11-01           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-11-08           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-11-15                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2013-11-22                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2013-11-29                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2013-12-06           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-12-13           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2013-12-20                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2013-12-27           {XLV, XLF, XLI, XLY, XLE, XLK, XLB, XLP}
# 2014-01-03                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2014-01-10                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2014-01-17                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2014-01-24                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2014-01-31                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2014-02-07                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2014-02-14           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2014-02-21           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2014-02-28           {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB}
# 2014-03-07                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2014-03-14      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2014-03-21      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2014-03-28      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2014-04-04      {XLV, XLF, XLI, XLU, XLY, XLE, XLK, XLB, XLP}
# 2014-04-11                {XLV, XLI, XLU, XLE, XLK, XLB, XLP}
# 2014-04-25           {XLV, XLF, XLI, XLU, XLE, XLK, XLB, XLP}
# ...
# 2017-03-03                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2017-03-10                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2017-03-17                     {XLF, XLI, XLU, XLY, XLK, XLB}
# 2017-03-24                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2017-03-31                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2017-04-07           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-04-21                {XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-04-28                {XLV, XLF, XLI, XLY, XLK, XLB, XLP}
# 2017-05-05           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-05-12           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-05-19           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-05-26           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-06-02           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-06-09           {XLV, XLF, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-06-16     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-06-23     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-06-30     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-07-07     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-07-14     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-07-21     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-07-28     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-08-04     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-08-11     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-08-18          {XLV, XLF, XLRE, XLI, XLU, XLK, XLB, XLP}
# 2017-08-25               {XLV, XLF, XLRE, XLI, XLU, XLK, XLB}
# 2017-09-01          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-09-08               {XLV, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-09-15     {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB, XLP}
# 2017-09-22          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-09-29          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-10-06          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-10-13          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-10-20          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-10-27                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2017-11-03          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-11-10          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-11-17          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-11-24          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-12-01     {XLV, XLF, XLRE, XLI, XLU, XLY, XLE, XLK, XLB}
# 2017-12-08          {XLV, XLF, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2017-12-15                {XLV, XLF, XLI, XLU, XLY, XLK, XLB}
# 2017-12-22                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2017-12-29                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2018-01-05                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2018-01-12                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2018-01-19                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2018-01-26                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2018-02-02                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2018-02-09                          {XLF, XLI, XLY, XLK, XLB}
# 2018-02-16                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2018-02-23                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2018-03-02                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2018-03-09                     {XLV, XLF, XLI, XLY, XLK, XLB}
# 2018-03-16                          {XLV, XLF, XLI, XLY, XLK}
# 2018-03-23                                         {XLY, XLK}
# 2018-04-06                                              {XLY}
# 2018-04-13                                    {XLY, XLE, XLK}
# 2018-04-20                          {XLF, XLI, XLY, XLE, XLK}
# 2018-04-27                                    {XLY, XLE, XLK}
# 2018-05-04                                    {XLY, XLE, XLK}
# 2018-05-11                               {XLY, XLE, XLK, XLF}
# 2018-05-18                     {XLF, XLI, XLY, XLE, XLB, XLK}
# 2018-05-25                               {XLY, XLE, XLK, XLI}
# 2018-06-01                               {XLY, XLE, XLK, XLI}
# 2018-06-08                {XLV, XLF, XLI, XLY, XLE, XLK, XLB}
# 2018-06-15                          {XLV, XLY, XLE, XLK, XLB}
# 2018-06-22                               {XLY, XLV, XLE, XLK}
# 2018-06-29                                    {XLY, XLE, XLK}
# 2018-07-06                         {XLV, XLRE, XLY, XLE, XLK}
# 2018-07-13                         {XLV, XLRE, XLY, XLE, XLK}
# 2018-07-20                         {XLV, XLRE, XLY, XLE, XLK}
# 2018-07-27          {XLV, XLF, XLRE, XLI, XLU, XLY, XLE, XLK}
# 2018-08-03          {XLV, XLF, XLRE, XLI, XLU, XLY, XLE, XLK}
# 2018-08-10                    {XLV, XLRE, XLU, XLY, XLE, XLK}
# 2018-08-17               {XLV, XLF, XLRE, XLU, XLY, XLK, XLP}
# 2018-08-24          {XLV, XLF, XLRE, XLI, XLU, XLY, XLE, XLK}
# 2018-08-31               {XLV, XLRE, XLI, XLU, XLY, XLE, XLK}
# 2018-09-07               {XLV, XLRE, XLI, XLU, XLY, XLK, XLB}
# 2018-09-14               {XLV, XLRE, XLI, XLU, XLY, XLE, XLK}
# 2018-09-21               {XLV, XLRE, XLI, XLU, XLY, XLE, XLK}
# 2018-09-28          {XLV, XLRE, XLI, XLU, XLY, XLE, XLK, XLP}
# 2018-10-05                     {XLV, XLI, XLU, XLY, XLE, XLK}
# 2018-10-12                                    {XLV, XLU, XLP}
# 2018-10-19                                    {XLV, XLU, XLP}
# 2018-10-26                                         {XLU, XLP}
# 2018-11-02                                    {XLV, XLU, XLP}
# 2018-11-09                              {XLV, XLU, XLRE, XLP}
# 2018-11-16                              {XLV, XLU, XLRE, XLP}
# 2018-11-23                              {XLV, XLU, XLRE, XLP}
# 2018-11-30                              {XLV, XLU, XLRE, XLP}
# 2018-12-07                              {XLV, XLU, XLRE, XLP}
# 2018-12-14                                   {XLU, XLRE, XLP}
# 2018-12-21                                              {XLU}
# 2018-12-28                                                 {}
# 2019-01-04                                                 {}
# 2019-01-11                                                 {}
# 2019-01-18                                              {XLV}
# 2019-01-25                                             {XLRE}
# 2019-02-01                                   {XLV, XLU, XLRE}
# 2019-02-08                              {XLI, XLU, XLRE, XLP}
# 2019-02-15               {XLV, XLRE, XLI, XLU, XLY, XLK, XLP}
# 2019-02-22     {XLV, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-03-01  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-03-08               {XLRE, XLC, XLI, XLU, XLY, XLK, XLB}
# 2019-03-15  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-03-22               {XLRE, XLC, XLI, XLU, XLY, XLK, XLP}
# 2019-03-29     {XLV, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-04-05  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-04-12     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-04-26     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-05-03     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-05-10     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-05-17     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-05-24          {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLP}
# 2019-05-31                    {XLRE, XLC, XLU, XLY, XLK, XLP}
# 2019-06-07  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-06-14  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-06-21  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-06-28     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-07-05     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-07-12          {XLF, XLRE, XLC, XLI, XLY, XLK, XLB, XLP}
# 2019-07-19          {XLF, XLRE, XLC, XLI, XLY, XLK, XLB, XLP}
# 2019-07-26          {XLF, XLRE, XLC, XLI, XLY, XLK, XLB, XLP}
# 2019-08-02     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-08-09     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-08-16               {XLRE, XLC, XLU, XLY, XLK, XLB, XLP}
# 2019-08-23                         {XLRE, XLU, XLY, XLK, XLP}
# 2019-08-30          {XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-09-06     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-09-13     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-09-20     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-09-27     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-10-04               {XLF, XLRE, XLC, XLU, XLY, XLK, XLP}
# 2019-10-11     {XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-10-18  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-10-25  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-11-01  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-11-08      {XLV, XLF, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-11-15  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-11-22  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-11-29  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-12-06  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLB,...
# 2019-12-13      {XLV, XLF, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-12-20      {XLV, XLF, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2019-12-27           {XLV, XLF, XLC, XLI, XLY, XLK, XLB, XLP}
# 2020-01-03           {XLV, XLF, XLC, XLI, XLU, XLY, XLK, XLP}
# 2020-01-10                     {XLV, XLF, XLC, XLI, XLY, XLK}
# 2020-01-17      {XLV, XLF, XLC, XLI, XLU, XLY, XLK, XLB, XLP}
# 2020-01-24     {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLP}
# 2020-01-31     {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLP}
# 2020-02-07     {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLP}
# 2020-02-14     {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLP}
# 2020-02-21     {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLK, XLP}
# 2020-02-28                                              {XLK}
# 2020-03-06                                    {XLV, XLU, XLK}
# 2020-03-13                                                 {}
# 2020-03-20                                                 {}
# 2020-03-27                                                 {}
# 2020-04-03                                                 {}
# 2020-04-17                                         {XLV, XLK}
# 2020-04-24                                         {XLV, XLK}
# 2020-05-01                                         {XLV, XLK}
# 2020-05-08                                    {XLC, XLK, XLV}
# 2020-05-15                                         {XLV, XLK}
# 2020-05-22                               {XLY, XLC, XLK, XLV}
# 2020-05-29                          {XLV, XLC, XLY, XLB, XLK}
# 2020-06-05                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-06-12                                    {XLY, XLC, XLK}
# 2020-06-19                          {XLV, XLC, XLY, XLB, XLK}
# 2020-06-26                                    {XLY, XLC, XLK}
# 2020-07-10                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-07-17                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-07-24                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-07-31               {XLV, XLRE, XLC, XLY, XLK, XLB, XLP}
# 2020-08-07                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-08-14                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-08-21                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-08-28                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-09-04                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-09-11                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-09-18                {XLV, XLC, XLI, XLY, XLK, XLB, XLP}
# 2020-09-25                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-10-02                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-10-09                     {XLV, XLC, XLY, XLK, XLB, XLP}
# 2020-10-16                     {XLV, XLC, XLI, XLY, XLK, XLB}
# 2020-10-23                          {XLC, XLI, XLY, XLK, XLB}
# 2020-10-30                          {XLC, XLI, XLY, XLK, XLB}
# 2020-11-06                          {XLC, XLI, XLY, XLK, XLB}
# 2020-11-13                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2020-11-20                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2020-11-27                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2020-12-04                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2020-12-11                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2020-12-18                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2021-01-08                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2021-01-15                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2021-01-22                {XLV, XLF, XLC, XLI, XLY, XLK, XLB}
# 2021-01-29                {XLV, XLF, XLC, XLI, XLY, XLK, XLB}
# 2021-02-05                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2021-02-12                     {XLF, XLC, XLI, XLY, XLK, XLB}
# 2021-02-19                {XLF, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-02-26                {XLF, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-03-05                {XLF, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-03-12                {XLF, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-03-19                {XLF, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-03-26          {XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-04-09                {XLF, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-04-16  {XLV, XLF, XLRE, XLC, XLI, XLU, XLY, XLE, XLK,...
# 2021-04-23     {XLV, XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-04-30          {XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-05-07                {XLF, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-05-14               {XLV, XLF, XLRE, XLC, XLI, XLE, XLB}
# 2021-05-21                {XLV, XLF, XLC, XLI, XLE, XLK, XLB}
# 2021-05-28          {XLV, XLF, XLRE, XLC, XLI, XLE, XLK, XLB}
# 2021-06-04               {XLF, XLRE, XLC, XLI, XLE, XLB, XLK}
# 2021-06-11          {XLV, XLF, XLRE, XLC, XLI, XLE, XLK, XLB}
# 2021-06-18     {XLV, XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-06-25          {XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-07-02     {XLV, XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-07-09     {XLV, XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-07-16     {XLV, XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-07-23          {XLV, XLF, XLRE, XLC, XLI, XLY, XLK, XLB}
# 2021-07-30     {XLV, XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-08-06     {XLV, XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-08-13          {XLV, XLF, XLRE, XLC, XLI, XLU, XLK, XLB}
# 2021-08-20     {XLV, XLF, XLRE, XLC, XLI, XLU, XLK, XLB, XLP}
# 2021-08-27               {XLV, XLF, XLRE, XLC, XLI, XLB, XLK}
# 2021-09-03               {XLV, XLF, XLRE, XLC, XLI, XLB, XLK}
# 2021-09-10          {XLV, XLF, XLRE, XLC, XLI, XLK, XLB, XLP}
# 2021-09-17          {XLV, XLF, XLRE, XLC, XLU, XLY, XLK, XLP}
# 2021-09-24          {XLV, XLF, XLRE, XLC, XLY, XLE, XLK, XLP}
# 2021-10-01               {XLV, XLF, XLRE, XLC, XLY, XLE, XLK}
# 2021-10-08                    {XLV, XLF, XLRE, XLC, XLY, XLK}
# 2021-10-15     {XLV, XLF, XLRE, XLC, XLY, XLE, XLK, XLB, XLP}
# 2021-10-22                    {XLV, XLF, XLRE, XLY, XLE, XLK}
# 2021-10-29                    {XLV, XLF, XLRE, XLY, XLE, XLK}
# 2021-11-05               {XLV, XLF, XLRE, XLY, XLE, XLK, XLB}
# 2021-11-12     {XLV, XLF, XLRE, XLC, XLI, XLY, XLE, XLK, XLB}
# 2021-11-19               {XLV, XLF, XLRE, XLY, XLE, XLK, XLB}
# 2021-11-26          {XLV, XLF, XLRE, XLY, XLE, XLK, XLB, XLP}
# 2021-12-03               {XLV, XLRE, XLU, XLY, XLE, XLK, XLP}
# 2021-12-10                         {XLV, XLRE, XLY, XLE, XLK}
# 2021-12-17               {XLV, XLRE, XLU, XLY, XLE, XLK, XLP}
# 2021-12-31                    {XLV, XLRE, XLU, XLY, XLK, XLP}
# 2022-01-07          {XLV, XLF, XLRE, XLU, XLY, XLE, XLK, XLP}
# 2022-01-14     {XLV, XLF, XLRE, XLU, XLY, XLE, XLK, XLB, XLP}
# 2022-01-21                                    {XLE, XLU, XLP}
# 2022-01-28                               {XLF, XLE, XLU, XLP}
# 2022-02-04                               {XLF, XLE, XLU, XLP}
# 2022-02-11                                    {XLE, XLF, XLP}
# 2022-02-18                                    {XLE, XLF, XLP}
# 2022-02-25                                    {XLE, XLF, XLP}
# 2022-03-04                                    {XLE, XLU, XLP}
# 2022-03-11                                         {XLE, XLU}
# 2022-03-18                {XLV, XLF, XLI, XLU, XLE, XLB, XLP}
# 2022-03-25                {XLV, XLF, XLI, XLU, XLE, XLB, XLP}
# 2022-04-01                    {XLV, XLRE, XLU, XLE, XLB, XLP}
# 2022-04-08                    {XLV, XLRE, XLU, XLE, XLB, XLP}

# %%
# removeList = []
# nasdaqList = pd.read_pickle("stockData/tickerList.pkl")
# for stock in nasdaqList:
#     try:
#         df = getStage(stock, coef,goodSectorDf)
#         if df.empty:
#             removeList.append(stock)
#     except:
#         removeList.append(stock)

# %%
# import pickle
# for removeItem in removeList:
#     nasdaqList.remove(removeItem)
# listOfTickerObject = open('stockData/tickerListpkl', 'wb')
# pickle.dump(nasdaqList, listOfTickerObject)
# listOfTickerObject.close()

# %%
# Open a file
nasdaqList = pd.read_pickle("stockData/tickerList.pkl")
result = open("Testdata/Realtime/result"+date.today().strftime('%Y-%m-%d')+".txt", "w")
buyList = []
holdList = []
sellList = []
portfolio = []
for symbol in nasdaqList:
    df = getStage(symbol,coef,goodSectorDf)
    shares = 0
    sharesSPY = 0
    if df.empty:
        continue
    if df.iloc[-1].Stage=="Buy":
        print(symbol," buy ",df.iloc[-1].support * coef[7])
        result.write(symbol+" buy " + str(df.iloc[-1].support * coef[7]) + "\n")
        buyList.append(symbol)
        portfolio.append(tuple((symbol, df.iloc[-1].close)))
    elif df.iloc[-1].Stage=="Stage 2":
        print(symbol," hold ",df.iloc[-1].support * coef[7])
        result.write(symbol+" hold " + str(df.iloc[-1].support * coef[7]) + "\n")
        holdList.append(holdList)
        portfolio.append(tuple((symbol, df.iloc[-1].close)))
    elif df.iloc[-1].Stage[0:4]=="Sell":
        print(symbol+" sell")
        result.write(symbol+" sell\n")
        sellList.append(sellList)
result.close()

# %%
##CURRENT BALANCE
balance = 100
allocation = balance / len(portfolio)
for ticker, close in portfolio:
    print(ticker, allocation / close, close)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/1q/w3g5nkks29g3kjdwmq1lssj00000gn/T/ipykernel_27301/3272274215.py in <module>
#       1 ##CURRENT BALANCE
#       2 balance = 100
# ----> 3 allocation = balance / len(portfolio)
#       4 for ticker, close in portfolio:
#       5     print(ticker, allocation / close, close)
#
# ZeroDivisionError: division by zero

# %%
print(buyList)
# Out:
# []

# %%
getStage("SAMG", coef, goodSectorDf)
# Out:
#                 close                                           Stage  \
# 2013-06-28  12.000000
# 2013-07-05  11.590000   volume -0.4776714513556619 1.1421709856192384
# 2013-07-12  12.650000   volume -0.6259541984732824 1.1421709856192384
# 2013-07-19  12.260000      RS -1.1878897336408405 0.27350824408318475
# 2013-07-26  14.060000  volume -0.13807982740021574 1.1421709856192384
# ...               ...                                             ...
# 2022-03-04  16.850000             bad sector XLF{'XLU', 'XLP', 'XLE'}
# 2022-03-11  17.990000                    bad sector XLF{'XLU', 'XLE'}
# 2022-03-18  19.700001                                         bearish
# 2022-03-25  21.910000                                             Buy
# 2022-04-01  20.219999      Sell 19.700000762939453 1.0764846753295985
#
#               support
# 2013-06-28   0.000000
# 2013-07-05   0.000000
# 2013-07-12   0.000000
# 2013-07-19   0.000000
# 2013-07-26   0.000000
# ...               ...
# 2022-03-04   0.000000
# 2022-03-11   0.000000
# 2022-03-18   0.000000
# 2022-03-25  19.700001
# 2022-04-01   0.000000
#
# [442 rows x 3 columns]

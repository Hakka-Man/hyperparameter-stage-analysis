# %%
file = open('params2022-04-01.txt')
i = 0
coef = ""
profit = 0
dictOfIndividuals = {}
for line in file:
    if i%2 == 0:
        coef = line
        i = i + 1
    elif i%2 == 1:
        profit = float(line)
        dictOfIndividuals[profit] = coef
        i = i + 1
print(sorted(dictOfIndividuals))
# Out:
# [129.33283778270814, 130.54184262870982, 131.27811663563958, 132.53728572383704, 144.74351946493576, 144.76123193202125, 146.2814291517756, 146.32356205317066, 152.1525578395711, 153.96600130883334, 156.35732513298674, 159.21454428533085, 161.21466614903386, 164.02019158597733, 167.73700463710682, 173.32760014567847, 183.93696812127246, 186.0921716819213, 186.4211041091296, 188.11490977518142, 193.37788854694244, 195.0759531660618, 196.02771037281923, 198.01978422772154, 198.53073794388922, 199.36873674612568, 199.9899154738561, 201.41411770879606, 202.54964618040867, 204.39693750248867, 205.4041789724307, 207.30552070576587, 207.37827299072364, 208.47019239588064, 213.1065794759232, 213.49891476501475, 214.10970327870936, 215.34543855984688, 216.91203234169993, 218.0538104309353, 219.9674042844838, 220.59322202909058, 221.07027196809952, 221.6010948260017, 221.7921244638911, 222.6826975446908, 223.48752771508273, 225.67589380169855, 226.97965972042456, 233.34303265545063, 234.927801
# ...

# %%
for key, value in dictOfIndividuals.items():
    list = eval(value)
    if float(list[1])>3:
        print(key, value)
# Out:
# 1542186.6032520207 [0.5011440230323366, 3.8034271746341566, 0.17302929388129204, 1.0355600122140736, 1.2191151180654558, 0.9385543909714653, 0.9752430891941133, 0.8777836122222266]
#
# 3877.8510838491343 [1.7570048853449112, 3.027536308035151, 0.06296835051531165, 1.0362489943642588, 1.0200915742895056, 0.9161722041503617, 1.0076884939768656, 1.1072466293805465]
#
# 309.0466197642747 [1.3208282761456338, 3.3309351143437764, -0.008930627220204532, 1.0404326540809017, 0.9268603446648638, 1.0496312299250454, 1.0941697041022265, 1.0487894320583804]
#
# 7991.969577155914 [1.237698923837466, 3.245912950212817, 0.23512545984097402, 1.0135707509559404, 1.075533784690782, 1.0037076374743743, 1.0149621842960228, 1.0848940589973943]
#
# 5909.011332177235 [0.5865759071650876, 3.494256471937071, 0.15183653345257847, 1.0318557026038373, 1.1886458389789818, 0.9966505317540377, 1.0319121608413466, 0.9730201823830176]
#
# ...

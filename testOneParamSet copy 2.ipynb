# %%
## IMPORTS
import numpy as np
import timeit
start = timeit.default_timer()
from datetime import datetime, date
from stage import getStage, fullPrint
import pandas as pd
from datetime import timedelta
import pickle
import yahoo_fin.stock_info as yf
import warnings

# %%
now = datetime.now()
transactionTemplate = yf.get_data('AAPL', start_date="1995-01-06",end_date= now, index_as_date = True).drop(['open','high','low','close','adjclose','volume','ticker'],axis=1)
transactionTemplate['Dates'] = pd.to_datetime(transactionTemplate.index)
transactionTemplate = transactionTemplate[transactionTemplate['Dates'].dt.weekday == 4]
transactionTemplate = transactionTemplate.drop('Dates', axis = 1)
transactionTemplate = transactionTemplate[~transactionTemplate.index.duplicated()]
transactionTemplate.to_pickle("transactionTemplate.pkl")

# %%
test = ['AIRG', 'MTEX', 'CAAS', 'APR', 'BSBK', 'RSSS', 'ADTHW', 'GLUE', 'STTK', 'WING', 'EWCZ', 'TTEC', 'OCG', 'AEAC', 'MKTX', 'FRLN', 'MLACU', 'AAME', 'RMBI', 'GPCOU', 'GWII', 'NMIH', 'CZR', 'PRPH', 'WMPN', 'ABCB', 'CCD', 'LAND', 'MUDSU', 'RVMD', 'LSEA', 'MMSI', 'LHAA', 'SENEB', 'WINVU', 'GRTX', 'GIIX', 'GTIM', 'PETQ', 'NKTX', 'CVLG', 'GACQU', 'NN', 'FOUN', 'CFIVU', 'LXEH', 'SQFT', 'IIIIU', 'ZI', 'GRVI', 'CLFD', 'MMLP', 'POLA', 'NBRV', 'MUDS', 'GBOX', 'VS', 'TRONU', 'SGA', 'CHX', 'STNE', 'NEON', 'SNOA', 'BPTH', 'HFBL', 'INTE', 'BIDU', 'NVAC', 'OBNK', 'LFTRU', 'AVDL', 'ASPU', 'AIHS', 'RELL', 'IKT', 'HSII', 'LIBY', 'CERT', 'LBRDA', 'HCDIP', 'ADSEW', 'HERAU', 'MMYT', 'BHSEU', 'VNET', 'ENER', 'EFSCP', 'EPHY', 'NCSM', 'DLO', 'TOPS', 'NSIT', 'RXST', 'NRACU', 'ATRS', 'VYNT', 'OMER', 'OCAXU', 'VTGN', 'TARA', 'INDP', 'FEMY', 'SRSA', 'LAZR', 'PDCE', 'MYPS', 'IGMS', 'VRPX', 'VC', 'TTD', 'WB', 'MPRAU', 'RCKT', 'NESR', 'GRPN', 'KC', 'BSGM', 'HCP', 'AMCX', 'BIOTU', 'TSIB', 'ZD', 'FSEA', 'CUBA', 'MORF', 'TGAAU', 'SWAV', 'VISL', 'ACLS', 'AVIR', 'NAACU', 'LGND', 'WHLRD', 'RMTI', 'NTLA', 'QH', 'PT', 'PEGRU', 'WPRT', 'KLTR', 'SHACU', 'PRTK', 'LRCX', 'WDC', 'CME', 'PUCKU', 'GOCO', 'OAS', 'RDI', 'UG', 'OMEX', 'CULL', 'ERYP', 'BWEN', 'SRAD', 'AATC', 'GTXAP', 'PACB', 'KSI', 'FLL', 'XMTR', 'DYN', 'TMPM', 'NCAC', 'GLTO', 'TNXP', 'BWACU', 'IDYA', 'SIGA', 'IIIV', 'MBUU', 'TFSL', 'RNWK', 'ADGI', 'AYLA', 'SASR', 'MEOA', 'DRTT', 'EXAI', 'NFBK', 'GBDC', 'HIIIU', 'PTCT', 'ACHV', 'ALLO', 'TENB', 'KRON', 'MANH', 'NWLI', 'FGFPP', 'BMAQU', 'ASLN', 'LTRPB', 'CTLP', 'ALYA', 'AFACU', 'OBT', 'FBIZ', 'DAWN', 'MVBF', 'APAC', 'RAND', 'ONEM', 'QNRX', 'ARRWU', 'VRRM', 'CROX', 'KFFB', 'SVFD', 'HOPE', 'SGII', 'WTFC', 'TPST', 'ADIL', 'GPRE', 'TUSK', 'PRLH', 'OEG', 'MYSZ', 'OBCI', 'TAYD', 'WTFCP', 'VORB', 'BWC', 'SRNE', 'SLDB', 'SIDU', 'AXON', 'FTCVU', 'CGC', 'HNNA', 'DNAB', 'JNCE', 'REYN', 'BAFN', 'AVGO', 'TWST', 'INTEU', 'TMPMU', 'GCMG', 'CHRS', 'PFSW', 'DISA', 'PEBO', 'CNTQU', 'GNPX', 'MOHO', 'VMD', 'CUE', 'GSM', 'HERA', 'BIGC', 'SCLE', 'BIMI', 'GGMCU', 'NDACU', 'SDGR', 'SELF', 'LQDT', 'FTCV', 'RCAT', 'RNXT', 'AMEH', 'SMCI', 'IBKR', 'IONM', 'PTC', 'CTIC', 'OSTR', 'PRDO', 'IDRA', 'SAMA', 'SANBU', 'ONCY', 'VUZI', 'LUMO', 'XPEL', 'IOACU', 'PDCO', 'WSFS', 'ATSG', 'LIONW', 'SOTK', 'ONB', 'NAII', 'DTOC', 'AGRI', 'LIXT', 'OCUL', 'DDOG', 'SOFO', 'SPSC', 'RUBY', 'CRWS', 'BLBX', 'VTIQ', 'ABCL', 'ALIM', 'ITQ', 'VINO', 'VRDN', 'MAAQW', 'SPWH', 'GRNQ', 'PAQCU', 'VQS', 'VCKA', 'VIVO', 'AMYT', 'SHEN', 'NVEC', 'CCCC', 'ADES', 'RENO', 'ADALW', 'AQMS', 'IMUX', 'WW', 'AXNX', 'HROW', 'ACER', 'VCEL', 'INPX', 'UK', 'MTRY', 'BRZE', 'AACIU', 'FCUV', 'VCYT', 'HBAN', 'GEEXW', 'TTNP', 'MPAA', 'FHB', 'ICMB', 'GTAC', 'BYND', 'GLEEU', 'SRSAU', 'IMNM', 'HSIC', 'OTRAU', 'DSEY', 'WBA', 'CEVA', 'LNDC', 'CDNA', 'IBTX', 'BDTX', 'RCKY', 'ITHXU', 'CWBC', 'BWBBP', 'ADAP', 'RACB', 'LCAP', 'BRIV', 'AMST', 'ICCC', 'THCPU', 'MPWR', 'CARV', 'FSSI', 'CHWAU', 'CRTX', 'MNPR', 'CVCO', 'CENX', 'HLIT', 'CMPOW', 'RNERU', 'MGIC', 'TVTY', 'BMRC', 'CFVIU', 'CCLP', 'OTEC', 'VAQC', 'OCCI', 'VRA', 'TROW', 'RBCAA', 'JMACW', 'UBCP', 'ICAD', 'TCRT', 'AIRTP', 'RMGCU', 'OPBK', 'UTSI', 'AIH', 'SLRX', 'VIVK', 'EDNC', 'TBSAU', 'GLDD', 'AEZS', 'DHHCU', 'FTRP', 'FARM', 'NLITU', 'CERE', 'ANGI', 'BMBL', 'RNDB', 'OSUR', 'AEAE', 'MCHP', 'NNOX', 'CLGN', 'VELO', 'VRM', 'RRGB', 'SOHOO', 'IMVT', 'ANTE', 'CVV', 'ATLO', 'PDSB', 'PFMT', 'PFX', 'ROSEU', 'UDMY', 'ANZU', 'SUMR', 'MTCH', 'SBFM', 'GATEU', 'COLM', 'TGA', 'PUBM', 'SNPS', 'CALT', 'HRTX', 'LGST', 'BHAC', 'SBET', 'SGRP', 'TWLV', 'RIDE', 'BNSO', 'DMAQ', 'SPKAU', 'TEKKU', 'ARBG', 'HTLD', 'TITN', 'HLNE', 'DGHI', 'ADXN', 'CFRX', 'ZNTL', 'MCAAU', 'CNTY', 'LANDO', 'JOAN', 'CARA', 'SVVC', 'CNXC', 'REDU', 'INGN', 'UBX', 'MBINN', 'ITRI', 'EBACU', 'KAIRU', 'FLAC', 'JAQCU', 'MRVI', 'BGFV', 'AMCIU', 'WTMAU', 'CRZN', 'SGML', 'NOAC', 'ACGL', 'USAK', 'ALF', 'CPAR', 'GILT', 'ALOR', 'CALA', 'BLDE', 'TZPS', 'MGTX', 'KOPN', 'ARIZ', 'VERY', 'IPDN', 'AKRO', 'GEOS', 'MESO', 'KALV', 'GOODN', 'DXPE', 'ANY', 'SRCE', 'ABGI', 'QTRX', 'GSMGW', 'PCTY', 'NVVE', 'CLRMU', 'ICLR', 'CGBD', 'AMGN', 'HSDT', 'TRUP', 'FLNT', 'RELI', 'CNNB', 'DYAI', 'INVA', 'GET', 'AEHR', 'SAGE', 'LMDX', 'HTOO', 'TLS', 'BTBT', 'ME', 'APTO', 'EML', 'RDUS', 'KAVL', 'BRKL', 'CCEL', 'FWP', 'EFSC', 'GDEN', 'MSGM', 'WWACU', 'MMAT', 'SYBT', 'COFS', 'AVDX', 'LUNA', 'GACQ', 'CSGP', 'ZM', 'DOCU', 'NMFC', 'IMCR', 'TKNO', 'UCBIO', 'TCMD', 'ADUS', 'IXAQ', 'DERM', 'RNERU', 'STRS', 'KZIA', 'QUMU', 'HEAR', 'CYCCP', 'ROCAU', 'CVGI', 'FNHC', 'ALKS', 'PRPL', 'CRTO', 'LXRX', 'CSWI', 'BTWNU', 'NWBI', 'XFINW', 'CLBK', 'RDFN', 'UPTD', 'PFHD', 'MTC', 'SSNC', 'DNAA', 'LTRN', 'AVID', 'MLAC', 'AHPA', 'NRXPW', 'OPI', 'CTHR', 'AEHL', 'STOK', 'CRON', 'MYNA', 'OKTA', 'VLDR', 'APPN', 'SRGA', 'LMNR', 'MTEM', 'AEYE', 'VIVE', 'UMBF', 'BTCY', 'BTBD', 'REG', 'STRL', 'KYMR', 'VBIV', 'VPCBU', 'CMPI', 'CYTK', 'PULM', 'ACAHU', 'BOCNU', 'CHMG', 'LHDX', 'GBRGU', 'AUVI', 'Z', 'LBPH', 'QCOM', 'ICCH', 'AXSM', 'TILE', 'RCEL', 'COLL', 'FWBI', 'CHTR', 'PGNY', 'TDUP', 'BWAY', 'FNGR', 'SSNT', 'JWEL', 'NGMS', 'FUV', 'HALL', 'KPRX', 'REFI', 'SUNS', 'TBLA', 'USWS', 'ALJJ', 'LYTS', 'GEG', 'SLMBP', 'PME', 'AUTL', 'VHNA', 'NMRK', 'VLYPP', 'FWONK', 'TRVN', 'PAQC', 'IMGN', 'USCT', 'VEV', 'ONTX', 'AGTC', 'ERAS', 'OPGN', 'DNLI', 'PFBC', 'APTMU', 'CVET', 'DNAY', 'BFRI', 'STXB', 'BNOX', 'GDYN', 'PEP', 'FHTX', 'BON', 'FFIC', 'LOAN', 'MAAQ', 'SGMA', 'TTOO', 'HOLX', 'FINMU', 'CVRX', 'FITBO', 'RNW', 'UBFO', 'ENSC', 'ZBRA', 'VRAR', 'GLBL', 'INBX', 'BLFS', 'AWRE', 'MTRYW', 'SNGX', 'FRONU', 'GDRX', 'LVRA', 'NICE', 'SSB', 'OXSQ', 'DSACU', 'MBIO', 'TREE', 'HCICU', 'COMS', 'SBLK', 'RCACU', 'BPYPP', 'ARRY', 'BILI', 'UPWK', 'AAWW', 'ESSCU', 'FUND', 'AUR', 'ICLK', 'COKE', 'CSSE', 'HCSG', 'CRTD', 'UEIC', 'SMPL', 'PHIC', 'NBSE', 'GGAL', 'KINZU', 'EAC', 'CASA', 'NVOS', 'UROY', 'NSTG', 'FWONA', 'PLXS', 'MBOT', 'ANDE', 'CBRGU', 'MOR', 'REVHU', 'RZLT', 'YELL', 'LTRY', 'AMLX', 'BWFG', 'LGAC', 'MODV', 'SURF', 'PEAR', 'MNDY', 'QRVO', 'AMTI', 'LSXMB', 'GDS', 'SLM', 'WWD', 'PROV', 'AVT', 'GRCL', 'BIOC', 'PODD', 'ACTDU', 'SIBN', 'AERI', 'UCL', 'FGF', 'CDTX', 'SBUX', 'PYPL', 'GTHX', 'TCVA', 'SOHO', 'ACTD', 'XFOR', 'ACEV', 'OLPX', 'IFRX', 'DYNT', 'TENX', 'PTRS', 'CNDT', 'GNOG', 'MRM', 'TOI', 'LOGI', 'HAPP', 'BCBP', 'CPRX', 'DHC', 'KSPN', 'VACC', 'EQRX', 'USEG', 'VIIAU', 'AXTI', 'AOSL', 'IMRX', 'PPSI', 'FSV', 'HON', 'BOTJ', 'MNRO', 'EBC', 'ACEVU', 'NRSN', 'OZON', 'BFC', 'CPIX', 'HFWA', 'MBINP', 'TNGX', 'SLNO', 'GRPH', 'CELC', 'DOMO', 'MPRA', 'NTAP', 'TRHC', 'ABVC', 'PLUS', 'GRUB', 'SOHON', 'OSBC', 'CINF', 'FCEL', 'ABTX', 'AUPH', 'EMCF', 'GPCO', 'QIWI', 'ACAD', 'ATCX', 'CVGW', 'HBCP', 'CRVS', 'DCOM', 'FSRX', 'ASPA', 'NRIX', 'NUWE', 'APTX', 'KOD', 'ISSC', 'VERI', 'FRBNU', 'HONE', 'ONCT', 'CCEP', 'AVGOP', 'OTRKP', 'CFFEU', 'AFRM', 'GGGVU', 'FRWAU', 'MSVB', 'ZY', 'GVP', 'CNTB', 'SCAQ', 'APXIU', 'FATPU', 'TRIB', 'HIBB', 'BREZ', 'ALACW', 'DTST', 'WEJOW', 'MASI', 'ULH', 'FHLTU', 'CASY', 'VALU', 'HOFV', 'FUTU', 'FIVE', 'MEAC', 'ARCB', 'VTAQ', 'FNCB', 'TXRH', 'THMO', 'REAX', 'FNWB', 'TASK', 'HPK', 'CMRX', 'ZSAN', 'AMRS', 'TSBK', 'AMWD', 'LMPX', 'VEON', 'NWL', 'TSAT', 'WAFDP', 'SSBK', 'GGAAU', 'IGAP', 'VTVT', 'CSX', 'MAAQU', 'GTACW', 'ERII', 'ACQRU', 'CSGS', 'EGBN', 'ELTK', 'CMBM', 'PTON', 'ELMS', 'PLBY', 'NTRB', 'VJET', 'VEEE', 'CCMP', 'SLRC', 'AEI', 'HYMCL', 'FLNC', 'AFCG', 'BROG', 'PCRX', 'PEGA', 'MNDT', 'SWIM', 'SSAAU', 'DMLP', 'OZK', 'VBLT', 'NEGG', 'VRTS', 'NRAC', 'GSAQ', 'VRTX', 'NNBR', 'SCOR', 'NTRA', 'SIRI', 'EQ', 'SBSI', 'AEPPZ', 'SOPH', 'NHICU', 'ANZUU', 'MRKR', 'SEIC', 'FINW', 'ROC', 'AGNC', 'IVAC', 'PZZA', 'ACOR', 'NNDM', 'CASI', 'MDNA', 'CLAYU', 'PLXP', 'ZLAB', 'KTCC', 'DSWL', 'PFLT', 'ELYM', 'GIPR', 'SAL', 'GERN', 'HTBK', 'TGVC', 'LEGN', 'ETTX', 'ONYXU', 'JKHY', 'ECPG', 'DUOL', 'LQDA', 'SMMF', 'BRY', 'TYME', 'WTRH', 'SIFY', 'EVCM', 'ZS', 'TGLS', 'SHOO', 'BNNRU', 'TRVG', 'LCAAU', 'RRBI', 'PKBK', 'ACHL', 'IAS', 'SCAQU', 'ASPS', 'FATP', 'EAR', 'BLRX', 'ARYD', 'IQMD', 'VABK', 'CWCO', 'ESGRP', 'JAQC', 'ALGN', 'AWH', 'FFIN', 'TECH', 'KLAQU', 'SFNC', 'FANG', 'PALT', 'ULBI', 'IPAXU', 'HYMC', 'LITTU', 'BRPMU', 'VLY', 'LAX', 'BCRX', 'FRW', 'HLBZ', 'GDEV', 'SABRP', 'CLRO', 'NHIC', 'CAC', 'SNCE', 'MAYS', 'HWEL', 'BHACW', 'CBRL', 'SMAP', 'SBRA', 'FATBB', 'OPT', 'EDSA', 'REED', 'TANH', 'NEXI', 'RDNT', 'CTAQ', 'TSHA', 'LAXXU', 'ANNX', 'GNTY', 'IOAC', 'REVEU', 'ON', 'AMOT', 'SBNYP', 'RGCO', 'LIZI', 'SCKT', 'MULN', 'GLBZ', 'FPAY', 'CCOI', 'YY', 'SDACU', 'SIMO', 'ARCE', 'BIVI', 'MNST', 'OYST', 'ARTE', 'CIH', 'CLVS', 'PCCTU', 'PHCF', 'SPI', 'GNTA', 'PSHG', 'PDLB', 'NMRD', 'CDAQU', 'MKTW', 'VRAY', 'KLIC', 'AUBAP', 'OPRX', 'SMID', 'IAC', 'SEVN', 'VLATU', 'PRCT', 'ADMP', 'VERO', 'LAAAU', 'SIER', 'ROAD', 'SCHN', 'FWAC', 'ENG', 'IPAR', 'EPAY', 'KLAC', 'TERN', 'ENTX', 'CDAQ', 'TCBI', 'XPER', 'UGRO', 'PSMT', 'LOGC', 'LANDM', 'TC', 'NHTC', 'CCB', 'ARRW', 'FTPA', 'CPOP', 'QQQX', 'LSXMA', 'BZUN', 'SINT', 'OTRA', 'RCRT', 'ARDS', 'BSQR', 'ADPT', 'STAF', 'WKEY', 'SLCRU', 'IMCC', 'AVEO', 'TSLA', 'IMRA', 'CTSO', 'STAB', 'BELFB', 'BCAB', 'REPH', 'FNVTW', 'AVHI', 'XENT', 'AMAO', 'RWLK', 'MYMD', 'GTPA', 'CTAQU', 'MF', 'SDH', 'BVXV', 'SBUX', 'SPCB', 'PLYA', 'GTH', 'ZNTE', 'DMAC', 'AAON', 'NGM', 'COWN', 'BLNK', 'STEP', 'DBVT', 'BGNE', 'MOBQ', 'PPBI', 'WINV', 'SSYS', 'WSBF', 'DGICB', 'TBKCP', 'SQFTW', 'LCAA', 'ORIA', 'TLIS', 'LARK', 'FHLT', 'BHSE', 'MINDP', 'DARE', 'EACPU', 'EYEN', 'CTSH', 'DJCO', 'QSI', 'BBGI', 'EDTX', 'CZNC', 'SNCY', 'BSET', 'ISLE', 'JAZZ', 'VERA', 'FSTR', 'ADERU', 'ADBE', 'PCSB', 'SWSSU', 'VSACU', 'RPRX', 'FRLAW', 'ADTH', 'OMGA', 'PMGMU', 'GNUS', 'RMGC', 'LFVN', 'BBIG', 'DHHC', 'IPAX', 'SPNE', 'ARCKU', 'JCICU', 'PPGHU', 'LOPE', 'MGI', 'CHI', 'HMTV', 'HYAC', 'RADA', 'HTIBP', 'SWET', 'LKFN', 'OTEX', 'LDHAU', 'PAYS', 'OM', 'EVLV', 'AMRK', 'ALAC', 'OTRK', 'HQY', 'EVER', 'THCA', 'GBNY', 'MICT', 'TUGCU', 'VALN', 'SPOK', 'MFH', 'ATVCU', 'ONCS', 'SBFM', 'NFE', 'RVSB', 'MGNX', 'AKYA', 'KELYB', 'PACXU', 'NLIT', 'SYNL', 'VWEWW', 'RMNI', 'VOXX', 'LESL', 'ORRF', 'PIIIW', 'AVTE', 'FITBP', 'HOOK', 'PSEC', 'PETV', 'BCYC', 'CTBI', 'CODA', 'MNMD', 'BTTX', 'RDBX', 'AGMH', 'TVTX', 'TIPT', 'ALLK', 'VIRC', 'FULT', 'FXNC', 'DALS', 'GRFS', 'BDSX', 'GABC', 'HLMN', 'UFCS', 'CLEU', 'EBTC', 'GRCYU', 'LGVC', 'ESBK', 'BTB', 'REVB', 'PCYG', 'AMBA', 'SPTN', 'GIIXU']

train = ['KDP', 'TNYA', 'PWP', 'EDNCU', 'ABOS', 'UEPS', 'HMPT', 'VLNS',
       'NIU', 'RIBT', 'MDWT', 'BNNR', 'AZN', 'AMPG', 'XNCR', 'PRIM',
       'RXRX', 'BYSI', 'FRLA', 'GLLI', 'PTIX', 'AINV', 'DBTX', 'AEAEU',
       'NUVA', 'OPEN', 'VTSI', 'LLNW', 'HIII', 'LIONU', 'PMGM', 'PEBK',
       'CBRGW', 'CASS', 'CRNX', 'JCTCF', 'VRME', 'OTECU', 'ROSEW',
       'GMBTU', 'CRMD', 'AFAC', 'LRFC', 'DFFN', 'GHSI', 'AMCI', 'MACK',
       'RGF', 'AGNCM', 'MITO', 'NWPX', 'SANA', 'TBPH', 'CACC', 'EPIX',
       'TLSA', 'CRNC', 'WWACW', 'LGVN', 'IMPP', 'ABMD', 'TRVI', 'VSEC',
       'FLMN', 'RXRAU', 'NAOV', 'POWW', 'PMD', 'ICHR', 'AIP', 'BCOR',
       'DWACU', 'NVSAU', 'METC', 'OLMA', 'CNOBP', 'EFOI', 'BBSI', 'VICR',
       'GAMB', 'UIHC', 'CDLX', 'VLGEA', 'SCLEU', 'ORPH', 'SPT', 'MKD',
       'FDBC', 'QUIK', 'ONYX', 'NSPR', 'PCH', 'SCHN', 'BTNB', 'UNB',
       'ZWRK', 'ASTE', 'OFED', 'EVOK', 'RXT', 'HBIO', 'HOOD', 'ISBC',
       'BBBY', 'STRN', 'SEAC', 'BFRA', 'ASRT', 'INO', 'SEV', 'AZTA',
       'SREV', 'IMGO', 'GASS', 'MAQC', 'XPAX', 'VOR', 'OLB', 'GFAI',
       'HVBC', 'BRLI', 'VREX', 'VECT', 'TUEM', 'CLBS', 'SDC', 'VHNAU',
       'BVS', 'IFBD', 'SSKN', 'SPRB', 'HFFG', 'PFIE', 'DRAY', 'MOXC',
       'OXUS', 'DCRDU', 'RPRX', 'ROAD', 'GMVD', 'SAIA', 'BCEL', 'SSP',
       'GFED', 'ERES', 'DFH', 'CYCN', 'TIGR', 'RXDX', 'WFCF', 'USAU',
       'AGBAU', 'DTRTU', 'TALK', 'AKTS', 'REAL', 'LFTR', 'GROW', 'HUT',
       'DSKE', 'ORMP', 'TCDA', 'VCSA', 'KDNY', 'KPTI', 'MQ', 'WALDU',
       'HYACU', 'ABEO', 'WOOF', 'ENERW', 'ULCC', 'APYX', 'SNPO', 'SBT',
       'PWOD', 'IMPL', 'AURCU', 'EMKR', 'NRDS', 'PROC', 'VGFC', 'BCDA',
       'SMIH', 'XBIT', 'VIASP', 'DSP', 'ATNF', 'PFDR', 'OLITU', 'AMPH',
       'RYAAY', 'ADI', 'MYRG', 'OZKAP', 'DILAU', 'ICFI', 'PHVS', 'GMTX',
       'VERB', 'CRWD', 'XERS', 'FKWL', 'FLUX', 'VG', 'BEEM', 'CLSN',
       'ITHX', 'ROCK', 'IPVIU', 'VSTA', 'AVCT', 'VENA', 'GMBLP', 'GOBI',
       'SUNW', 'DTRT', 'SLGN', 'ACQR', 'SLGCW', 'CYRN', 'CRAI', 'CGEN',
       'GLHAU', 'GCBC', 'PRFX', 'IIVI', 'CGRN', 'ATEC', 'PAA', 'SIVB',
       'MACA', 'GNSS', 'OXUSU', 'CRDF', 'WHF', 'LMACU', 'MEOAU', 'APCXW',
       'HNRG', 'DWAC', 'CHNR', 'SCPS', 'XP', 'THRY', 'ICVX', 'LAWS',
       'PHICU', 'POWL', 'KURA', 'FARO', 'RUSHB', 'ACVA', 'CIVB', 'ASLE',
       'MON', 'PCVX', 'SPWR', 'VNOM', 'LABP', 'CTXR', 'PIII', 'HUSN',
       'LMACA', 'KEQU', 'WSC', 'EXPO', 'ARCK', 'GALT', 'IQMDU', 'TIOA',
       'TZOO', 'SOHU', 'RGLD', 'CATC', 'ALGS', 'OCSL', 'NYXH', 'BFST',
       'DHBC', 'BSKYU', 'PSAGU', 'TRS', 'ALTO', 'VLON', 'OCCIO', 'HTHT',
       'SGC', 'NXTC', 'JSPR', 'MDGL', 'SGLB', 'ITI', 'XCUR', 'CFIV',
       'MBINO', 'PYPD', 'RCII', 'HORIU', 'RRR', 'OPK', 'PDD', 'OSTK',
       'ARQQ', 'HPLT', 'HAAC', 'TIGO', 'SIVBP', 'KZR', 'SEEL', 'GMAB',
       'WETF', 'AMPL', 'IMV', 'CFB', 'LPSN', 'LGTO', 'ADSK', 'COHU',
       'ACCD', 'STSA', 'HTLFP', 'DIBS', 'PRTC', 'BPAC', 'MLAI', 'ZVO',
       'VXRT', 'GLSI', 'PACW', 'LVOXU', 'NBEV', 'LNTH', 'THRN', 'COLI',
       'ADTX', 'BFI', 'LYRA', 'PANW', 'OCX', 'PRSRU', 'EFTR', 'LHCG',
       'PFDRU', 'DRIO', 'AGGRU', 'SFET', 'MRVL', 'PAGP', 'AKIC', 'TBSA',
       'CARG', 'LEDS', 'MDVL', 'TELA', 'UCTT', 'SWIR', 'MDRRP', 'WVFC',
       'MTAC', 'SNDX', 'CLDX', 'VCNX', 'GPACU', 'EBON', 'SCOBU', 'GEVO',
       'EMLDU', 'KLDO', 'ATER', 'MESA', 'APDN', 'FRPH', 'ALPA', 'PRAX',
       'BLDP', 'FATE', 'APTM', 'BOOM', 'WALD', 'JBHT', 'EDTXU', 'DYNS',
       'IGNYU', 'FCNCP', 'LEXX', 'GANX', 'EOSE', 'NVFY', 'ZNTEU', 'TOIIW',
       'IMPPP', 'INMB', 'CRCT', 'FTHM', 'LTRX', 'MHLD', 'MRCC', 'XAIR',
       'NKSH', 'TECTP', 'NBTB', 'ENPH', 'IMMP', 'CSII', 'SAMG', 'QURE',
       'HHGC', 'SBSI', 'SNY', 'SAFT', 'NVSA', 'CIFR', 'STX', 'XEL',
       'AMAOU', 'CMCO', 'WIX', 'ALACU', 'CHSCO', 'MERC', 'JCIC', 'ENSG',
       'SILK', 'GLAQ', 'PTE', 'DISCK', 'LCAPU', 'SLAM', 'NBSTU', 'STKL',
       'RNA', 'MBTC', 'CBRG', 'MCAA', 'DZSI', 'RCHG', 'VVPR', 'NECB',
       'MBWM', 'BLMN', 'RGP', 'SHLS', 'RELY', 'ATAX', 'PTPI', 'PRVA',
       'WRAP', 'WWAC', 'JBLU', 'FIZZ', 'SLVR', 'ANGO', 'ASAXU', 'SEER',
       'AURC', 'EXAS', 'TAOP', 'LINC', 'SFST', 'GEEX', 'GILD', 'CSTL',
       'ZIONO', 'MGRC', 'DCBO', 'IHRT', 'STRR', 'SCYX', 'VERV', 'CVLY',
       'MBNKP', 'ALBO', 'BOSC', 'NDLS', 'ALVR', 'OESX', 'ELDN', 'TURN',
       'AVACW', 'FENC', 'APPS', 'NEOG', 'ILMN', 'FUSB', 'OXLC', 'EBAY',
       'AHPI', 'BRID', 'IVCPU', 'PTGX', 'MDJH', 'FSBW', 'NVAX', 'RCON',
       'GFS', 'LITM', 'QDEL', 'WAVE', 'BUSE', 'GGPI', 'HWBK', 'AHI',
       'ORGO', 'NTUS', 'MOGO', 'EKSO', 'REGN', 'LOV', 'HCAR', 'PXLW',
       'AEHA', 'IEA', 'COMSP', 'HIHO', 'BBI', 'MIME', 'TA', 'FLWS',
       'HAACU', 'ECOL', 'SKYT', 'OHPAU', 'EVK', 'GLAQU', 'NARI', 'CNSL',
       'KRT', 'DILA', 'MYGN', 'CNCE', 'ZKIN', 'CREX', 'APWC', 'WTMA',
       'SNRH', 'TLRY', 'LPCN', 'CYTO', 'USCTU', 'BHFAO', 'SHCA', 'ARKO',
       'ATY', 'SCVL', 'MILE', 'BWB', 'PLCE', 'ISRG', 'AVCO', 'APOG',
       'PCAR', 'PCCT', 'SAFM', 'GVCI', 'REVBU', 'CENT', 'SYBX', 'HUGE',
       'APCX', 'DLHC', 'NWS', 'YTRA', 'VIA', 'DHACU', 'MAT', 'CFFI',
       'SLNHP', 'NYMT', 'SHQAU', 'TEDU', 'UPTDU', 'ATLC', 'PTICU', 'DIOD',
       'PGRW', 'VLCN', 'SBGI', 'CPRT', 'HEES', 'MVIS', 'HEPA', 'DAIO',
       'EYE', 'HYMCW', 'EQBK', 'MANT', 'LCNB', 'PCXCW', 'BENEU', 'EDAP',
       'AUB', 'ORLY', 'APP', 'MTACU', 'CFFE', 'SNPX', 'SBAC', 'OVLY',
       'VTNR', 'QTT', 'LWAY', 'KRKR', 'SWBI', 'ONCR', 'QCRH', 'CDXC',
       'TER', 'POWWP', 'LGSTW', 'EVOL', 'GLLIU', 'STCN', 'CLVR', 'SKYAU',
       'MCAF', 'GATE', 'TBLT', 'IIN', 'ASUR', 'ASRV', 'FELE', 'FAMI',
       'SAGA', 'YI', 'CECE', 'ARKR', 'HTZ', 'JMAC', 'RNLX', 'CYCC',
       'SIGI', 'GGMC', 'PNFP', 'YQ', 'ACMR', 'INTA', 'CRECU', 'PLMIU',
       'THTX', 'HIVE', 'EHTH', 'ARGX', 'PTEN', 'BPYPO', 'AVHIU', 'CLST',
       'GPRO', 'MARA', 'HCCI', 'THFF', 'USIO', 'AGIL', 'RIGL', 'VENAU',
       'MCBC', 'ALTR', 'JYAC', 'VCKAU', 'TETCU', 'SPTKU', 'SGBX', 'YGMZ',
       'IVCBU', 'CLPS', 'AFMD', 'CBTX', 'CRVL', 'DISCB', 'TESS', 'LYFT',
       'KFRC', 'RAIN', 'WASH', 'ZION', 'GRWG', 'SCOA', 'ROKU', 'MIRO',
       'LJPC', 'MSTR', 'NWE', 'RGNX', 'CNXN', 'LIONW', 'ADMA', 'KROS',
       'DLCAU', 'ARGU', 'NVEI', 'VTRS', 'BTX', 'BRAG', 'ARTW', 'KAIIU',
       'GTPBU', 'ONDS', 'SUPN', 'REVE', 'RNWK', 'MRAM', 'SSRM', 'BZ',
       'PRTH', 'RETO', 'INTU', 'PACX', 'CLSK', 'NYMTZ', 'SNFCA', 'PSTI',
       'MNTX', 'TGAN', 'WERN', 'VERX', 'SLGL', 'ACIU', 'LBTYB', 'MLVF',
       'DNUT', 'CBFV', 'CPSS', 'PUYI', 'CHCO', 'DMTK', 'GSMG', 'OB',
       'ALRN', 'MDB', 'GIWWU', 'BHFAP', 'ASTR', 'TRUE', 'KBAL', 'SANM',
       'CHWA', 'AKTX', 'NSYS', 'ROLLP', 'BCOV', 'PPGH', 'ATNX', 'CGEM',
       'PGRWU', 'CLAQ', 'BWCAU', 'GSEVU', 'BIOT', 'NDAC', 'INM', 'RMGC',
       'LILA', 'LINK', 'FRGI', 'BIIB', 'TOWN', 'RAPT', 'CALB', 'APPF',
       'MYFW', 'VSAT', 'GIGM', 'DHAC', 'GOEV', 'NOVVU', 'RDCM', 'RSVR',
       'GBIO', 'CHW', 'LBAI', 'NCBS', 'SFT', 'NODK', 'BRQS', 'SIOX',
       'FCFS', 'MTCR', 'ATHX', 'ARIZU', 'PETZ', 'RARE', 'GLYC', 'ALRM',
       'VYNE', 'WABC', 'PXS', 'OBLG', 'MPACU', 'NATR', 'CCNC', 'TOAC',
       'USLM', 'TAIT', 'SCPH', 'CETXP', 'VBFC', 'CWBR', 'AHCO', 'GGPIU',
       'DWSN', 'ALRS', 'STRM', 'BWAC', 'CBAT', 'PBHC', 'MKSI', 'SPKBU',
       'VII', 'ENDP', 'OP', 'RPTX', 'CLOV', 'CDEV', 'HMNF', 'DENN',
       'GXII', 'SWKS', 'AMSC', 'LNSR', 'SPTK', 'AESE', 'LTRPA', 'PBAX',
       'NTWK', 'PIK', 'AOGOU', 'MEKA', 'KOSS', 'GNACU', 'ARTEU', 'SQFTP',
       'ALDX', 'ROVR', 'LKQ', 'DVAX', 'HBNC', 'STRA', 'PKOH', 'FOX',
       'LTCH', 'ALXO', 'XXII', 'FBMS', 'SZZL', 'BLU', 'SNCR', 'MCHX',
       'API', 'INAB', 'PAFO', 'LEVLP', 'GLLIW', 'GXIIU', 'ESTA', 'KRYS',
       'LOCO', 'WKHS', 'PNT', 'CMLS', 'LSTR', 'LEGAU', 'SGIIU', 'ABNB',
       'PRTG', 'ENLV', 'VCXAU', 'PTIC', 'APMI', 'RIVN', 'MODD', 'STAA',
       'MACU', 'BHFAM', 'PBFS', 'HZNP', 'EXTR', 'WISA', 'GLPG', 'IRDM',
       'EVAX', 'INMD', 'OCDX', 'LZ', 'INTZ', 'OVID', 'CSIQ', 'NUVL',
       'LANC', 'PEGR', 'POSH', 'CMAX', 'APA', 'SVFC', 'SGEN', 'ESPR',
       'PATK', 'STRC', 'NAAC', 'SNTG', 'GOVX', 'STRNW', 'FB', 'ALHC',
       'LVO', 'FRBK', 'RENT', 'OTTR', 'ISPC', 'CMCTP', 'GDNRU', 'MONCU',
       'SYRS', 'ARVL', 'BHF', 'CENTA', 'TCPC', 'FCRD', 'MITK', 'RBBN',
       'COLIU', 'MEOH', 'KIIIU', 'HEPS', 'CTRM', 'PRFT', 'TUGC', 'ROCG',
       'TLMD', 'URBN', 'APVO', 'TTMI', 'SCMA', 'FVCB', 'OSIS', 'DLCA',
       'SAGAU', 'VPCB', 'NCNA', 'KINS', 'GRABW', 'AKICU', 'SCMAU', 'LASR',
       'RMBL', 'EXFY', 'SVFA', 'PAFOU', 'AZYO', 'LITE', 'GT', 'INTG',
       'HLG', 'APM', 'CLAQU', 'DSAC', 'WMG', 'CHCI', 'NVMI', 'STRO',
       'BLKB', 'WSBCP', 'TSP', 'OFLX', 'GWRS', 'RICK', 'SLP', 'GIII',
       'SIGIP', 'DISH', 'HLXA', 'FBIO', 'SHIP', 'COHR', 'RESN', 'PFC',
       'SDAC', 'LUXAU', 'SLN', 'AKU', 'EEIQ', 'TWCB', 'ROST', 'OFS',
       'CYRX', 'SABR', 'WAFU', 'NDAQ', 'ALOT', 'PROF', 'EZGO', 'LAZY', 'SRRA', 'NXTP', 'ACBA', 'HTBI',
       'THCP', 'GAIN', 'SGTX', 'OXACU', 'SOFI', 'CRNT', 'MCBS', 'SLDP',
       'EDUC', 'PAVM', 'JANX', 'MTTR', 'CRKN', 'EGLX', 'TCOM', 'ORIAU',
       'BEAT', 'XBIO', 'KPLT', 'ESSC', 'FFNW', 'XFIN', 'ADVM', 'IVA',
       'EXLS', 'OTMOW', 'ZTAQU', 'AQB', 'ANIX', 'TSCAP', 'SWKH', 'MAPS',
       'ITCI', 'EXC', 'ANEB', 'GMBL', 'TCFC', 'HIFS', 'WAVD', 'IXAQU',
       'ACXP', 'BNR', 'ALPAU', 'ISEE', 'SGH', 'IRMD', 'INKT', 'GOGL',
       'CGO', 'CDZI', 'TCBIO', 'EJFA', 'WVVI', 'EVO', 'CRBP', 'SALM',
       'SIEN', 'LVLU', 'SMTC', 'VRNA', 'ITOS', 'PTNR', 'CENQ', 'LIND',
       'ARAY', 'MACUU', 'HMCO', 'CODX', 'CHDN', 'MDRR', 'IBCP', 'PRDS',
       'CRIS', 'MBCN', 'CGNX', 'SABS', 'ABST', 'COMM', 'MGTA', 'SND',
       'FTPAU', 'ALEC', 'DBGI', 'PTLO', 'CNEY', 'CNSP', 'KMDA', 'KVSC',
       'XOMAO', 'NTRS', 'BCTX', 'SBFG', 'GYRO', 'CLWT', 'RKLB', 'POOL',
       'CORT', 'XLO', 'IGAC', 'RCLF', 'XOMAP', 'RAVE', 'TH', 'FTFT',
       'RCMT', 'HGSH', 'SHAC', 'FWRD', 'IMMX', 'PFIN', 'OGI', 'DLPN',
       'WULF', 'TWCBU', 'AEIS', 'PANL', 'EDIT', 'FOXF', 'MCRI', 'FRPT',
       'PFIS', 'SLS', 'CEMI', 'BIOL', 'EOLS', 'TRST', 'BIRD', 'DADA',
       'RWAY', 'CWST', 'CURI', 'MU', 'LITT', 'BBCP', 'SNEX', 'ANAT',
       'PSAG', 'GHACU', 'IGACU', 'PPIH', 'TAST', 'EVOP', 'RPHM', 'CBSH',
       'MMMB', 'KMPH', 'GTYH', 'EBET', 'FITB', 'CELH', 'GSHD', 'AUUD',
       'LWLG', 'DCPH', 'VECO', 'RAIN', 'LMNL', 'GTACU', 'AERC', 'ASAX',
       'OPRA', 'NH', 'ADAL', 'TRMR', 'AGFS', 'REPL', 'GLBS', 'MSAC',
       'MPAC', 'ATRI', 'MEIP', 'SANW', 'THCAU', 'CCAP', 'PECO', 'SSAA',
       'AEACU', 'EA', 'ITRN', 'XOS', 'HLAHU', 'DTEA', 'ABIO', 'CDXS',
       'PMVP', 'VERU', 'FTAA', 'MDIA', 'CHKP', 'AGNCO', 'CTKB', 'THRM',
       'GTPAU', 'VIOT', 'CYBR', 'TRMK', 'CIDM', 'DUNE', 'BMAQ', 'SITM',
       'RANI', 'MTSI', 'PBTS', 'UNIT', 'XPDBU', 'MASS', 'LGACU', 'KRNT',
       'TWIN', 'VINP', 'PETS', 'NSSC', 'SMFR', 'MSDA', 'NBTX', 'PTOCU',
       'OMAB', 'YORW', 'EIGR', 'LGHL', 'FOUNU', 'PRTA', 'LVACU', 'BKCC',
       'MNTK', 'AGNCP', 'FSSIU', 'GNTX', 'CHY', 'CLRM', 'MEDP', 'TROO',
       'PLTK', 'SPNS', 'HSTO', 'LAKE', 'BLFY', 'HBANP', 'PHAT', 'STLD',
       'PDFS', 'ALGM', 'VBTX', 'FYBR', 'TCRX', 'CHEF', 'TCBK', 'KLAQ',
       'VIRX', 'PTVE', 'ADAG', 'TMDX', 'CING', 'SPRO', 'IGIC', 'WILC',
       'ALCO', 'SESN', 'HOTH', 'GEEXU', 'NEO', 'HEXO', 'SVNA', 'UTMD',
       'VIEW', 'DCGO', 'DCT', 'ADTN', 'ALPP', 'TTSH', 'HRZN', 'BRLIU',
       'SCHL', 'WDAY', 'BECN', 'ALNA', 'ACIW', 'SYNH', 'BSKY', 'VELOU',
       'ZWRKU', 'AVTX', 'MARK', 'CONX', 'SVFB', 'MTBCO', 'IRWD', 'FNVT',
       'MACAU', 'DUOT', 'ACRX', 'TGVCW', 'MVST', 'SNES', 'ACB', 'INKAU',
       'VKTX', 'TNDM', 'LION', 'FSTX', 'KAIR', 'KNTE', 'FIVN', 'PAYX',
       'SERA', 'ASTL', 'FIAC', 'CLRB', 'RFIL', 'SBFMW', 'SMTI', 'SLGG',
       'TRKA', 'DNAC', 'MNKD', 'AIKI', 'MCRB', 'ETAC', 'OPNT', 'SYPR',
       'INBK', 'HHS', 'COCO', 'ANSS', 'CPHC', 'MAXN', 'KVHI', 'CAKE',
       'FRSG', 'CSCO', 'SVSVU', 'ATVC', 'AGIO', 'CIIG', 'LCUT', 'JOFF',
       'HNST', 'TSCBP', 'CONE', 'IDBA', 'CHSCN', 'TYRA', 'IDCC', 'AGEN',
       'AQST', 'COVA', 'POWI', 'OSPN', 'ALKT', 'GTX', 'TSCO', 'HCVIU',
       'ATNI', 'HCTI', 'IART', 'ACBAU', 'CLVRW', 'SCOA', 'NBIX', 'SWAG',
       'PCT', 'LTBR', 'HBP', 'SWTX', 'EPHYU', 'MNTS', 'PUCK', 'OXAC',
       'SOLO', 'FMTX', 'YJ', 'MDLZ', 'SGRY', 'FVAM', 'SDIG', 'PROG',
       'TRMB', 'SBLK', 'PBCTP', 'SCAQU', 'MIND', 'ABSI', 'ZEST', 'OPCH',
       'OCCIN', 'TACT', 'TCACU', 'PBBK', 'BKNG', 'ACAH', 'HA', 'ATIF',
       'LIBYU', 'FDUS', 'WINT', 'LKCO', 'CCTSU', 'HOLI', 'AMSWA', 'ISAA',
       'BOXL', 'XELA', 'VMEO', 'UCBI', 'CRZNU', 'KNDI', 'WHLR', 'RBB',
       'XRX', 'HUDI', 'SLDPW', 'JYNT', 'TOIIW', 'NSEC', 'ELYS', 'VTYX',
       'UTRS', 'OXBR', 'GGGV', 'BLSA', 'CCBG', 'GRIN', 'KIDS', 'RLAY',
       'KVSA', 'NWSA', 'RILYP', 'PGEN', 'STKS', 'DALN', 'APMIU', 'BWMX',
       'EVOJ', 'KSICU', 'ATAI', 'CBNK', 'KBNT', 'GMFIU', 'LMAO', 'ABUS',
       'GLRE', 'SATL', 'ROLL', 'RBCN', 'MCLD', 'ALNY', 'EBMT', 'BELFA',
       'PBCT', 'LGTOW', 'CLOEU', 'IBRX', 'FMAO', 'IRBT', 'ASPCU', 'LYEL',
       'IIII', 'RNAZ', 'AEMD', 'DISAU', 'JMACU', 'CITEU', 'COVAU', 'IBEX',
       'AUGX', 'ACST', 'PNNT', 'WKSP', 'AFAQ', 'DUO', 'AAL', 'ESAC',
       'PPTA', 'HMHC', 'CRXT', 'MRNS', 'OTLK', 'BMRA', 'FLXS', 'FOXW',
       'JUGG', 'ASTS', 'MLAIU', 'MCAE', 'CARE', 'FIXX', 'NMMC', 'AMED',
       'IBOC', 'PTSI', 'BRCN', 'ALSAU', 'BBLG', 'GTLB', 'GREE', 'BZFD',
       'BPYPN', 'TIVC', 'MBII', 'SCOB', 'AIRT', 'EZFL', 'LBTYK', 'SSTI',
       'CNTA', 'ACHC', 'HCWB', 'DGII', 'SCWX', 'CETX', 'FDMT', 'KXIN',
       'PTOC', 'NOACU', 'KNBE', 'LIFE', 'KIII', 'BHFAN', 'BIOS', 'SMIT',
       'TRNS', 'LE', 'AROW', 'FTCI', 'SQL', 'MXL', 'VORBW', 'HWC', 'HYRE',
       'VLYPO', 'REVH', 'OIIM', 'SVC', 'CAMT', 'CDZIP', 'HYW', 'TMKR',
       'ALTUU', 'UNCY', 'BSVN', 'UVSP', 'GRIL', 'APEI', 'CMCSA', 'BRTX',
       'INDI', 'GVCIU', 'SRZN', 'LMB', 'TTCF', 'CALM', 'NMTR', 'IPWR',
       'FSBC', 'LAUR', 'VTRU', 'BRP', 'WSTG', 'PEPLU', 'PRAA', 'HUMA',
       'OEPWU', 'III', 'FRSH', 'LPRO', 'CHSCP', 'PRLD', 'NVEE', 'LDHA',
       'LMFA', 'FINM', 'YTEN', 'AEP', 'GBT', 'OPHC', 'LX', 'LFST', 'INDT',
       'REFR', 'ISUN', 'OXLCM', 'RVACU', 'ISTR', 'CHPMU', 'TCX', 'GBS',
       'OLLI', 'FBNC', 'CLNE', 'NUZE', 'DRVN', 'RSLS', 'ATOS', 'CSCW',
       'IDXX', 'BEAM', 'ARLP', 'CBAN', 'ALGT', 'LAAA', 'KINZ', 'ALORU',
       'VRNS', 'AGYS', 'BAOS', 'RDHL', 'AGRX', 'ARHS', 'LILM', 'MDXH',
       'FCNCO', 'DOYU', 'AHG', 'LFUS', 'KLXE', 'EVFM', 'HHGCU', 'APACU',
       'BYRN', 'BKR', 'CD', 'PFG', 'TCRR', 'GNLN', 'BZFDW', 'VSTM',
       'LPTX', 'AVRO', 'FORD', 'HGBL', 'VYGR', 'XFINU', 'WHLRP', 'COOL',
       'SNAX', 'BSGA', 'ENTA', 'BXRX', 'ALORW', 'QTNT', 'NVCN', 'CKPT',
       'CYTH', 'JOUT', 'TGVCU', 'BRLT', 'OTLY', 'SONN', 'AGBA', 'BCAC',
       'WTBA', 'PLSE', 'MSFT', 'WNW', 'SYNA', 'HBANM', 'DTSS', 'GMBT',
       'LBRDK', 'QUBT', 'AYTU', 'GHAC', 'KHC', 'NOVV', 'AYRO', 'XNET',
       'AXDX', 'CPAAU', 'HSTM', 'INVO', 'COIN', 'LGSTU', 'KIRK', 'VTAQU',
       'OVBC', 'HBT', 'MAQCU', 'BLNGU', 'XSPA', 'AMNB', 'BLPH', 'AFAQU',
       'EPSN', 'DUNEU', 'PBPB', 'WTFCM', 'VIAV', 'ISIG', 'BWMN', 'CRMT',
       'GOGO', 'AKAM', 'CFVI', 'ARQT', 'ACGLO', 'HRMY', 'AXLA', 'DCOMP',
       'ALLR', 'IMAB', 'RAMMU', 'LPTH', 'TWNK', 'ATXS', 'OMIC', 'IZEA',
       'ZUMZ', 'MIDD', 'EVGN', 'LUNG', 'SWETU', 'ICCM', 'HAS', 'FOXWU',
       'PRSO', 'VWE', 'SLVRU', 'ANIK', 'LIVN', 'FMNB', 'FGBIP', 'STIM',
       'SHYF', 'GTEC', 'TSIBU', 'GNCA', 'CPARU', 'MNTV', 'VMGAU', 'TCON',
       'QLYS', 'XELB', 'VLAT', 'QMCO', 'APRE', 'LNT', 'SONM', 'HTGM',
       'ARGUU', 'LOVE', 'INFN', 'LSXMK', 'CDNS', 'NXST', 'MNOV', 'ARCT',
       'UPC', 'BLIN', 'SGMO', 'AVPT', 'ERESU', 'NVNOW', 'LOB', 'BTCS',
       'BJDX', 'OTIC', 'VRNT', 'LULU', 'FRST', 'WATT', 'OLK', 'KTOS',
       'INCY', 'FLYW', 'SHBI', 'EXPE', 'CSPI', 'KRBP', 'MITC', 'CUEN',
       'ANPC', 'MBRX', 'SAMAU', 'PI', 'PIXY', 'FFWM', 'GRCY', 'HCDI',
       'STER', 'HURN', 'LLL', 'QFIN', 'SENEA', 'FITBI', 'BRFH', 'XPAXU',
       'ACET', 'CVBF', 'IPSC', 'AXGN', 'FGBI', 'CPLP', 'NCMI', 'IEP',
       'LEGH', 'CLXT', 'CNTQ', 'PSTV', 'AVO', 'ELOX', 'CTXS', 'AIRS',
       'JUPW', 'AOUT', 'OCGN', 'STRRP', 'DSGN', 'BFIN', 'RCHGU', 'SVRA',
       'SCAQ', 'BNTX', 'SSSS', 'WIRE', 'KE', 'PLRX', 'NEXT', 'PEPL',
       'AMAT', 'NEPH', 'UBSI', 'SCSC', 'PFTA', 'VRSK', 'NRXP', 'CXDO',
       'PONO', 'CONN', 'AVACU', 'FTAAU', 'MEDS', 'UONEK', 'SLGC', 'CENQU',
       'ROIV', 'OHAAU', 'HCM', 'IMMR', 'JFIN', 'PALI', 'CONXU', 'MREO',
       'YMTX', 'IDEX', 'CCXI', 'CHNG', 'EDTK', 'WEYS', 'AAPL', 'EYES',
       'CASH', 'BL', 'WYNN', 'ATOM', 'IMAQU', 'KERN', 'SHCAW', 'EM',
       'PHAR', 'TWKS', 'FULTP', 'VOD', 'CELZ', 'LCID', 'GECC', 'FSRXU',
       'SPK', 'EGRX', 'CMPS', 'ELEV', 'OSW', 'COOP', 'XENE', 'CHPM',
       'ARBE', 'SV', 'LVOX', 'LEVL', 'KARO', 'TIG', 'VIRT', 'TARS',
       'SLAMU', 'OLIT', 'ASTC', 'GWGH', 'SIERU', 'AZPN', 'FCAP', 'STGW',
       'RSVR', 'CATY', 'LOTZ', 'OCAX', 'LVTX', 'CDRO', 'INVE', 'AMKR',
       'EMBK', 'FOSL', 'PTMN', 'DAOOU', 'NWFL', 'MGPI', 'NDSN', 'CAR',
       'ARWR', 'ESEA', 'CNET', 'SLNH', 'DHBCU', 'ARBK', 'TCBC', 'VRSN',
       'PLMR', 'CHSCL', 'ALZN', 'KAII', 'MGEE', 'BJRI', 'GPP', 'EBIX',
       'FTDR', 'TRON', 'IINN', 'QNST', 'POW', 'BKEP', 'FNWD', 'NATI',
       'PRSR', 'FIACU', 'LAMR', 'DGICA', 'GRTS', 'ADN', 'NVNO', 'HAIAU',
       'APLS', 'BSY', 'NMMCU', 'FEIM', 'INOD', 'LBC', 'GLBE', 'YMAB',
       'MITAU', 'NLTX', 'BYTSU', 'PTRA', 'QLGN', 'SECO', 'GAN', 'AVAH',
       'TWOU', 'ODFL', 'ICPT', 'CFMS', 'HCVI', 'CHRW', 'ENVB', 'FORTY',
       'ASND', 'IMKTA', 'TOACU', 'FMBH', 'MARPS', 'STBA', 'RMBL', 'INNV',
       'DATS', 'BNIX', 'ARTNA', 'TCBS', 'EUCRU', 'HMCOU', 'MTRX', 'ENVX',
       'INTEW', 'MSEX', 'HTLF', 'USAP', 'BCOW', 'LBPS', 'FUSN', 'ROIC', 'GLPI',
       'ARKOW', 'HWKN', 'OSTRU', 'NFLX', 'GTBP', 'RAIL', 'EVGO', 'BKEPP',
       'RMBS', 'SRCL', 'HOUR', 'LJAQ', 'AGLE', 'RNDB', 'BCSAU', 'NCACU',
       'MYNZ', 'FWRG', 'ROCG', 'DTOCU', 'RPD', 'MRAI', 'HMST', 'PCX',
       'VAXX', 'EXEL', 'SVFAU', 'JG', 'CTRN', 'TALS', 'WSBC', 'SCPL',
       'ALT', 'TBCPU', 'ARBEW', 'SRRK', 'CDAQW', 'MXCT', 'VMAR', 'OHPA',
       'MSBI', 'PWFL', 'CCSI', 'PDEX', 'CHUY', 'TMUS', 'METX', 'SSBI',
       'PSTX', 'DLTR', 'NEWT', 'FA', 'CFBK', 'DICE', 'MATW', 'COLB',
       'IREN', 'CRUS', 'FISV', 'BLI', 'CERN', 'NBST', 'LPLA', 'EQOS',
       'MINM', 'DGNU', 'BPTS', 'GAMCU', 'SMIHU', 'TBK', 'PMCB', 'NERV',
       'ARCC', 'DBX', 'CCNE', 'PBAXU', 'CREC', 'AMSF', 'CNTX', 'TRMD',
       'OMEG', 'LIAN', 'ASPAU', 'JOBS', 'GSKY', 'PLAB', 'INCR', 'ITRM',
       'SNT', 'BLUE', 'VINC', 'NTIC', 'OPRT', 'MGNI', 'ORGN', 'RNERW',
       'LIDR', 'RCM', 'MOFG', 'MNSB', 'FTEK', 'CNFR', 'LUXA', 'OPTN',
       'UXIN', 'NATH', 'MIRM', 'BHACU', 'KRNLU', 'TOUR', 'TIOAU', 'XTLB',
       'GAME', 'INSM', 'NAUT', 'RLMD', 'ATXI', 'LEGA', 'NTCT', 'MTBC',
       'UFPI', 'SHCR', 'PNFPP', 'JVA', 'ANAB', 'ASYS', 'AMD', 'CYAN',
       'SY', 'LBRDP', 'NAVI', 'TEAM', 'ISO', 'VRCA', 'DKDCA', 'MCAG',
       'WDFC', 'BBIO', 'ADV', 'AFBI', 'JCS', 'BTWN', 'YVR', 'GENC',
       'CVAC', 'GSEV', 'SFBC', 'DCTH', 'BPACU', 'MCFT', 'GRVY', 'NVTS',
       'SPRC', 'KTTA', 'KRTX', 'DWACW', 'ROSE', 'FGEN', 'CABA', 'ATVI',
       'EGAN', 'GLBLU', 'CPSI', 'GIACU', 'AMTX', 'NLSP', 'APPH', 'HTOOW',
       'GLHA', 'EVOJU', 'SCOAU', 'HCAT', 'ACNB', 'RILYL', 'SNDL', 'LRMR',
       'MRSN', 'PCB', 'FRLAU', 'GRAY', 'FFBC', 'AFYA', 'CJJD', 'MAR',
       'BANR', 'VCTR', 'CCTS', 'SMED', 'MRUS', 'NXGL', 'ATEX', 'ACTG',
       'DHCA', 'CGNT', 'AVAV', 'NYMTM', 'DHCAU', 'BCACU', 'POWRU', 'YNDX',
       'UNAM', 'QK', 'VSAC', 'PCSA', 'PPHPU', 'LGO', 'LIQT', 'ZCMD',
       'COST', 'BYTS', 'NTGR', 'AUVIP', 'NXGN', 'BIOX', 'DKNG', 'HDSN',
       'MDWD', 'HYZN', 'AUTO', 'RAM', 'TPTX', 'GP', 'BLTS', 'BTRS',
       'TGTX', 'GNFT', 'MDXG', 'FRON', 'HCNEU', 'RTLR', 'AEHAU', 'MOTS',
       'KELYA', 'ALLT', 'QRHC', 'AMRN', 'BOKF', 'HCARU', 'PAYO', 'TW',
       'ANIP', 'FFIV', 'CREG', 'TXMD', 'FMIVU', 'EBAC', 'DTIL', 'MSDAU',
       'LBTYA', 'FAT', 'FCCO', 'SRDX', 'BLNG', 'ACRS', 'NPCE', 'AUID',
       'CTIB', 'AREB', 'SXTC', 'TATT', 'AUBN', 'WRLD', 'PYCR', 'EWTX',
       'HELE', 'CHSCM', 'SPKB', 'COOLU', 'CHK', 'ZYXI', 'CDMO', 'RGC',
       'GOOD', 'BRKHU', 'CCAIU', 'AVGR', 'CADL', 'TBBK', 'KRNY', 'ZENV',
       'OCUP', 'GIW', 'AURA', 'ZT', 'MELI', 'CRSP', 'SZZLU', 'ZIVO',
       'EWBC', 'REKR', 'NRBO', 'SRTS', 'CIZN', 'NTES', 'CMPO', 'PYR',
       'KALU', 'PLL', 'CMCT', 'THACU', 'WISH', 'RBBN', 'AKBA', 'PANA',
       'ESSA', 'FATPW', 'CLLS', 'HLTH', 'PLBC', 'MEACU', 'TIL', 'JAN',
       'TOMZ', 'PRPO', 'DRRX', 'AMAL', 'BTAI', 'OMQS', 'PLMI', 'IKNA',
       'INSG', 'DCRD', 'CLAY', 'OEPW', 'MCAFU', 'CSTR', 'HYFM', 'CMPR',
       'SKYA', 'SOHOB', 'SOVO', 'GSIT', 'NBN', 'PERI', 'EJH', 'PGC',
       'ROCC', 'SVNAU', 'HLAH', 'RVAC', 'RUTH', 'SANB', 'PFTAU', 'ETON',
       'INSE', 'EQIX', 'SMBK', 'DSGX', 'ARYE', 'BKSC', 'ATLCP', 'ONVO',
       'WEJO', 'BRIVU', 'ORGS', 'PLPC', 'LCAHU', 'RNW', 'ACGLN', 'CMPX',
       'MOVE', 'SFM', 'FRGAP', 'ODP', 'BMEA', 'PPC', 'DOOO', 'GBRG',
       'GNAC', 'BCSA', 'AUDC', 'LYLT', 'ENJY', 'IMOS', 'CSQ', 'IPVI',
       'GIFI', 'ALPN', 'ESLT', 'BSRR', 'TXG', 'HCNE', 'MLKN', 'AAOI',
       'MIGI', 'SGHT', 'CPSH', 'NRC', 'RICO', 'FATBP', 'CLAR', 'SMLR',
       'REGI', 'BRPM', 'OPOF', 'KRUS', 'MCAGU', 'HOWL', 'PAX', 'TSVT',
       'BGCP', 'ARTA', 'CAN', 'SELB', 'AVAC', 'HAIN', 'SURG', 'SMMT',
       'SILC', 'RNST', 'MRCY', 'HST', 'SATS', 'HUBG', 'SBNY', 'AKUS',
       'PIRS', 'BPOP', 'SUMO', 'TWLVU', 'BLCT', 'VVOS', 'CELUW', 'CLBT',
       'CSSEP', 'NYMX', 'CVCY', 'ARDX', 'MBIN', 'SHC', 'NICK', 'DKDCU',
       'MGYR', 'MTBCP', 'CRECW', 'UAL', 'INKA', 'ARAV', 'UTME', 'QRTEB',
       'VMGA', 'LYL', 'AGRIW', 'SAVA', 'DXYN', 'SCHL', 'SLAB', 'ELSE',
       'JAKK', 'ERIC', 'WTW', 'AHPAU', 'NVCR', 'VNDA', 'NPABU', 'PCOM',
       'ETACU', 'MNSBP', 'BPRN', 'EVBG', 'QRTEA', 'XGN', 'PAAS', 'PCXCU',
       'SIEB', 'CRESY', 'MITA', 'WVE', 'CG', 'UPST', 'QIPT', 'RETA',
       'NLOK', 'DPCSU', 'ATHA', 'CAMP', 'OLED', 'MBTCU', 'EVLO', 'XRAY',
       'KALA', 'RBKB', 'UNTY', 'HALO', 'FBRX', 'SEED', 'UTHR', 'ADER',
       'TRIN', 'ATHE', 'HCKT', 'CFFN', 'GLNG', 'PAYA', 'NCTY', 'RLYB',
       'LUCD', 'UMPQ', 'ARVN', 'PSNL', 'JAMF', 'XM', 'RUSHA', 'DXCM',
       'URGN', 'IGNY', 'WNEB', 'ARBGU', 'TGAA', 'ROOT', 'KTRA', 'OSS',
       'CDAK', 'CLSD', 'RPTX', 'FFBW', 'TBCP', 'GTPB', 'KRMD', 'UONE',
       'GOOGL', 'SBFG', 'SMSI', 'PMTS', 'BITF', 'ZYNE', 'TSEM', 'AY',
       'SLNG', 'AMTB', 'OBSV', 'ALTU', 'TCAC', 'VFF', 'WAFD', 'EDRY',
       'PESI', 'WLDN', 'HSON', 'EJFAU', 'CCRN', 'LMAT', 'COGT', 'AGFY',
       'IMTX', 'SLHG', 'THRX', 'SCYX', 'IMBI', 'CMMB', 'ITQRU', 'ASPC',
       'DRMA', 'IRTC', 'SKIN', 'ESACU', 'SNRHU', 'BPMC', 'JD', 'ONEW',
       'DPCS', 'HPLTU', 'DOGZ', 'POAI', 'CYAD', 'CVLT', 'NISN', 'GO',
       'CTMX', 'CDW', 'HYPR', 'CCNEP', 'BCML', 'LGIH', 'DGLY', 'LCA',
       'RADI', 'AZ', 'OCFC', 'HITI', 'AVNW', 'TZPSU', 'MDRX', 'RDVT',
       'GROM', 'FOUNW', 'PASG', 'MORN', 'BLTSU', 'KRNL', 'LGTOU', 'VIRI',
       'UBOH', 'CYXT', 'CLMT', 'PCTTU', 'AVXL', 'FRTA', 'NYMTL', 'CSTE',
       'GPAC', 'CLNN', 'RANI', 'PNTG', 'NRIM', 'UPLD', 'SBCF', 'PYXS',
       'GLAD', 'ZNGA', 'TPBAU', 'CLPT', 'SMBC', 'LEE', 'HIMX', 'BANF',
       'FSLR', 'OXLCO', 'REE', 'ROST', 'MPB', 'SNBR', 'PRVB', 'UTAAU',
       'OXBRW', 'FISI', 'JRVR', 'PLUG', 'ADSE', 'PNBK', 'THAC', 'OCC',
       'RCHG', 'NOVT', 'TSRI', 'BATRA', 'LECO', 'AREC', 'SPLK', 'NCNO',
       'AFIB', 'DNAD', 'OHAA', 'LI', 'RGEN', 'RILY', 'FREE', 'CIIGU',
       'GATEW', 'CDK', 'HURC', 'RUN', 'JRSH', 'BRKR', 'TTGT', 'PBLA',
       'DMRC', 'GH', 'ZEAL', 'CGTX', 'NTNX', 'UFPT', 'CUTR', 'ITIC',
       'VIEWW', 'WORX', 'HOFT', 'SKYW', 'NKLA', 'NMTC', 'JACK', 'AGNCN',
       'BASE', 'MTP', 'PPHP', 'JAGX', 'NVDA', 'VWTR', 'CSBR', 'VIR',
       'GSAQU', 'SEDG', 'MTRYU', 'FANH', 'ATRC', 'ASMB', 'PRLHU', 'RGLS',
       'MNDO', 'LFMDP', 'WHLM', 'DHIL', 'LFMD', 'JZXN', 'DRUG', 'GRAB',
       'VCXA', 'ENTF', 'WVVIP', 'TMCI', 'ICUI', 'RUN', 'NTRSO', 'GENE',
       'HQI', 'PVBC', 'BNFT', 'DDI', 'ADOC', 'ULTA', 'LVAC', 'ECOR',
       'COCP', 'STRT', 'OCFCP', 'RVNC', 'MHUA', 'CINC', 'RPID', 'IMRN',
       'JJSF', 'ASML', 'PHIO', 'DH', 'JBSS', 'TPIC', 'TMDI', 'HCIIU',
       'TCBX', 'DAVEW', 'BLBD', 'BANX', 'SBNY', 'FIBK', 'CRBU', 'TRDA',
       'HSAQ', 'FICVU', 'GHRS', 'VIGL', 'ROLL', 'ATRA', 'PXSAP', 'OXLCP',
       'PAHC', 'TXN', 'NPAB', 'VTIQU', 'PHUN', 'NDRA', 'LSPRU', 'SMAPU',
       'IOVA', 'CYN', 'PNRG', 'BGRY', 'IQ', 'PRTS', 'JOFFU', 'LVRAU',
       'KNSA', 'ATRO', 'XRTX', 'GLG', 'HCIC', 'BIOSU', 'LSBK', 'OFIX',
       'ASO', 'RPAY', 'PHAS', 'TTWO', 'INTC', 'ETSY', 'AADI', 'FMIV',
       'ARTL', 'NEPT', 'APEN', 'SOPA', 'IMAQ', 'FAST', 'NXPI', 'ENTFW',
       'SBTX', 'ENTFU', 'NXPL', 'WTER', 'TTEK', 'TEKK', 'IMTE', 'LIBYW',
       'WFRD', 'SFIX', 'PENN', 'CPAA', 'SRPT', 'HSKA', 'RVPH', 'BAND',
       'APLT', 'PCTI', 'RDWR', 'GLMD', 'XOMA', 'SEAT', 'MDGS', 'CRDL',
       'SISI', 'EXPD', 'MCAEU', 'CMTL', 'PINC', 'ADALU', 'BYFC', 'LMST',
       'ENOB', 'ENTG', 'COUP', 'BMRN', 'BENE', 'BBQ', 'SWSS', 'ZEUS',
       'CTRE', 'EPZM', 'AMZN', 'SLCR', 'SPPI', 'DRAYU', 'TFFP', 'CBAY',
       'FRBA', 'GURE', 'NYMTN', 'RMCF', 'HAFC', 'SYTA', 'SONO', 'ENERU',
       'WIMI', 'FNCH', 'ROCGU', 'INDB', 'RCLFU', 'FTNT', 'SRAX', 'HCII',
       'GSBC', 'NKTR', 'BLCM', 'GLEE', 'RXRA', 'INFI', 'ADP', 'SLHGP',
       'PPBT', 'HTIA', 'RNST', 'NOVN', 'FORR', 'LOOP', 'FULC', 'TSC',
       'ZG', 'TBNK', 'FIACW', 'AEY', 'PCYO', 'SWAGU', 'CIGI', 'CNTG',
       'USCB', 'WKME', 'HHR', 'PLAY', 'DAKT', 'IMXI', 'EXPI', 'LJAQU',
       'GOOG', 'BSFC', 'SP', 'GFGDU', 'EYPT', 'TMC', 'SJ', 'SPFI', 'CRSR',
       'CZWI', 'LMAOU', 'BOLT', 'HUIZ', 'BATRK', 'SHCAU', 'FTVIU', 'HARP',
       'ANGN', 'PBIP', 'RNER', 'CBIO', 'NURO', 'AEAEW', 'PONOU', 'GIAC',
       'NVIV', 'RKDA', 'CCAI', 'TETC', 'CHEK', 'BHAT', 'SHQA', 'FBIOP',
       'QLI', 'TPBA', 'BNTC', 'BCLI', 'SNSE', 'JUGGU', 'DORM', 'FUNC',
       'SGMS', 'PRGS', 'CFLT', 'BSGAU', 'FFHL', 'ARTAU', 'BCPC', 'PATI',
       'CNOB', 'RICOU', 'HGEN', 'CERS', 'GAIA', 'FFIE', 'PRCH', 'GMDA',
       'TMKRU', 'JFU', 'GOSS', 'CAPR', 'CELU', 'LGVCU', 'AACI', 'MTLS',
       'MFIN', 'CSWC', 'FRSX', 'HWELU', 'OTMO', 'ORTX', 'GAMC', 'FTVI',
       'TRIP', 'LSCC', 'PRQR', 'MRNA', 'HAYN', 'LILAK', 'PBYI', 'ESQ',
       'UHAL', 'RMR', 'AGGR', 'ABCM', 'NOTV', 'DLTH', 'LIVE', 'BKYI',
       'ORIC', 'ACT', 'RIOT', 'AIMC', 'VITL', 'BLZE', 'FCNCA', 'FREQ',
       'MIST', 'WLFC']
HOLDING = 0
TOTAL = 1
allList = test+train

# %%
SectorDict = {
    "Energy":"XLE","Technology":"XLK",
    "Communication Services":"XLC",
    "Consumer Staples":"XLP",
    "Health Care":"XLV",
    "Consumer Cyclical":"XLY",
    "Industrial":"XLI",
    "Utilities":"XLU",
    "Materials":"XLB",
    "Financial":"XLF",
    "Real Estate":"XLRE"}
sectorDfList = []
for sector in SectorDict.values():
    sectorDfList.append(pd.read_pickle("stockData/sectorCharts/"+sector+".pkl"))
goodSectorDf = sectorDfList[0].drop(['open','high','low','adjclose','close','ticker','volume','percent','MA30','MA30Slope','RS'],axis=1)
goodSectorDf['Sectors'] = [[] for _ in range(len(goodSectorDf))]
goodSectorDf.index = sectorDfList[0].index
index = 0
for date in sectorDfList[0].index:
    listOfSector = []
    for df in sectorDfList:
        try:
            #print(df.at[date,'MA30Slope'],df.at[date,'RS'])
            #!!!!!!!! or for new params
            #!!!!!!!!
            #!!!!!!!!
            #!!!!!!!!
            if  df.at[date,'MA30Slope'] > 0.992549883242513 and df.loc[date,'RS'] > -0.3044455098712273:
                if df.at[date,'close'] > df.at[date,'MA30']:
                    #print(df.at[date,'ticker'])
                    listOfSector.append(df.at[date,'ticker'])
        except: 
            pass
        # print(listOfSector)
    goodSectorDf.iat[index,0] = set(listOfSector)
    index = index + 1
removeList = []
for ticker in allList:
    try:
        df = getStage(ticker,[0.03361077383204303, 1.7466372328111242, -0.08498841770875612, 0.926192276854965, 1.1764676012556523, 1.1405501342698643, 0.8517616225271734, 0.8691969716399011, 1.268490629719207, 1.0013386634337298, 0.07551020458494859, 0.9489349345040117, 0.996709764664632, 0.9485725801058837, 0.9857019510456804],goodSectorDf)
        if df.empty:
            removeList.append(ticker)
    except:
        removeList.append(ticker)
print(removeList)
# Out:
# ['WWACW', 'GFED', 'SLGCW', 'HGSH', 'CDAQW', 'FRTA']

# %%
for ticker in removeList:
    if ticker in test:
        test.remove(ticker)
    if ticker in train:
        train.remove(ticker)
    if ticker in allList:
        allList.remove(ticker)

# %%
def calculateGroupReturn(list):
    monthlyReturn = pd.read_pickle("transactionTemplate.pkl")
    monthlyReturn = monthlyReturn.resample('M').mean()
    monthlyReturn.index = monthlyReturn.index.strftime("%Y:%m")
    currentColumn = -1
    for symbol in list:
        if symbol in monthlyReturn.columns:
            continue
        try:
            df = pd.read_pickle("stockData/nyseNasdaq/"+symbol+".pkl")
        except:
            print(symbol)
            continue
        if not (df['close'] != 0).all() or df.empty:
            if df.empty:
                print(symbol)
            continue
        monthlyReturn[symbol] = 1
        currentColumn += 1
        monthCheck = df.index[0].strftime("%Y:%m")
        lastPrice = df.iat[0,0]
        initialPrice = df.iat[0,0]
        for index, element in df.iterrows():
            if (index.strftime("%Y:%m") != monthCheck):
                if (initialPrice == 0): continue
                if (lastPrice / initialPrice >= 1.01 and lastPrice / initialPrice < 2):
                    rowNumber = monthlyReturn.index.get_loc(index.strftime("%Y:%m"))
                    monthlyReturn.iat[rowNumber, currentColumn] = (lastPrice / initialPrice)
                initialPrice = element[0]
                lastPrice = element[0]
                monthCheck = index.strftime("%Y:%m")
            lastPrice = element[0]
    return monthlyReturn

# %%
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning) 
listOfDf = calculateGroupReturn(allList)
ratio = [1,1]
for i in range(2):
    if i == 0:
        l = test
    else:
        l = train
    index = 0
    while index != len(l):
        if l[index] not in listOfDf.columns:
            l = np.delete(l, index)
        else:
            index += 1
    for index, element in listOfDf[l].iterrows():
        #print(element.to_list())
        listOfStockRet = element.to_list()
        while 1.0 in listOfStockRet:
            listOfStockRet.remove(1.0)
        if len(listOfStockRet) != 0:
            ratio[i] = ratio[i] * np.mean(listOfStockRet)     
ratio[1] = ratio[1] / ratio[0]
ratio[0] = 1.0
print(ratio)
# Out:
# [1.0, 0.566674529183376]

# %%
def evalFit(params, tickers, goodSectorDf):
        transactionFit = pd.read_pickle("transactionTemplate.pkl")
        transactionFit['holding'] = np.empty((len(transactionFit), 0)).tolist()
        #print("Reach #1")
        for symbol in tickers:
            df = getStage(symbol,params,goodSectorDf)
            buyDf = pd.read_pickle('stockData/nyseNasdaq/'+symbol+'Buy.pkl')
            inStage = False
            buyTwice = False
            if df.empty:
                continue
            if buyDf['open'].eq(0).any().any():
                continue
            for index, element in df.iterrows():
                open = 0
                monday = index + timedelta(3)
                i = transactionFit.index.get_loc(index)
                if element.Stage == "Stage 2" or element.Stage == "Buy":
                    if monday in buyDf.index:
                        open = buyDf.at[monday,'open']
                    else:
                        open = element.close
                    #delete
                    transactionFit.iat[int(i),HOLDING].append((symbol,open,0))
                    if buyTwice:
                        transactionFit.iat[i, HOLDING].append((symbol,open,0))
                    if element.Stage == "Buy" and inStage:
                        transactionFit.iat[i, HOLDING].append((symbol,open,0))
                        buyTwice = True
                    inStage = True
                    continue
                if "Sell" == element.Stage[0:4]:
                    if monday in buyDf.index:
                        open = buyDf.at[monday,'open']
                    else:
                        open = element.close
                    transactionFit.iat[i, HOLDING].append((symbol,open,-1))
                    if buyTwice:
                        transactionFit.iat[i, HOLDING].append((symbol,open,-1))
                    inStage = False
                    buyTwice = False
        #print("Reach #2")
        total = 100
        first = True
        transactionFitCopy = transactionFit
        transactionFitCopy['total'] = 0
        transactionFitCopy.to_csv("onlyShare.csv")
        #print("Reach #3")
        for index, element in transactionFitCopy.iterrows():
            indexNum = transactionFitCopy.index.get_loc(index)
            if first:
                first = False
                transactionFitCopy.iat[indexNum,1] = 100
                # print(i,transactionFitCopy.iat[i,1],"#1")
                continue
            if len(element.holding) == 0:
                transactionFitCopy.iat[indexNum,1] = transactionFitCopy.iat[indexNum-1,1]
                # print(i,transactionFitCopy.iat[i,1],"#2")
                continue
            else:
                prevData = transactionFitCopy.iat[indexNum-1, 0]
                if len(prevData):
                    total = 0
                    removeList = []
                    close = 0
                    for i in range(len(prevData)):
                        for j in range(len(element.holding)):
                            if element.holding[j][0] == prevData[i][0]:
                                close = element.holding[j][1]
                                if element.holding[j][2] == -1:
                                    removeList.append(element.holding[j])
                                break
                        total += close*prevData[i][2]
                    transactionFitCopy.iat[indexNum,1] = total
                    # print(i,transactionFitCopy.iat[indexNum,1],"#3")
                    for delete in removeList:
                        if delete in element.holding:
                            element.holding.remove(delete)
                else:
                    transactionFitCopy.iat[indexNum,1] = transactionFitCopy.iat[indexNum-1,1]
                    # print(i,transactionFitCopy.iat[i,1],"#4")
            if len(element.holding):
                allocation = total/len(element.holding)
            for i in range(len(element.holding)):
                element.holding[i] = (element.holding[i][0],element.holding[i][1],allocation/element.holding[i][1])
        stockHolding  = 0
        transactionFitCopy.to_csv("estimatorTest.csv")
        for i in transactionFitCopy.iterrows():
            stockHolding += len(i[1]['holding'])
        if stockHolding/(transactionFitCopy.shape[0])<(len(tickers)/1000) or transactionFitCopy.iat[-1,TOTAL]<=100:
            print(stockHolding)
            print(transactionFitCopy.iloc[-1]['total'])
            return -1
        return transactionFitCopy.iloc[-1]['total']

# %%
def evalReturn(params,tickerList):
    now = datetime.now()
    now = now.strftime("%Y-%m-%d-%H:%M")
    transaction = pd.read_pickle("transactionTemplate.pkl")
    transaction['holding'] = np.empty((len(transaction), 0)).tolist()
    SectorDict = {
    "Energy":"XLE","Technology":"XLK",
    "Communication Services":"XLC",
    "Consumer Staples":"XLP",
    "Health Care":"XLV",
    "Consumer Cyclical":"XLY",
    "Industrial":"XLI",
    "Utilities":"XLU",
    "Materials":"XLB",
    "Financial":"XLF",
    "Real Estate":"XLRE"}
    sectorDfList = []
    for sector in SectorDict.values():
        sectorDfList.append(pd.read_pickle("stockData/sectorCharts/"+sector+".pkl"))
        goodSectorDf = sectorDfList[0].drop(['open','high','low','adjclose','close','ticker','volume','percent','MA30','MA30Slope','RS'],axis=1)
        goodSectorDf['Sectors'] = [[] for _ in range(len(goodSectorDf))]
        goodSectorDf.index = sectorDfList[0].index
        index = 0
        for date in sectorDfList[0].index:
            listOfSector = []
            for df in sectorDfList:
                try:
                    # print(df.at[date,'MA30Slope'],df.at[date,'RS'])
                    # print(individual[0][9],individual[0][10])
                    if  df.at[date,'MA30Slope'] > params[9] and df.at[date,'RS'] > params[10]:
                        if df.at[date,'close'] > df.at[date,'MA30']:
                            # print(df.at[date,'ticker'])
                            listOfSector.append(df.at[date,'ticker'])
                except: 
                    pass
                # print(listOfSector)
            goodSectorDf.iat[index,0] = set(listOfSector)
            index = index + 1
    result = evalFit(params,tickerList,goodSectorDf)
    return result

# %%
params = [0.9541367404767006, 1.1711855919824754, 0.3234811779827891, 1.0480872813002329, 1.0866838780973604, 1.0020752138164395, 0.9187896854398971, 0.8002092301235872, 1.3569632641884322, 0.9890583327350672, -0.2451178101795499, 0.884918514683724, 0.9938597434829046, 0.8568586434484793, 0.9842870131231478]
print(evalReturn(params,test))
print(evalReturn(params,train))
# Out:
# 58240.42632567776
# 77781.23495914286

# %%
params = [0.5246636931097627, 2.014031456005862, 0.34980206873499997, 0.9542774120430266, 1.2643916262401744, 1.2869933122703707, 0.9106987414558653, 1.0200821554493262, 1.2091932751681138, 0.9951663566011892, -0.23493304580222474, 0.9400037283075476, 0.9981975235463614, 0.8752036990435879, 0.9681606091692291]
print(evalReturn(params,test))
print(evalReturn(params,train))
# Out:
# 8329.166821177949
# 9360.406267256423

# %%
## IMPORTS
import numpy as np
import timeit
start = timeit.default_timer()
from datetime import datetime, date
from stage import getStage, fullPrint
import pandas as pd
from datetime import timedelta
import pickle
import yahoo_fin.stock_info as yf
import warnings

# %%
now = datetime.now()
transactionTemplate = yf.get_data('AAPL', start_date="1995-01-06",end_date= now, index_as_date = True).drop(['open','high','low','close','adjclose','volume','ticker'],axis=1)
transactionTemplate['Dates'] = pd.to_datetime(transactionTemplate.index)
transactionTemplate = transactionTemplate[transactionTemplate['Dates'].dt.weekday == 4]
transactionTemplate = transactionTemplate.drop('Dates', axis = 1)
transactionTemplate = transactionTemplate[~transactionTemplate.index.duplicated()]
transactionTemplate.to_pickle("transactionTemplate.pkl")

# %%
test = ['MLAIU', 'ZNTEU', 'AVTE', 'ELSE', 'PTPI', 'COMSP', 'ABCB', 'REKR', 'CDAQ', 'LFTRU', 'ARCC', 'CAAS', 'BSQR', 'VSAT', 'BCAC', 'ACIW', 'LGACU', 'GYRO', 'TOPS', 'ATER', 'SBNY', 'CLOV', 'OEPWU', 'PCRX', 'LILM', 'ACER', 'HUBG', 'VRTX', 'BFI', 'MOR', 'KRMD', 'ZTAQU', 'JAQC', 'HYW', 'SMIH', 'FREQ', 'APTMU', 'BBIO', 'NEPH', 'JAGX', 'IBCP', 'ONDS', 'SNRHU', 'OGI', 'BXRX', 'FRONU', 'EVLV', 'INM', 'OXUSU', 'NRBO', 'ROCC', 'LX', 'XFINU', 'EVOK', 'CYXT', 'HIII', 'BOKF', 'ZLAB', 'RMR', 'VC', 'KINZU', 'NSIT', 'SILC', 'CNXN', 'CIIG', 'ALOT', 'PXS', 'LGTOW', 'AAPL', 'VREX', 'SPRC', 'UEIC', 'RMGCU', 'APWC', 'NYMTM', 'SMTI', 'MKTX', 'GGAL', 'FCCO', 'CMAX', 'ASPC', 'QTNT', 'LPRO', 'BNTX', 'TCACU', 'AMRK', 'NYXH', 'WIRE', 'WDAY', 'PRTS', 'FSV', 'BHF', 'VWEWW', 'KOSS', 'SNFCA', 'FFNW', 'SASR', 'MICT', 'IDRA', 'RESN', 'UFCS', 'ENERW', 'HQI', 'NEWT', 'TBK', 'FATPU', 'MNDO', 'AGLE', 'SURG', 'LOTZ', 'HLXA', 'LTRPB', 'BIIB', 'JAKK', 'CNSP', 'SINT', 'AADI', 'VRSK', 'JYNT', 'CRVS', 'TMDI', 'SWET', 'SIBN', 'XRX', 'WILC', 'SBAC', 'RNW', 'DAOOU', 'CMCSA', 'ZWRK', 'NATR', 'SLM', 'SSBI', 'ASML', 'ALCO', 'AIRG', 'ENTX', 'JD', 'SHACU', 'PMGM', 'SWKS', 'MDGS', 'VTNR', 'GATE', 'HYAC', 'MAPS', 'ABOS', 'AVNW', 'CRZN', 'ABVC', 'OFS', 'ADBE', 'OVBC', 'HEES', 'OHPAU', 'VITL', 'DTOCU', 'ARBEW', 'BTBD', 'EXEL', 'LEVL', 'ENERU', 'TAYD', 'BEAT', 'TLMD', 'SRGA', 'CMTL', 'MRAI', 'VAXX', 'TYRA', 'SNPS', 'GOBI', 'DUNE', 'ODFL', 'ABNB', 'AKUS', 'BTWNU', 'CPAA', 'FNCB', 'SEER', 'CSII', 'BWB', 'EGLX', 'HOLI', 'AGRI', 'CSTL', 'ARCT', 'SPLK', 'BROG', 'AEZS', 'AMCX', 'CLVRW', 'AMAOU', 'USCTU', 'EXPD', 'EBTC', 'LJPC', 'BUSE', 'VVOS', 'LCNB', 'ACNB', 'GLLIU', 'TCRT', 'HYMC', 'CYCN', 'LNSR', 'KPLT', 'HRZN', 'RXRAU', 'BNSO', 'AQMS', 'NOVN', 'GLYC', 'JBSS', 'SZZLU', 'BKCC', 'NWSA', 'ANGI', 'LITE', 'BWACU', 'PKBK', 'VTYX', 'WNW', 'GRAB', 'DAKT', 'SWAGU', 'RPD', 'SANBU', 'WRAP', 'LHAA', 'GLPI', 'DGICB', 'SILK', 'PHCF', 'TBLT', 'MXCT', 'BNNRU', 'VENA', 'LASR', 'ARVL', 'OTEX', 'PI', 'MDWT', 'MSFT', 'EBMT', 'CING', 'ERES', 'SIMO', 'LAZR', 'AAL', 'NVCR', 'DDOG', 'BZUN', 'EIGR', 'MTACU', 'VELO', 'VLYPP', 'FATPW', 'CG', 'SPRO', 'CNDT', 'IIIV', 'DXYN', 'MITA', 'RVAC', 'CRSR', 'FFIC', 'ULH', 'APM', 'DHCA', 'PRVB', 'ITRI', 'PEBO', 'BIOC', 'IMVT', 'VS', 'HYACU', 'EYE', 'CRTD', 'DAIO', 'DWACW', 'VMAR', 'DOMO', 'CELUW', 'WIMI', 'CLPS', 'SDIG', 'FTNT', 'CRKN', 'OBT', 'SLNHP', 'SLAMU', 'SEIC', 'AVPT', 'TCDA', 'UIHC', 'AMSF', 'SWETU', 'WSC', 'ETON', 'SOHOB', 'LAND', 'KRUS', 'GANX', 'AZPN', 'RNERU', 'PEPL', 'DCOM', 'NPABU', 'ADTH', 'HEAR', 'HCICU', 'MAAQ', 'FUTU', 'PSNL', 'BSVN', 'ACTD', 'BYFC', 'CATC', 'BCACU', 'ACBAU', 'GLTO', 'KERN', 'BPOP', 'CDW', 'ELEV', 'DFFN', 'ACHL', 'BJDX', 'GSKY', 'CADL', 'SSNT', 'CTMX', 'SAFM', 'GWGH', 'ESACU', 'OPCH', 'PLMIU', 'NYMTZ', 'GIACU', 'LIVN', 'CAPR', 'WDC', 'MKTW', 'SABS', 'TBCPU', 'INTA', 'OCCI', 'MIRM', 'WKEY', 'PROC', 'QUMU', 'AVHI', 'HGEN', 'LNTH', 'ELYM', 'ONB', 'SHCA', 'TPBA', 'BTRS', 'FUND', 'LIQT', 'GSBC', 'BSET', 'HHGC', 'ADPT', 'SCSC', 'CCTSU', 'DENN', 'HORIU', 'LIBY', 'PPHP', 'SLAB', 'PLRX', 'RPTX', 'BITF', 'HTLF', 'HYMCL', 'LVACU', 'SOVO', 'MYNA', 'SAFT', 'GAME', 'TCRX', 'SKYAU', 'SGA', 'NVVE', 'PHAS', 'RUBY', 'FULTP', 'EPAY', 'VBLT', 'COHR', 'AINV', 'RCAT', 'HSDT', 'SMAP', 'EDAP', 'SMPL', 'CAMT', 'STAB', 'GROW', 'ONCR', 'TUGCU', 'ANZUU', 'IINN', 'CIH', 'SMBK', 'WKME', 'RXRA', 'OTLY', 'LITM', 'HIHO', 'UCBI', 'BCOV', 'SND', 'KRYS', 'USAK', 'EXPE', 'AXSM', 'OMER', 'WKSP', 'MACUU', 'BLCM', 'PRCT', 'FLNC', 'BWMX', 'SMAPU', 'CORT', 'PLAY', 'MDWD', 'KLDO', 'OKTA', 'ENTG', 'OCCIO', 'TNGX', 'LVRAU', 'GGGV', 'HCNEU', 'SVNAU', 'TROW', 'TWCBU', 'ALLK', 'FRBK', 'FTCV', 'OSUR', 'BBIG', 'ALORW', 'TIGR', 'AEP', 'MFIN', 'ROCK', 'RPID', 'MILE', 'HHS', 'ALDX', 'ANY', 'CIDM', 'FANG', 'CVAC', 'RMBL', 'GMBL', 'ARAY', 'SDAC', 'VELOU', 'DCBO', 'MSDAU', 'GAMC', 'ODP', 'GNACU', 'PIIIW', 'BLBD', 'VERA', 'SBLK', 'GPP', 'REGN', 'FVAM', 'TRS', 'MDIA', 'TRMK', 'AURC', 'ICCM', 'AURA', 'IIIIU', 'APCX', 'CPHC', 'MRSN', 'TCPC', 'TRHC', 'AUB', 'LUNA', 'CINF', 'AFCG', 'LBRDP', 'RKDA', 'YORW', 'PCTI', 'VIR', 'SPKBU', 'PLXS', 'MTLS', 'DLHC', 'SIER', 'GTLB', 'AEMD', 'SYNH', 'CHPMU', 'YI', 'CLVR', 'SNCR', 'EBAC', 'JUPW', 'EPHYU', 'INTC', 'MANH', 'INSE', 'GTAC', 'BSBK', 'CUBA', 'DFH', 'FMIV', 'RMBL', 'TSCO', 'FTDR', 'LMPX', 'BMRC', 'CLSN', 'VINC', 'WOOF', 'JBLU', 'GDEV', 'ACQR', 'TRDA', 'UONE', 'FTHM', 'EYES', 'FISV', 'MEOAU', 'GLLI', 'EVFM', 'DSACU', 'IBOC', 'SYNL', 'IDYA', 'AVCT', 'LKFN', 'INTEU', 'SHCAW', 'AEHAU', 'PLSE', 'MITC', 'AVAH', 'BMAQ', 'CFFN', 'REVE', 'AMRS', 'CWBC', 'LFVN', 'LEDS', 'NDLS', 'FOUN', 'UHAL', 'IKNA', 'FNVTW', 'HCWB', 'ONEW', 'MBCN', 'MTCR', 'VLCN', 'ISEE', 'FMBH', 'ROVR', 'CCOI', 'SOHO', 'SBUX', 'CERE', 'AVDL', 'KIRK', 'MELI', 'ICLK', 'GBT', 'COLM', 'FCNCA', 'AMOT', 'NTAP', 'PFHD', 'OXAC', 'ISSC', 'PT', 'RNER', 'CAR', 'ADOC', 'JMAC', 'SYRS', 'CITEU', 'AMGN', 'PESI', 'TWNK', 'MDRX', 'ALBO', 'OXLCO', 'VTIQU', 'LUXA', 'MGTX', 'CFRX', 'BYRN', 'STNE', 'HPK', 'ALGT', 'ADAP', 'SSAA', 'RLAY', 'VIVO', 'AZYO', 'NVTS', 'SPKAU', 'BPTS', 'DISH', 'CGEM', 'MNTX', 'RIVN', 'GRNQ', 'ABIO', 'SOPH', 'RSLS', 'MNOV', 'VEON', 'USCT', 'NSEC', 'BILI', 'KLAQ', 'IMUX', 'KOPN', 'NRSN', 'KTRA', 'PRPO', 'TIG', 'NEOG', 'DRAY', 'LSPRU', 'FSSIU', 'RAND', 'LITT', 'GGPIU', 'BSRR', 'BSKY', 'SLGC', 'SLRX', 'RYAAY', 'BIMI', 'LCAPU', 'DUOL', 'TCBIO', 'NLIT', 'DNLI', 'LOGC', 'OBSV', 'GWII', 'GLLIW', 'TGAA', 'ADERU', 'FHB', 'ARHS', 'FIAC', 'PMVP', 'PBIP', 'GRAY', 'BBGI', 'SNPX', 'MACK', 'WNEB', 'MTRY', 'FSEA', 'AREB', 'CMPS', 'BKEP', 'AMAL', 'ELDN', 'EVOJ', 'MAR', 'BIOL', 'CGBD', 'NYMTL', 'HTGM', 'PBAXU', 'GIIX', 'STRM', 'AVIR', 'THRN', 'PCAR', 'SENEA', 'OHAA', 'ALJJ', 'OCFCP', 'DMRC', 'LGAC', 'BLTS', 'FOXW', 'VBIV', 'TC', 'VERV', 'MDLZ', 'MCAA', 'LCA', 'PASG', 'LIVE', 'FSSI', 'TTMI', 'NRXPW', 'LOOP', 'CROX', 'GATEU', 'ITHX', 'HCDIP', 'NVFY', 'GMBT', 'BMAQU', 'LOV', 'CYTO', 'ONEM', 'MIST', 'APLS', 'GLSI', 'AFRM', 'KNSA', 'ROC', 'SANB', 'PERI', 'CNTQU', 'BMEA', 'TBCP', 'CLOEU', 'EAC', 'QIPT', 'CLDX', 'FSTR', 'MBTC', 'SOFI', 'PXSAP', 'FKWL', 'MRVI', 'HALO', 'PRTK', 'XPAXU', 'ACB', 'TACT', 'SSSS', 'ASTE', 'ESQ', 'ASPU', 'GXII', 'ADVM', 'NDRA', 'LTBR', 'RMNI', 'VHNAU', 'CPRX', 'SKYA', 'STXB', 'NTWK', 'UROY', 'AGEN', 'PRDO', 'CYN', 'DKDCA', 'KVHI', 'CNTX', 'NATH', 'JOUT', 'CCCC', 'HBANP', 'HBANM', 'GO', 'CLBK', 'TWCB', 'ABGI', 'WALDU', 'YVR', 'VLDR', 'FBNC', 'MRM', 'PCTY', 'QCOM', 'LABP', 'BCBP', 'PCYG', 'CVBF', 'DAVEW', 'IMGN', 'MEKA', 'STER', 'KIIIU', 'POAI', 'LVAC', 'TTCF', 'HTIA', 'GHACU', 'MDVL', 'DCPH', 'PANA', 'EXFY', 'TSBK', 'EQIX', 'TTD', 'RGLD', 'TAOP', 'ATVCU', 'ZNTE', 'AERC', 'PLBY', 'ACHV', 'JAMF', 'PNFPP', 'PRTH', 'FFHL', 'IMTE', 'ATHA', 'PPTA', 'DSAC', 'PLMI', 'DRIO', 'QCRH', 'HFWA', 'ZSAN', 'MGTA', 'ORTX', 'MTBCO', 'CHKP', 'VIVK', 'ECOL', 'AMST', 'IKT', 'HALL', 'TCOM', 'MCAG', 'EBAY', 'GBOX', 'QIWI', 'KIDS', 'WING', 'UNAM', 'EQRX', 'IMMX', 'RANI', 'ALPA', 'ROSEU', 'ALTO', 'HOLX', 'ORGS', 'FRLN', 'CAC', 'TTOO', 'OBLG', 'HOTH', 'FMIVU', 'GNAC', 'RDFN', 'CHTR', 'IIII', 'AVACU', 'ATCX', 'BPYPP', 'BLDE', 'TRST', 'BYTS', 'WATT', 'VISL', 'TZPSU', 'SRRA', 'AVCO', 'ASTC', 'UDMY', 'IBTX', 'NWFL', 'HAS', 'NYMT', 'MCAFU', 'BRKHU', 'MDRRP', 'BBQ', 'QUIK', 'IVAC', 'LGTO', 'HCAT', 'SDGR', 'ATNF', 'AEACU', 'OSS', 'WTMA', 'LNDC', 'HTOO', 'OTECU', 'BKSC', 'ILMN', 'FCEL', 'ZCMD', 'EHTH', 'HWKN', 'LESL', 'LXRX', 'EDTK', 'CENTA', 'SCAQ', 'AEAEW', 'WISH', 'PBPB', 'ERAS', 'NCTY', 'SMED', 'HTLFP', 'NBEV', 'RCMT', 'OFIX', 'XERS', 'GSEVU', 'LUMO', 'LTRY', 'FRPH', 'CHUY', 'PRAA', 'SMMF', 'OHPA', 'GFGDU', 'BHFAM', 'LQDT', 'LEGN', 'HURN', 'MYGN', 'OCUP', 'DGHI', 'CTSO', 'ATOS', 'ZT', 'CAKE', 'KTCC', 'ADES', 'BOOM', 'CIVB', 'WBA', 'TENX', 'DHHCU', 'FDMT', 'CLEU', 'SLCRU', 'ORPH', 'AGGR', 'RBCAA', 'OSPN', 'ITQRU', 'RDHL', 'TRMD', 'POWRU', 'VPCBU', 'EMCF', 'STRO', 'RLYB', 'LAKE', 'AMEH', 'CELZ', 'EM', 'ITI', 'BNR', 'RFIL', 'LUXAU', 'OPK', 'ARGUU', 'APPS', 'CSTR', 'RILYL', 'OMQS', 'BBLG', 'CSQ', 'TWIN', 'CCAP', 'GNSS', 'ISAA', 'CHSCM', 'IPAXU', 'RGEN', 'REPL', 'PWOD', 'SEVN', 'NYMX', 'SWIM', 'RZLT', 'CDAK', 'CELC', 'PCXCW', 'GLUE', 'TTSH', 'CDZIP', 'PRGS', 'LGSTU', 'LAAA', 'FAMI', 'NKLA', 'SKIN', 'ACQRU', 'ROOT', 'SBFM', 'WFCF', 'DWACU', 'ATRS', 'AROW', 'HAYN', 'VMEO', 'RBB', 'WYNN', 'KE', 'VOXX', 'PRLHU', 'ELMS', 'SIGI', 'BREZ', 'LILA', 'HUMA', 'CLRB', 'LION', 'LMAOU', 'BCAB', 'SRCE', 'KC', 'GASS', 'VRDN', 'BRIV', 'ITHXU', 'SGIIU', 'AAWW', 'ASLN', 'OLB', 'VQS', 'APTO', 'CLLS', 'BNIX', 'IEP', 'VRSN', 'CHNR', 'AKTX', 'BOSC', 'MYSZ', 'APACU', 'EQBK', 'ITQ', 'MDNA', 'ICHR', 'NCBS', 'KRNT', 'TTNP', 'CLAR', 'FOSL', 'RCRT', 'DILAU', 'ACLS', 'ADMP', 'RCKY', 'PATK', 'TBSAU', 'TMC', 'PRLD', 'UONEK', 'INKT', 'IOAC', 'TFSL', 'CDNS', 'HCDI', 'GOODN', 'LYL', 'ALTR', 'WWACW', 'ANNX', 'SIEN', 'EQOS', 'EVOL', 'EKSO', 'SCAQU', 'MGYR', 'GPCO', 'VORB', 'SBUX', 'IGIC', 'ALNA', 'MMLP', 'HEPS', 'SLAM', 'QSI', 'ISTR', 'SZZL', 'BRFH', 'FLWS', 'RETO', 'HCIC', 'NXST', 'HCP', 'KAIIU', 'CNFR', 'RAIN', 'ARQQ', 'TOI', 'BLDP', 'VCEL', 'ARBGU', 'AKAM', 'OPEN', 'MACA', 'KXIN', 'CSWI', 'ETACU', 'SWIR', 'GECC', 'ADIL', 'RBCN', 'CERS', 'WTFC', 'CTRN', 'ZIONO', 'OLLI', 'NVEE', 'AGNCO', 'IIVI', 'SABR', 'XBIO', 'SONN', 'LSBK', 'AMPH', 'LI', 'PFLT', 'USWS', 'AGRIW', 'HOOK', 'MSVB', 'GLPG', 'MCAEU', 'CLMT', 'MGPI', 'REVBU', 'CGC', 'DOOO', 'MU', 'GOCO', 'CARE', 'CENQ', 'ISIG', 'ESTA', 'GVP', 'VOD', 'ORLY', 'CNTA', 'LRCX', 'PPSI', 'ALAC', 'BHFAP', 'GBS', 'GRTS', 'KLAC', 'LQDA', 'OPGN', 'BLCT', 'UFPI', 'CSX', 'MRNS', 'PSEC', 'UNB', 'PUCKU', 'MUDS', 'GTACW', 'STOK', 'VTSI', 'VMGAU', 'DGICA', 'DGII', 'HNRG', 'WVE', 'HGSH', 'LBPH', 'ISUN', 'FIACU', 'NEON', 'SWKH', 'FWRG', 'TGA', 'FGF', 'ZD', 'INSM', 'CNNB', 'DTIL', 'ARLP', 'GDS', 'SIERU', 'HUGE', 'FRST', 'CULL', 'TNXP', 'ANIX', 'BCML', 'OSTRU', 'ELTK', 'NPAB', 'BLZE', 'EVOP', 'RENT', 'ENPH', 'SV', 'AYTU', 'FCFS', 'MON', 'WULF', 'NBTX', 'FUNC', 'COCP', 'CWST', 'BPACU', 'CDLX', 'VXRT', 'VERI', 'MARA', 'DLTR', 'APPH', 'VTAQ', 'IBRX', 'APMIU', 'PCX', 'SNCE', 'INDT', 'RADI', 'MPWR', 'IART', 'SSAAU', 'CBAN', 'NISN', 'LCAAU', 'GSAQ', 'IQMDU', 'REVH', 'ONVO', 'BLFS', 'CVCO', 'ENLV', 'SONO', 'CFLT', 'PEGR', 'AXNX', 'RWAY', 'DGLY', 'OTRK', 'SHLS', 'AIRT', 'BLNG', 'PSMT', 'NFE', 'NVAX', 'FFIE', 'UPLD', 'QLGN', 'SMLR', 'IBEX', 'ACAH', 'BKYI', 'ARDX', 'ORIA', 'FNWD', 'CALT', 'JCTCF', 'MCAAU', 'HBNC', 'SRZN', 'KRKR', 'CLGN', 'CCRN', 'FTAAU', 'TNDM']

train = ['ENJY', 'SVSVU', 'SBT', 'PCVX', 'KAII', 'NAUT', 'SDACU', 'PUYI',
       'CINC', 'SMCI', 'ICPT', 'INBK', 'TYME', 'BZFD', 'HITI', 'CZR',
       'VICR', 'HUSN', 'FHLTU', 'BHACU', 'PTGX', 'ALLO', 'FRSH', 'DHAC',
       'RILY', 'BAFN', 'FITB', 'EJFAU', 'KROS', 'PVBC', 'AEPPZ', 'PTRS',
       'EVGO', 'PRQR', 'MGRC', 'LPCN', 'RVMD', 'NCNA', 'PLL', 'III',
       'LEGAU', 'AGTC', 'AUDC', 'TGAN', 'FRGI', 'ITOS', 'ERII', 'SFIX',
       'HFFG', 'SPRB', 'CLAY', 'ESSCU', 'SWSS', 'JCS', 'IPDN', 'XTLB',
       'VTIQ', 'MBOT', 'HERAU', 'PSAGU', 'NVNO', 'CEMI', 'WVVIP', 'SCKT',
       'SLHGP', 'CUE', 'SGEN', 'OPRA', 'INBX', 'HUDI', 'KLTR', 'JAZZ',
       'DNAC', 'CRVL', 'SLGN', 'ERESU', 'CERT', 'LVRA', 'DOCU', 'KZIA',
       'AUVIP', 'PTVE', 'PTOC', 'SRTS', 'FANH', 'BSGAU', 'TEAM', 'SHOO',
       'GT', 'LFST', 'LAWS', 'CDMO', 'PCOM', 'WSFS', 'RPRX', 'EPSN',
       'ABCL', 'HPLT', 'BLSA', 'BRLIU', 'ACVA', 'DERM', 'INVA', 'ORIC',
       'CBAY', 'VEEE', 'SFT', 'SEV', 'DDI', 'SVFD', 'DH', 'TREE', 'INAB',
       'WFRD', 'LDHAU', 'CPAAU', 'ETSY', 'VOR', 'UMPQ', 'HSKA', 'SKYT',
       'LVOX', 'JYAC', 'MPB', 'FLUX', 'SELF', 'VRNA', 'SSB', 'ARWR',
       'ASND', 'RIOT', 'WEJOW', 'LRMR', 'JKHY', 'ACIU', 'FCNCO', 'PPHPU',
       'RDI', 'JOAN', 'XXII', 'FHLT', 'ZYNE', 'MATW', 'FGBIP', 'CFVIU',
       'ARVN', 'LYRA', 'CRECW', 'ACOR', 'NODK', 'WHLR', 'DHACU', 'CME',
       'CFFE', 'LMAO', 'ALACU', 'OLIT', 'PEAR', 'ALORU', 'ALPN', 'DISCB',
       'ARCE', 'ASPAU', 'CREC', 'EVER', 'ADAG', 'KBAL', 'PBLA', 'SGMS',
       'PBBK', 'MIME', 'FATBP', 'RCII', 'GHSI', 'TERN', 'BMRN', 'PDD',
       'LANC', 'BRKL', 'LINK', 'PYPL', 'REDU', 'HERA', 'SCOBU', 'WAVD',
       'DKNG', 'LJAQ', 'RVSB', 'KINS', 'CGEN', 'EACPU', 'CASI', 'ZNTL',
       'ISRG', 'CSBR', 'AYRO', 'SFM', 'CAN', 'VIVE', 'MNTK', 'ENSC',
       'BGFV', 'PBAX', 'CDEV', 'SBNY', 'GERN', 'ARIZ', 'SHYF', 'VYGR',
       'TEDU', 'PBCTP', 'NH', 'WKHS', 'ATY', 'POWWP', 'GREE', 'LIBYW',
       'STRC', 'AERI', 'ARRY', 'CREX', 'APRE', 'IGAC', 'SRPT', 'MCHX',
       'NRC', 'CDAQU', 'SCOA', 'IPVI', 'BHFAO', 'MRUS', 'PBHC', 'CNTG',
       'GIWWU', 'INNV', 'CGNX', 'CALB', 'MONCU', 'RXT', 'EFTR', 'RNWK',
       'RXST', 'GEVO', 'HIVE', 'SPTN', 'PALI', 'AMCIU', 'CHNG', 'SHC',
       'PGRW', 'SIDU', 'TSP', 'OHAAU', 'SSKN', 'TBBK', 'CSCO', 'DISCK',
       'WB', 'MAAQU', 'LGHL', 'MRNA', 'AACI', 'UBCP', 'NERV', 'ISLE',
       'XNET', 'HBAN', 'CRTO', 'AMRN', 'NN', 'BTNB', 'LEGH', 'RUSHA',
       'MIRO', 'BWMN', 'HRMY', 'GMBLP', 'CLBS', 'CFFEU', 'PCB', 'CGTX',
       'GAMCU', 'SGII', 'BIOS', 'CUEN', 'PDEX', 'PPIH', 'VUZI', 'EGRX',
       'MBNKP', 'LUCD', 'MSTR', 'CNTB', 'CONXU', 'AVGOP', 'HAIN', 'ATNX',
       'ACHC', 'DJCO', 'FEIM', 'ARDS', 'AOUT', 'VLAT', 'LEGA', 'DTRT',
       'RCHGU', 'VINP', 'HBIO', 'RGCO', 'PMD', 'ARBE', 'HEXO', 'GBDC',
       'SGC', 'DBVT', 'RARE', 'IMMP', 'FTCVU', 'ROCG', 'AVDX', 'TMCI',
       'CLWT', 'RMGC', 'ROSE', 'BBCP', 'RXDX', 'INMB', 'TPTX', 'CCEP',
       'HCTI', 'BRPM', 'CSIQ', 'OLITU', 'CHEF', 'STLD', 'SGHT', 'AFACU',
       'RVPH', 'JANX', 'NMRK', 'GSIT', 'CLBT', 'SOHON', 'MODV', 'MMYT',
       'OCUL', 'MDXH', 'AMAO', 'DNUT', 'CWCO', 'CLRO', 'HVBC', 'BNNR',
       'OESX', 'METC', 'LTRPA', 'AVO', 'EDNCU', 'CTSH', 'RNLX', 'AXTI',
       'CBTX', 'RMBS', 'BZFDW', 'FFWM', 'TKNO', 'TZOO', 'AVEO', 'NTRSO',
       'PIII', 'ACGL', 'PCYO', 'PETZ', 'RAVE', 'MBIO', 'DYNT', 'BCOR',
       'CHCI', 'OCAXU', 'CLNE', 'IMV', 'ALKT', 'FYBR', 'AMD', 'MORN',
       'RNERU', 'WEJO', 'RMTI', 'LPSN', 'RICOU', 'AGNCP', 'CSTE', 'APDN',
       'VIRT', 'ZKIN', 'ZUMZ', 'APVO', 'SONM', 'AGIL', 'ASTS', 'GOOD',
       'ENER', 'EXC', 'AGFY', 'SYBT', 'ALEC', 'SYPR', 'OXLC', 'NWPX',
       'CBSH', 'ROLL', 'ORMP', 'STKL', 'FTFT', 'BFC', 'BVXV', 'BHAT',
       'ZEUS', 'MNDY', 'DTOC', 'SNAX', 'GAIA', 'APYX', 'DTST', 'HYPR',
       'POSH', 'SWAV', 'DIOD', 'BIOT', 'FNWB', 'WHLRD', 'BGRY', 'TCAC',
       'SISI', 'FMTX', 'BRY', 'IMRX', 'CVLT', 'LYTS', 'EPZM', 'THAC',
       'TSCBP', 'IRDM', 'SSRM', 'VVPR', 'APXIU', 'VERO', 'BHSEU', 'SBSI',
       'TARS', 'WORX', 'JOBS', 'SVFAU', 'COLB', 'QQQX', 'GMBTU', 'SESN',
       'OCGN', 'ALACW', 'SURF', 'LBPS', 'PCTTU', 'INDI', 'FFIN', 'CHMG',
       'MCAGU', 'ARTE', 'STTK', 'GMDA', 'VIRC', 'IMCC', 'MRCY', 'DYN',
       'NXGN', 'ABSI', 'FOUNU', 'IMMR', 'PYXS', 'NCNO', 'WLFC', 'GTHX',
       'SEAC', 'ICFI', 'TFFP', 'SCLEU', 'PTLO', 'OLK', 'FIXX', 'ERYP',
       'GRTX', 'WWD', 'BECN', 'SBET', 'TRUP', 'DORM', 'IMKTA', 'BSGA',
       'SLGL', 'AUPH', 'ROCG', 'VRPX', 'DRTT', 'MBINO', 'ARIZU', 'IHRT',
       'OSIS', 'PRTC', 'BZ', 'SPNS', 'MSDA', 'AATC', 'FAST', 'Z', 'URBN',
       'GTIM', 'DMLP', 'RAMMU', 'QNRX', 'EDIT', 'SNGX', 'EBET', 'BMBL',
       'IGAP', 'TWLV', 'TMPM', 'SQFTP', 'ACEVU', 'DXCM', 'LCID', 'INPX',
       'HQY', 'LNT', 'LILAK', 'BLKB', 'MXL', 'PAYA', 'VERY', 'NXGL',
       'WHLM', 'STRR', 'CCNE', 'CVV', 'ORIAU', 'GLBZ', 'NDACU', 'VORBW',
       'BRCN', 'VGFC', 'FHTX', 'NAVI', 'DOGZ', 'MNST', 'JBHT', 'BTBT',
       'DSEY', 'AGGRU', 'OTEC', 'SGMO', 'MCRB', 'SPOK', 'NFBK', 'UNIT',
       'IMOS', 'MTBCP', 'MGEE', 'GRPH', 'BWCAU', 'OSW', 'SSTI', 'SAL',
       'ADI', 'AGMH', 'RBKB', 'VERB', 'SVNA', 'GBRG', 'PTCT', 'MYPS',
       'CBIO', 'PCSA', 'CHW', 'IQMD', 'OCC', 'CONX', 'FBMS', 'BOCNU',
       'LAMR', 'NRAC', 'NRIM', 'BHACW', 'OCAX', 'ESLT', 'SIVB', 'LBTYA',
       'SNPO', 'ICLR', 'MEOA', 'FOX', 'RANI', 'GLAQU', 'NLTX', 'UCL',
       'ZYXI', 'LCUT', 'RDNT', 'BRTX', 'FLNT', 'CSWC', 'KVSC', 'GLBS',
       'NMFC', 'TIOA', 'STKS', 'AUTL', 'ACTG', 'XBIT', 'CPSS', 'HFBL',
       'BBI', 'NVMI', 'POLA', 'VMD', 'OTRAU', 'IMPP', 'SWAG', 'RPTX',
       'CTAQU', 'SPWH', 'RCHG', 'FICVU', 'FNCH', 'AVGR', 'ANPC', 'SNSE',
       'CHRW', 'GP', 'JOFF', 'SLS', 'IOVA', 'MCFT', 'GEG', 'VALN', 'GOSS',
       'ROLLP', 'BKR', 'SNDL', 'CIZN', 'SLMBP', 'MMMB', 'SNTG', 'FSBC',
       'AQB', 'AKICU', 'COKE', 'TETC', 'AMPL', 'WTFCM', 'FOXWU', 'HMNF',
       'EML', 'HYRE', 'MNSBP', 'INTEW', 'PEGA', 'SIOX', 'XOMAO', 'IMRA',
       'GRPN', 'SHAC', 'SAMG', 'OIIM', 'EVO', 'MYRG', 'BIOTU', 'VLNS',
       'OVLY', 'IPAX', 'XGN', 'SLVRU', 'VCXAU', 'HCII', 'FWONA', 'UPWK',
       'URGN', 'HNNA', 'COLIU', 'GET', 'AVAC', 'RNWK', 'SFNC', 'ONCS',
       'IMGO', 'EBACU', 'AY', 'INCY', 'PROG', 'GGAAU', 'GLBLU', 'NEGG',
       'ATHX', 'TSAT', 'KRT', 'XFINW', 'ACEV', 'STRA', 'EAR', 'COOLU',
       'INTG', 'FOUNW', 'CFIV', 'FTVIU', 'LVO', 'TUGC', 'SIVBP', 'REGI',
       'HIBB', 'MODD', 'STRNW', 'STEP', 'ANTE', 'APP', 'TEKK', 'SLGCW',
       'AVHIU', 'ABCM', 'ULBI', 'ON', 'VACC', 'AGBAU', 'CMMB', 'BWAC',
       'ACRS', 'SLRC', 'NTES', 'WALD', 'LPTX', 'SOTK', 'PONOU', 'DLTH',
       'TOAC', 'EBC', 'PRFT', 'FRW', 'TUEM', 'JACK', 'CNXC', 'ALKS',
       'SGLB', 'GOGO', 'TRVN', 'DYAI', 'SPSC', 'GPRE', 'PRPH', 'RNW',
       'ASRT', 'RAPT', 'TXRH', 'VRCA', 'GTPAU', 'CPSI', 'GSHD', 'SOLO',
       'SYBX', 'ALRM', 'KZR', 'NAII', 'NHICU', 'TIOAU', 'ACAHU', 'PHAT',
       'OMIC', 'TILE', 'QTRX', 'NXTC', 'VIRX', 'ALYA', 'DSGX', 'AKTS',
       'AWH', 'OCG', 'IMTX', 'METX', 'ATAX', 'JVA', 'LTCH', 'RBBN',
       'ATLC', 'HCSG', 'BIRD', 'TH', 'AQST', 'CVLG', 'NWBI', 'CCB',
       'MNSB', 'IPSC', 'IZEA', 'GEEXU', 'CVGW', 'RNAZ', 'RAIN', 'SUMO',
       'GRIN', 'SMID', 'IVCBU', 'FUV', 'HZNP', 'DADA', 'AREC', 'PGEN',
       'FNHC', 'CLRMU', 'HSAQ', 'GSEV', 'AHPI', 'OPRX', 'BANF', 'PRSO',
       'TBKCP', 'TSIB', 'WABC', 'TMDX', 'ATHE', 'MCLD', 'HCCI', 'MCRI',
       'LVOXU', 'BANX', 'LGVC', 'OCSL', 'AVRO', 'LEVLP', 'VLY', 'CCNC',
       'TRONU', 'AIRS', 'ACXP', 'NLITU', 'SOHU', 'FBRX', 'ATLO', 'CVCY',
       'BTAI', 'BANR', 'INKA', 'MDRR', 'FDBC', 'CRSP', 'MRKR', 'GLRE',
       'OTRKP', 'HSIC', 'EQ', 'CYRX', 'BCPC', 'YNDX', 'GMFIU', 'TRIP',
       'QRHC', 'SITM', 'SATS', 'ROAD', 'ESSA', 'RVNC', 'IRWD', 'NGM',
       'RADA', 'EUCRU', 'CDRO', 'AMBA', 'BGNE', 'EVLO', 'BWEN', 'HOFV',
       'TENB', 'FDUS', 'WTMAU', 'ANIK', 'BWAY', 'OM', 'REAX', 'NTRS',
       'ARBG', 'PKOH', 'ARKO', 'BRLI', 'VIA', 'EJFA', 'CLSD', 'HBT',
       'KPRX', 'COWN', 'DAWN', 'NESR', 'VERX', 'GNTY', 'SAMAU', 'PACB',
       'CASH', 'CCBG', 'CYCCP', 'MINM', 'ZION', 'CRMD', 'STAA', 'IRMD',
       'AEAC', 'USAP', 'BLU', 'RSVR', 'COUP', 'ABEO', 'ARCKU', 'FATE',
       'DRMA', 'WWAC', 'BYTSU', 'JFU', 'AHI', 'REAL', 'PRLH', 'CCTS',
       'BLPH', 'INDP', 'POW', 'PATI', 'ACST', 'OMGA', 'NOVV', 'SELB',
       'WINV', 'ISO', 'HLMN', 'SOHOO', 'EXLS', 'AEY', 'BPYPO', 'STGW',
       'MHLD', 'ROIV', 'BDTX', 'XFIN', 'TALS', 'PNNT', 'ESBK', 'AMCI',
       'FELE', 'SPPI', 'AMAT', 'SOPA', 'FRBA', 'SPNE', 'KTOS', 'ACCD',
       'CMPR', 'PAAS', 'ABTX', 'VBTX', 'COFS', 'RENO', 'BRQS', 'VRAY',
       'FENC', 'SLNH', 'BAOS', 'SAGA', 'MFH', 'HLIT', 'HLNE', 'ROIC',
       'LULU', 'GVCIU', 'EGBN', 'AEAEU', 'VIEW', 'BATRK', 'TSRI', 'TLIS',
       'TCBX', 'CREG', 'LAAAU', 'DTSS', 'BCSAU', 'GRIL', 'PRTG', 'CCMP', 'XELA', 'YTRA', 'LLL', 'SAMA', 'BWC', 'EMKR', 'TCBS', 'AZ', 'NBRV',
       'MYMD', 'PAYO', 'SCVL', 'NTRA', 'KDP', 'HCIIU', 'SRRK', 'PLBC',
       'MBIN', 'GOEV', 'HTIBP', 'QMCO', 'PYCR', 'HOOD', 'PZZA', 'SSNC',
       'TOWN', 'YGMZ', 'PGNY', 'NWE', 'TUSK', 'RCEL', 'BCSA', 'KLAQU',
       'LSEA', 'CLST', 'IMPPP', 'CYTK', 'CHSCN', 'ALSAU', 'OCDX', 'NTCT',
       'MLVF', 'PALT', 'MTAC', 'DIBS', 'TECTP', 'DNAD', 'UCTT', 'FISI',
       'RILYP', 'LPLA', 'OXUS', 'DISA', 'ACET', 'CVRX', 'ANZU', 'NFLX',
       'BIDU', 'JMACW', 'VSEC', 'ABMD', 'CMPOW', 'LOPE', 'VTRU', 'CRXT',
       'ITRM', 'TEKKU', 'CRDF', 'TBNK', 'OXBR', 'LMB', 'HTLD', 'ELYS',
       'PCCTU', 'INOD', 'NVIV', 'RGNX', 'CATY', 'IPVIU', 'WLDN', 'SBRA',
       'CACC', 'MARK', 'CUTR', 'VJET', 'NEO', 'PFBC', 'MSAC', 'OCFC',
       'OZKAP', 'UEPS', 'GSM', 'ASRV', 'ATRA', 'ADN', 'ELOX', 'RDWR',
       'DRRX', 'USAU', 'GACQ', 'MAT', 'IMAB', 'HAFC', 'CCXI', 'MOBQ',
       'HST', 'LIND', 'POWL', 'LIDR', 'IQ', 'WEYS', 'LITTU', 'NBST',
       'THCAU', 'CRAI', 'HAPP', 'JAQCU', 'RIDE', 'MDB', 'ADALU', 'ICCH',
       'LANDM', 'NWL', 'GFAI', 'ADTX', 'ATRC', 'SVRA', 'PAA', 'LDHA',
       'AMYT', 'CDK', 'REFR', 'UPST', 'COIN', 'PDFS', 'RTLR', 'FRPT',
       'SCPL', 'POWW', 'INMD', 'VIGL', 'PCSB', 'PEP', 'SEEL', 'QDEL',
       'JUGGU', 'NKSH', 'KTTA', 'SCPS', 'APLT', 'IMBI', 'VSACU', 'PFTAU',
       'ZI', 'ZY', 'TSHA', 'VEV', 'FRLAU', 'BCEL', 'MEAC', 'SLVR', 'ENOB',
       'ADUS', 'HTOOW', 'FCUV', 'GABC', 'GTBP', 'IMNM', 'MGI', 'PDLB',
       'PAGP', 'MIGI', 'NEXI', 'SUMR', 'RICK', 'LGSTW', 'DSWL', 'ADP',
       'INVO', 'BWFG', 'CALA', 'MLAC', 'ARKOW', 'ETTX', 'INTZ', 'OZON',
       'RELL', 'SAGE', 'TMKR', 'CRBU', 'SCOB', 'SMTC', 'YY', 'KNDI',
       'GOGL', 'GLBE', 'SIFY', 'MAYS', 'SPTK', 'SJ', 'TIGO', 'SIGIP',
       'NBTB', 'TCBC', 'EBON', 'BIGC', 'CPRT', 'DTEA', 'ASLE', 'OYST',
       'PHUN', 'NXPL', 'GILD', 'PEBK', 'LSXMA', 'DHC', 'BSGM', 'NOVT',
       'ENVX', 'NTNX', 'ZEAL', 'PFSW', 'KRTX', 'GLHAU', 'AEAE', 'GTH',
       'VIIAU', 'SRSAU', 'SSYS', 'GIGM', 'RLMD', 'FFBW', 'IPWR', 'INCR',
       'VTGN', 'CASS', 'IRTC', 'GIFI', 'OB', 'MTSI', 'IREN', 'ASUR',
       'CRBP', 'UTRS', 'CLRM', 'FTRP', 'VRNT', 'BWBBP', 'PEPLU', 'OCCIN',
       'TARA', 'SLNG', 'CBRGW', 'NSTG', 'IEA', 'GBIO', 'BTX', 'AXDX',
       'CASA', 'TWST', 'EPHY', 'THACU', 'VCNX', 'CPIX', 'AIMC', 'NVOS',
       'GTACU', 'STRT', 'CIIGU', 'FWBI', 'SCWX', 'GLMD', 'PACXU', 'MGIC',
       'FATBB', 'ROKU', 'CBRL', 'RCHG', 'OMAB', 'MASI', 'CASY', 'OTRA',
       'LFTR', 'CYBR', 'PHVS', 'CFMS', 'FWP', 'PIXY', 'CPAR', 'NBSTU',
       'RRBI', 'BFST', 'SBTX', 'KMDA', 'NSSC', 'NVCN', 'PSAG', 'GBRGU',
       'PFIE', 'MEIP', 'ZM', 'NYMTN', 'ULTA', 'SCHL', 'GLEE', 'IONM',
       'AIHS', 'TLRY', 'TOUR', 'CENQU', 'ROST', 'SNT', 'FLMN', 'EVK',
       'DBX', 'WTW', 'INDB', 'AVGO', 'NSYS', 'GGMC', 'TWOU', 'FSRX',
       'CLAYU', 'FGFPP', 'PYPD', 'CPOP', 'CHI', 'KALA', 'LFMD', 'EXPO',
       'SBLK', 'HTHT', 'FOXF', 'CDAQW', 'DUO', 'HRTX', 'FAT', 'TSEM',
       'PACW', 'ROAD', 'FBIZ', 'IFRX', 'DLPN', 'PAQC', 'ZIVO', 'XRAY',
       'ZS', 'YELL', 'JCICU', 'MIND', 'STRS', 'THRY', 'MTP', 'MKSI',
       'MCHP', 'PRAX', 'ZENV', 'SANA', 'TXG', 'SNCY', 'BCTX', 'AKU',
       'AUBAP', 'ENG', 'SDC', 'MINDP', 'KARO', 'AGNCN', 'TCFC', 'HCAR',
       'RUTH', 'FTPA', 'MTC', 'GNLN', 'NECB', 'COHU', 'UBOH', 'RGLS',
       'MITK', 'SMBC', 'PETS', 'FTPAU', 'TGVCW', 'BKNG', 'FATP', 'SRAD',
       'VFF', 'AESE', 'TETCU', 'PBCT', 'RACB', 'CARG', 'GIIXU', 'GDYN',
       'ADSEW', 'CCAI', 'KRON', 'SHBI', 'SIEB', 'EXTR', 'GNTX', 'IFBD',
       'LAXXU', 'SRDX', 'GRVY', 'CAMP', 'HAIAU', 'RXRX', 'CYTH', 'ALNY',
       'TRKA', 'RIBT', 'KFRC', 'AMED', 'ADAL', 'VRAR', 'EXPI', 'AIKI',
       'FFIV', 'YMTX', 'LUNG', 'RSVR', 'ALPP', 'CPLP', 'HPLTU', 'OSTR',
       'TER', 'DRVN', 'TBPH', 'MITO', 'CURI', 'LSXMB', 'TGLS', 'AZN',
       'DCT', 'HMHC', 'DGNU', 'EVBG', 'HSII', 'LMST', 'GMTX', 'SFET',
       'FSLR', 'SECO', 'UNTY', 'CENT', 'CHEK', 'PRDS', 'KFFB', 'MGNX',
       'SGRP', 'PMCB', 'VYNT', 'IDCC', 'NBSE', 'DISAU', 'PWFL', 'RRR',
       'FA', 'REE', 'DCTH', 'VRRM', 'LSCC', 'APR', 'WTBA', 'RGP', 'SEAT',
       'USCB', 'ARGU', 'SANW', 'MEOH', 'LKQ', 'RCON', 'BLIN', 'PTEN',
       'MTRYU', 'PAYS', 'PAHC', 'VCKAU', 'SERA', 'BHFAN', 'ARTL', 'MSGM',
       'RUSHB', 'INVE', 'CHWA', 'HELE', 'TRIN', 'OLED', 'EMLDU', 'FCAP',
       'AMKR', 'RCLFU', 'GAN', 'PHICU', 'AFAQ', 'HAACU', 'KELYB', 'SQL',
       'AIH', 'ADTHW', 'CARA', 'JUGG', 'DSP', 'AEI', 'CGO', 'LBAI', 'BRP',
       'BLFY', 'AMSC', 'ARRW', 'BFRA', 'SAGAU', 'CHRS', 'REPH', 'VIRI',
       'TXN', 'TALK', 'NNDM', 'ZNGA', 'NDAC', 'DARE', 'BPTH', 'PFIN',
       'MAQC', 'ARYE', 'CRMT', 'CHCO', 'FRSX', 'SVVC', 'GOOG', 'GRUB',
       'TITN', 'SYNA', 'GAMB', 'EFOI', 'XENT', 'SCMA', 'HOWL', 'FITBO',
       'TGVC', 'SQFTW', 'MTRX', 'SNRH', 'FPAY', 'DCGO', 'MRAM', 'SCYX',
       'NOACU', 'SMIT', 'GILT', 'TROO', 'NHTC', 'SCAQ', 'VLYPO', 'SBFG',
       'DOYU', 'LGND', 'KSPN', 'THCP', 'RVACU', 'MOFG', 'JCIC', 'KDNY',
       'BLTSU', 'ANSS', 'NCAC', 'AMPG', 'MPRAU', 'OPNT', 'GOOGL', 'REVHU',
       'HURC', 'HA', 'REYN', 'CDXS', 'BOTJ', 'TPBAU', 'NVDA', 'RKLB',
       'MNPR', 'CDTX', 'ARTNA', 'MEDP', 'UVSP', 'AVID', 'AFBI', 'SCHL',
       'WSBF', 'LSTR', 'GENE', 'LXEH', 'FUSN', 'TCBK', 'FIZZ', 'PTE',
       'AKYA', 'SALM', 'SP', 'VTRS', 'TATT', 'GROM', 'STRL', 'XPER',
       'XPAX', 'WWACU', 'GSAQU', 'GTPA', 'CCEL', 'UBX', 'SMMT', 'CRCT',
       'CTXS', 'ESGRP', 'CARV', 'GNPX', 'AZTA', 'PPGHU', 'ARTW', 'LIONW',
       'FCRD', 'CRZNU', 'LRFC', 'NSPR', 'BTTX', 'USLM', 'LAZY', 'PFG',
       'PRIM', 'MOHO', 'NATI', 'PMGMU', 'BCOW', 'SCOAU', 'GCBC', 'MIDD',
       'CONN', 'NTRB', 'HHGCU', 'BELFA', 'MARPS', 'HYFM', 'UXIN', 'ACBA',
       'TTEC', 'LMDX', 'DSGN', 'EA', 'WRLD', 'ATXI', 'PAX', 'RELY', 'AHG',
       'PPGH', 'LEE', 'JAN', 'MMAT', 'IDBA', 'SVFB', 'KAIR', 'WVFC',
       'NBN', 'ATSG', 'ALGN', 'VAQC', 'NUVL', 'AMWD', 'EYEN', 'SNES',
       'CDZI', 'ARYD', 'LKCO', 'PTSI', 'QTT', 'REG', 'MACAU', 'EOSE',
       'HLTH', 'CRUS', 'TAST', 'NTLA', 'PLUG', 'MVBF', 'XMTR', 'ROST',
       'GGGVU', 'TVTY', 'CLAQU', 'AKBA', 'JSPR', 'EGAN', 'APA', 'DHCAU',
       'FIBK', 'VTVT', 'PAQCU', 'HLG', 'ATIF', 'GIW', 'GH', 'MTEM',
       'TVTX', 'THCA', 'EDSA', 'LZ', 'FREE', 'RNST', 'SY', 'CODX', 'GALT',
       'BNOX', 'BLI', 'SPWR', 'SLP', 'GDRX', 'UNCY', 'SGTX', 'SHCR',
       'CBRGU', 'BVS', 'VSTA', 'VLON', 'VNOM', 'BYSI', 'INFI', 'OMEX',
       'ASMB', 'UBSI', 'AACIU', 'NTGR', 'BPYPN', 'COST', 'PSHG', 'SBSI',
       'BPMC', 'XPDBU', 'PFTA', 'KEQU', 'FWONK', 'NDSN', 'WMG', 'STAF',
       'INKAU', 'KRNL', 'ACT', 'CFB', 'TXMD', 'PRFX', 'PCH', 'CNOBP',
       'LGST', 'LVLU', 'ALLT', 'MKD', 'ASYS', 'NLSP', 'SFBC', 'MESO',
       'TLSA', 'SXTC', 'YJ', 'EXAS', 'TMUS', 'CGRN', 'DRAYU', 'BCYC',
       'CNTY', 'FRGAP', 'PAFO', 'VCXA', 'NMRD', 'BBBY', 'HTBK', 'ACAD',
       'AXLA', 'CABA', 'GRVI', 'XEL', 'NMTR', 'PDCO', 'TWKS', 'ANGN',
       'INO', 'ARKR', 'QRTEA', 'SBGI', 'ALPAU', 'KRNY', 'APMI', 'DPCS',
       'SGMA', 'VRTS', 'RDBX', 'TNYA', 'LEXX', 'ITCI', 'HTZ', 'MRCC',
       'AAME', 'REVEU', 'FRON', 'QLI', 'EVCM', 'WASH', 'ADTN', 'SRCL',
       'LFMDP', 'LMNL', 'XLO', 'AMSWA', 'VSAC', 'HOFT', 'CCLP', 'EDRY',
       'PPBI', 'FRSG', 'MSEX', 'BEEM', 'SGH', 'FULC', 'ITRN', 'CTIB',
       'CKPT', 'GMAB', 'MCAE', 'BRZE', 'LHDX', 'GDNRU', 'INTU', 'SUNW',
       'CXDO', 'APPN', 'RCKT', 'MULN', 'ROSEW', 'VWE', 'APTM', 'GLG',
       'DCRDU', 'STRN', 'CSCW', 'BFRI', 'ATRO', 'EDUC', 'ASTL', 'ALRS',
       'NURO', 'PCXCU', 'INTE', 'FARM', 'GIAC', 'AVTX', 'CMPI', 'TOMZ',
       'LBRDA', 'NKTR', 'PBYI', 'GTPB', 'CRWD', 'UCBIO', 'MDGL', 'VYNE',
       'CLSK', 'OXSQ', 'AUUD', 'GURE', 'LOCO', 'COLL', 'RMBI', 'OPOF',
       'RETA', 'GMVD', 'OPBK', 'ALVR', 'CRECU', 'VLATU', 'NVNOW', 'RUN',
       'COVAU', 'DALS', 'HON', 'MHUA', 'DMAC', 'DCOMP', 'SNOA', 'SQFT',
       'RDCM', 'MYNZ', 'VG', 'GACQU', 'SPT', 'LMFA', 'HTBI', 'BBSI',
       'ACGLO', 'ACTDU', 'PRSRU', 'LAUR', 'BCDA', 'GDEN', 'HUIZ', 'SREV',
       'FORD', 'TRVI', 'TGAAU', 'PRTA', 'AGNC', 'KVSA', 'LMAT', 'ATEX',
       'VCYT', 'CTRE', 'VMGA', 'BRID', 'NOVVU', 'SABRP', 'NBIX', 'AUBN',
       'OMEG', 'AGFS', 'OAS', 'DKDCU', 'GEEX', 'MAAQW', 'IBKR', 'GEOS',
       'OFED', 'OTMO', 'ROCAU', 'WPRT', 'COOL', 'FTVI', 'BMRA', 'MBINP',
       'HYMCW', 'DPCSU', 'ESSC', 'JNCE', 'CNEY', 'MORF', 'VBFC', 'LTRN',
       'PULM', 'BOLT', 'GLAQ', 'RNXT', 'SBFM', 'PDCE', 'CIGI', 'RNERW',
       'MF', 'SVFC', 'SNEX', 'TIVC', 'BLBX', 'UFPT', 'HROW', 'MVST',
       'MNDT', 'XM', 'NPCE', 'HCM', 'SUNS', 'MLAI', 'MANT', 'ALLR',
       'CPARU', 'MYFW', 'BOXL', 'QFIN', 'AEYE', 'WAVE', 'MPAA', 'APAC',
       'PRCH', 'FEMY', 'UG', 'WVVI', 'HLBZ', 'FB', 'HWBK', 'HNST', 'AVXL',
       'EOLS', 'ADMA', 'KLIC', 'MPAC', 'NVSAU', 'VIEWW', 'ASPCU', 'CELU', 'SLN', 'EXAI', 'FLAC', 'GGMCU',
       'CYAN', 'IGNYU', 'SUPN', 'OVID', 'WSBCP', 'OTTR', 'GGPI', 'PGRWU',
       'WW', 'ZG', 'LOB', 'CNET', 'PSTX', 'VECT', 'BYND', 'EDTX', 'JJSF',
       'WSBC', 'TRNS', 'RWLK', 'RNA', 'POOL', 'ASAX', 'ICMB', 'OXLCM',
       'BKEPP', 'MAXN', 'AGNCM', 'UPTD', 'ASTR', 'WERN', 'VABK', 'ARGX',
       'PFDRU', 'FCNCP', 'REVB', 'DZSI', 'EBIX', 'AHCO', 'HSON', 'GPAC',
       'IGACU', 'SVC', 'KSI', 'YTEN', 'GXIIU', 'BLMN', 'DNAA', 'MEACU',
       'HIIIU', 'WAFDP', 'IXAQ', 'FNGR', 'PLYA', 'FXNC', 'RDUS', 'MBRX',
       'WDFC', 'POWI', 'RBBN', 'JFIN', 'SAIA', 'ALTU', 'TOACU', 'AVACW',
       'DVAX', 'TSIBU', 'EFSC', 'OSTK', 'AFYA', 'ACGLN', 'LMNR', 'SCMAU',
       'NCMI', 'MUDSU', 'HCKT', 'GLAD', 'AHPA', 'CRIS', 'NXTP', 'RPHM',
       'MLACU', 'VKTX', 'CSPI', 'NMIH', 'PLCE', 'OSBC', 'KPTI', 'WHF',
       'ICCC', 'KRNLU', 'ONCY', 'BEAM', 'AKIC', 'SMSI', 'OEG', 'OEPW',
       'GRFS', 'LCAA', 'PHIO', 'AGYS', 'KIII', 'ICAD', 'EFSCP', 'FINW',
       'CRNX', 'KINZ', 'CLVS', 'CCNEP', 'RCM', 'ATRI', 'CHX', 'HIMX',
       'CNSL', 'PLXP', 'MBWM', 'OXACU', 'NARI', 'TMKRU', 'NGMS', 'IDXX',
       'BL', 'CJJD', 'ENTFU', 'ASPS', 'XENE', 'CTIC', 'KMPH', 'FGEN',
       'MCBC', 'VWTR', 'BLNK', 'VLGEA', 'PTIC', 'NXPI', 'PHAR', 'AXGN',
       'PROF', 'ALXO', 'WINT', 'ZBRA', 'TRIB', 'ARBK', 'AFMD', 'NMMCU',
       'TZPS', 'ZWRKU', 'ADER', 'GTPBU', 'LOGI', 'ANAB', 'RUN', 'HHR',
       'MRVL', 'PTOCU', 'TCX', 'MTBC', 'VENAU', 'CPSH', 'ORRF', 'FBIOP',
       'AEIS', 'ESAC', 'SVFA', 'GRWG', 'PBFS', 'WHLRP', 'VRME', 'FWAC',
       'BHSE', 'ALTUU', 'MSBI', 'PWP', 'UTHR', 'KELYA', 'HCVI', 'PLAB',
       'HMST', 'LGTOU', 'BPAC', 'ORGN', 'MLKN', 'VIAV', 'LLNW', 'LCAHU',
       'BASE', 'HWC', 'BNFT', 'LWAY', 'CLPT', 'CVLY', 'PETQ', 'KLXE',
       'STIM', 'TTEK', 'DBTX', 'ETAC', 'EYPT', 'LMACA', 'CHY', 'AMNB',
       'EWTX', 'PANL', 'NVEI', 'BRLT', 'PUCK', 'FSBW', 'HAAC', 'AOGOU',
       'OP', 'ONCT', 'FULT', 'AXON', 'NRIX', 'NTUS', 'MDJH', 'FFBC',
       'CYCC', 'CSSE', 'COOP', 'GVCI', 'HOUR', 'THTX', 'CONE', 'LPTH',
       'BENEU', 'ICVX', 'RPRX', 'MBINN', 'BLRX', 'COCO', 'CHSCP', 'HIFS',
       'CTRM', 'CENX', 'PNT', 'CRDL', 'DMTK', 'OPT', 'PLPC', 'GTXAP',
       'LIONU', 'SPKB', 'DNAB', 'PSTI', 'DNAY', 'WINVU', 'NMTC', 'TCON',
       'RELI', 'FMAO', 'MNTV', 'GIII', 'DUNEU', 'AUR', 'APEN', 'DBGI',
       'STCN', 'DICE', 'TSLA', 'FTCI', 'DLCA', 'ENTF', 'KALU', 'DUOT',
       'HMTV', 'CERN', 'XOMA', 'PIK', 'ACMR', 'PLUS', 'CRTX', 'SLGG',
       'SCOR', 'LSXMK', 'OFLX', 'IMAQ', 'GCMG', 'CTXR', 'NUZE', 'CIFR',
       'DILA', 'GRCL', 'FUSB', 'TSVT', 'TGTX', 'OLPX', 'TIL', 'SCHN',
       'TRMR', 'CRON', 'PRVA', 'VRNS', 'CMPO', 'VTAQU', 'KRBP', 'HLAHU',
       'SPI', 'CHSCL', 'UTMD', 'OPRT', 'ALGM', 'CLXT', 'SDH', 'ATOM',
       'CHK', 'ATXS', 'BRPMU', 'FBIO', 'NRXP', 'IMRN', 'GBNY', 'ONYXU',
       'FRBNU', 'PSTV', 'SBNYP', 'IVCPU', 'TBLA', 'SKYW', 'NLOK', 'BIVI',
       'BSKYU', 'EMBK', 'KOD', 'WISA', 'TCBI', 'QH', 'NEXT', 'PCT',
       'SHIP', 'ALRN', 'BJRI', 'GSMGW', 'SFST', 'RGF', 'NICK', 'SLCR',
       'MBUU', 'NOTV', 'VCTR', 'CVGI', 'APEI', 'CDNA', 'NIU', 'ENTFW',
       'OPI', 'ONTX', 'FRLA', 'RGC', 'IIN', 'WETF', 'AEHL', 'AMTB',
       'DWSN', 'EEIQ', 'TOIIW', 'FVCB', 'SCPH', 'HCARU', 'THRX', 'BTB',
       'CSGS', 'FTEK', 'GLBL', 'BIOX', 'TRVG', 'NAAC', 'IXAQU', 'HDSN',
       'UTME', 'COMS', 'RRGB', 'CNTQ', 'SNY', 'SLHG', 'FTAA', 'CHSCO',
       'MACU', 'ANAT', 'APCXW', 'BATRA', 'UK', 'DLO', 'CMCTP', 'DYNS',
       'ARCB', 'GHAC', 'OPHC', 'AUGX', 'ADALW', 'AMLX', 'SOFO', 'MVIS',
       'SNDX', 'RNDB', 'CBFV', 'YQ', 'CTLP', 'QUBT', 'ITIC', 'TW', 'ARTA',
       'GLDD', 'THFF', 'ADSK', 'CD', 'SPK', 'IVA', 'FRWAU', 'EJH', 'LIAN',
       'TRON', 'CTBI', 'CYAD', 'AGIO', 'THMO', 'NOAC', 'VPCB', 'FWRD',
       'CMCO', 'LE', 'CZNC', 'CTAQ', 'GLNG', 'APOG', 'GNUS', 'FIACW',
       'TRMB', 'RMCF', 'LTRX', 'TOIIW', 'SBCF', 'INSG', 'MAQCU', 'FORTY',
       'BRIVU', 'ARCK', 'BDSX', 'PTMN', 'REED', 'CCSI', 'UMBF', 'INFN',
       'GATEW', 'TDUP', 'LIBYU', 'PMTS', 'UTSI', 'HCVIU', 'ALGS', 'NTIC',
       'NMMC', 'SMIHU', 'GOVX', 'GENC', 'WTFCP', 'HMCO', 'CVET', 'STBA',
       'KHC', 'ISBC', 'SPCB', 'XELB', 'JMACU', 'MTRYW', 'MOVE', 'LAX',
       'ANGO', 'SBFG', 'OTMOW', 'SGRY', 'FIVE', 'NVAC', 'QK', 'AMTX',
       'XRTX', 'PLTK', 'WIX', 'HLAH', 'IMCR', 'NKTX', 'MQ', 'MPRA',
       'ULCC', 'WSTG', 'TWLVU', 'GPACU', 'MPACU', 'NWS', 'ME', 'TAIT',
       'SWTX', 'NRACU', 'FLXS', 'BTCY', 'FINM', 'ADXN', 'TELA', 'ALZN',
       'KALV', 'ISPC', 'MOTS', 'EVOJU', 'ALIM', 'ABUS', 'COLI', 'SCYX',
       'JWEL', 'RSSS', 'SBFMW', 'EWCZ', 'CFFI', 'JOFFU', 'BSFC', 'UBFO',
       'LARK', 'AUVI', 'FLYW', 'BTCS', 'SLDPW', 'SLDB', 'HCNE', 'IDEX',
       'MCAF', 'PNTG', 'HWEL', 'SANM', 'FARO', 'ASPA', 'IGMS', 'DWAC',
       'LCAP', 'ASO', 'VERU', 'PAFOU', 'BHAC', 'EWBC', 'GEEXW', 'PRPL',
       'LIONW', 'GFED', 'MESA', 'LOVE', 'SRNE', 'UTAAU', 'ASAXU', 'DHHC',
       'TRUE', 'PFMT', 'PHIC', 'SIGA', 'SIRI', 'CRESY', 'NVEC', 'AEHA',
       'PUBM', 'GTX', 'VINO', 'LANDO', 'NDAQ', 'ABST', 'NAACU', 'IAS',
       'CLFD', 'UAL', 'ZEST', 'LBTYB', 'CCD', 'RNDB', 'QURE', 'CRNT',
       'ATNI', 'RDVT', 'PIRS', 'CFBK', 'MITAU', 'BELFB', 'AFAQU', 'DRUG',
       'ORGO', 'MASS', 'SHQAU', 'OXLCP', 'ALOR', 'SSBK', 'SCOA', 'HYZN',
       'FRLAW', 'SEED', 'AUTO', 'OPTN', 'TCMD', 'TSC', 'CSGP', 'HMCOU',
       'SGML', 'RMGC', 'SATL', 'OZK', 'AKRO', 'SMFR', 'PCCT', 'MTCH',
       'PFX', 'CMBM', 'OXBRW', 'CRNC', 'GLEEU', 'COMM', 'FNVT', 'XP',
       'DSKE', 'PDSB', 'OBCI', 'ENSG', 'TIPT', 'AURCU', 'ALHC', 'ATAI',
       'FLL', 'LGVN', 'AEHR', 'ICUI', 'BFIN', 'LYFT', 'SPFI', 'BIOSU',
       'AWRE', 'ARTEU', 'RAIL', 'RNST', 'AIRTP', 'LBTYK', 'DCRD', 'DHIL',
       'GLHA', 'ROLL', 'BCLI', 'CTHR', 'SPTKU', 'TA', 'ANIP', 'ARTAU',
       'VALU', 'ROCGU', 'SCAQU', 'BNTC', 'CMPX', 'NRDS', 'AYLA', 'CRWS',
       'SHEN', 'PROV', 'PPC', 'XPEL', 'CECE', 'DMAQ', 'LFUS', 'FIVN',
       'GRCYU', 'QRTEB', 'IOACU', 'MCBS', 'RCACU', 'PNRG', 'MOXC', 'VHNA',
       'RAM', 'XOMAP', 'PXLW', 'FITBP', 'CEVA', 'SRAX', 'CHWAU', 'JZXN',
       'BRKR', 'CALM', 'STSA', 'ECPG', 'SWSSU', 'BAND', 'AMTI', 'LGVCU',
       'ANDE', 'GFS', 'CETXP', 'AFIB', 'PTIX', 'PTNR', 'CBAT', 'KAVL',
       'LYLT', 'LECO', 'BPRN', 'TASK', 'AFAC', 'VCKA', 'NAOV', 'PME',
       'HGBL', 'FSTX', 'EZGO', 'ATVC', 'RCLF', 'CMCT', 'MBII', 'PAYX',
       'TANH', 'TESS', 'CFIVU', 'AOSL', 'XFOR', 'REFI', 'CETX', 'LIXT',
       'ANEB', 'ARRWU', 'PEGRU', 'NUVA', 'ONYX', 'LMACU', 'YMAB', 'IMXI',
       'CELH', 'WAFU', 'CSSEP', 'NUWE', 'HMPT', 'GTEC', 'TPIC', 'MTEX',
       'GHRS', 'LOAN', 'NHIC', 'FITBI', 'FINMU', 'NICE', 'SAVA', 'SSP',
       'AGRX', 'EPIX', 'GIPR', 'CHDN', 'WTER', 'MMSI', 'VECO', 'AUID',
       'HSTO', 'ARAV', 'CBRG', 'OLMA', 'LBC', 'PENN', 'LBRDK', 'MEDS',
       'AIP', 'UGRO', 'SLDP', 'ATLCP', 'VRM', 'MNRO', 'ATVI', 'LHCG',
       'TBSA', 'PBTS', 'PTRA', 'JRSH', 'VRA', 'PLMR', 'SEDG', 'MOGO',
       'ENTA', 'CFVI', 'NWLI', 'HONE', 'API', 'PYR', 'ESPR', 'EDNC',
       'BGCP', 'VCSA', 'XSPA', 'DTRTU', 'AVAV', 'COVA', 'BCRX', 'XNCR',
       'SYTA', 'MTTR', 'KYMR', 'ARQT', 'CCAIU', 'OCX', 'NNBR', 'FGBI',
       'GWRS', 'ALF', 'CMLS', 'CLNN', 'BLNGU', 'MNMD', 'MNTS', 'OTIC',
       'CBNK', 'LGIH', 'USIO', 'MREO', 'PINC', 'HARP', 'GRABW', 'FMNB',
       'HUT', 'SCHN', 'FRTA', 'ACRX', 'WMPN', 'GNFT', 'VNET', 'BTWN',
       'PETV', 'CTKB', 'XAIR', 'PODD', 'AAON', 'CHPM', 'LGO', 'DXPE',
       'VIOT', 'AGBA', 'GNCA', 'SCLE', 'STX', 'CDXC', 'GSMG', 'PONO',
       'TTWO', 'GPRO', 'MGNI', 'LIZI', 'COGT', 'GNTA', 'LVTX', 'TCRR',
       'PNBK', 'HBP', 'IAC', 'IGNY', 'AMZN', 'VIASP', 'ALT', 'PANW',
       'CZWI', 'PTICU', 'IRBT', 'NVSA', 'KBNT', 'BON', 'ENVB', 'JG',
       'XCUR', 'GRCY', 'IPAR', 'PFIS', 'MNKD', 'BENE', 'OBNK', 'SNBR',
       'USEG', 'SRSA', 'ECOR', 'UPTDU', 'TURN', 'TMPMU', 'EVAX', 'JRVR',
       'KNBE', 'INGN', 'LIFE', 'CWBR', 'LWLG', 'VSTM', 'HOPE', 'SWBI',
       'PNFP', 'GTYH', 'DATS', 'GNOG', 'VII', 'IMPL', 'CNOB', 'CLAQ',
       'PFC', 'ADGI', 'BLUE', 'CGNT', 'HBCP', 'LINC', 'WTRH', 'HEPA',
       'ZVO', 'WAFD', 'FORR', 'RIGL', 'GAIN', 'NCSM', 'FSRXU', 'APPF',
       'LYEL', 'TSCAP', 'CNCE', 'KNTE', 'QRVO', 'ESEA', 'PTON', 'QLYS',
       'APTX', 'NEPT', 'AVT', 'SENEB', 'EDTXU', 'IMAQU', 'KURA', 'TGVCU',
       'PFDR', 'UPC', 'QNST', 'AAOI', 'STRRP', 'CODA', 'LJAQU', 'TCVA',
       'PACX', 'ADV', 'DHBCU', 'DLCAU', 'ENDP', 'TECH', 'ERIC', 'CMRX',
       'PECO', 'TTGT', 'NNOX', 'THRM', 'PAVM', 'DALN', 'RPAY', 'MBTCU',
       'BSY', 'AHPAU', 'OTLK', 'GPCOU', 'ATEC', 'PRSR', 'NCACU', 'EVGN',
       'PPBT', 'TLS', 'XOS', 'SLNO', 'TPST', 'MERC', 'RICO', 'SHCAU',
       'KAIRU', 'DHBC', 'VNDA', 'CYRN', 'PTC', 'HSTM', 'THCPU', 'PGC',
       'SGBX', 'KSICU', 'SHQA', 'EZFL', 'HWELU', 'ADSE', 'MDXG', 'BRAG']
HOLDING = 0
TOTAL = 1
allList = test+train

# %%
SectorDict = {
    "Energy":"XLE","Technology":"XLK",
    "Communication Services":"XLC",
    "Consumer Staples":"XLP",
    "Health Care":"XLV",
    "Consumer Cyclical":"XLY",
    "Industrial":"XLI",
    "Utilities":"XLU",
    "Materials":"XLB",
    "Financial":"XLF",
    "Real Estate":"XLRE"}
sectorDfList = []
for sector in SectorDict.values():
    sectorDfList.append(pd.read_pickle("stockData/sectorCharts/"+sector+".pkl"))
goodSectorDf = sectorDfList[0].drop(['open','high','low','adjclose','close','ticker','volume','percent','MA30','MA30Slope','RS'],axis=1)
goodSectorDf['Sectors'] = [[] for _ in range(len(goodSectorDf))]
goodSectorDf.index = sectorDfList[0].index
index = 0
for date in sectorDfList[0].index:
    listOfSector = []
    for df in sectorDfList:
        try:
            #print(df.at[date,'MA30Slope'],df.at[date,'RS'])
            #!!!!!!!! or for new params
            #!!!!!!!!
            #!!!!!!!!
            #!!!!!!!!
            if  df.at[date,'MA30Slope'] > 0.992549883242513 and df.loc[date,'RS'] > -0.3044455098712273:
                if df.at[date,'close'] > df.at[date,'MA30']:
                    #print(df.at[date,'ticker'])
                    listOfSector.append(df.at[date,'ticker'])
        except: 
            pass
        # print(listOfSector)
    goodSectorDf.iat[index,0] = set(listOfSector)
    index = index + 1
removeList = []
for ticker in allList:
    try:
        df = getStage(ticker,[0.03361077383204303, 1.7466372328111242, -0.08498841770875612, 0.926192276854965, 1.1764676012556523, 1.1405501342698643, 0.8517616225271734, 0.8691969716399011, 1.268490629719207, 1.0013386634337298, 0.07551020458494859, 0.9489349345040117, 0.996709764664632, 0.9485725801058837, 0.9857019510456804],goodSectorDf)
        if df.empty:
            removeList.append(ticker)
    except:
        removeList.append(ticker)
print(removeList)

# %%
for ticker in removeList:
    if ticker in test:
        test.remove(ticker)
    if ticker in train:
        train.remove(ticker)
    if ticker in allList:
        allList.remove(ticker)

# %%
def calculateGroupReturn(list):
    monthlyReturn = pd.read_pickle("transactionTemplate.pkl")
    monthlyReturn = monthlyReturn.resample('M').mean()
    monthlyReturn.index = monthlyReturn.index.strftime("%Y:%m")
    currentColumn = -1
    for symbol in list:
        if symbol in monthlyReturn.columns:
            continue
        try:
            df = pd.read_pickle("stockData/nyseNasdaq/"+symbol+".pkl")
        except:
            print(symbol)
            continue
        if not (df['close'] != 0).all() or df.empty:
            if df.empty:
                print(symbol)
            continue
        monthlyReturn[symbol] = 1
        currentColumn += 1
        monthCheck = df.index[0].strftime("%Y:%m")
        lastPrice = df.iat[0,0]
        initialPrice = df.iat[0,0]
        for index, element in df.iterrows():
            if (index.strftime("%Y:%m") != monthCheck):
                if (initialPrice == 0): continue
                if (lastPrice / initialPrice >= 1.01 and lastPrice / initialPrice < 2):
                    rowNumber = monthlyReturn.index.get_loc(index.strftime("%Y:%m"))
                    monthlyReturn.iat[rowNumber, currentColumn] = (lastPrice / initialPrice)
                initialPrice = element[0]
                lastPrice = element[0]
                monthCheck = index.strftime("%Y:%m")
            lastPrice = element[0]
    return monthlyReturn

# %%
warnings.filterwarnings("ignore", category=pd.errors.PerformanceWarning) 
listOfDf = calculateGroupReturn(allList)
ratio = [1,1]
for i in range(2):
    if i == 0:
        l = test
    else:
        l = train
    index = 0
    while index != len(l):
        if l[index] not in listOfDf.columns:
            l = np.delete(l, index)
        else:
            index += 1
    for index, element in listOfDf[l].iterrows():
        #print(element.to_list())
        listOfStockRet = element.to_list()
        while 1.0 in listOfStockRet:
            listOfStockRet.remove(1.0)
        if len(listOfStockRet) != 0:
            ratio[i] = ratio[i] * np.mean(listOfStockRet)     
ratio[1] = ratio[1] / ratio[0]
ratio[0] = 1.0
print(ratio)
# Out:
# [1.0, 0.7051849488592921]

# %%
def evalFit(params, tickers, goodSectorDf):
        transactionFit = pd.read_pickle("transactionTemplate.pkl")
        transactionFit['holding'] = np.empty((len(transactionFit), 0)).tolist()
        #print("Reach #1")
        for symbol in tickers:
            df = getStage(symbol,params,goodSectorDf)
            buyDf = pd.read_pickle('stockData/nyseNasdaq/'+symbol+'Buy.pkl')
            inStage = False
            buyTwice = False
            if df.empty:
                continue
            if buyDf['open'].eq(0).any().any():
                continue
            for index, element in df.iterrows():
                open = 0
                monday = index + timedelta(3)
                i = transactionFit.index.get_loc(index)
                if element.Stage == "Stage 2" or element.Stage == "Buy":
                    if monday in buyDf.index:
                        open = buyDf.at[monday,'open']
                    else:
                        open = element.close
                    #delete
                    transactionFit.iat[int(i),HOLDING].append((symbol,open,0))
                    if buyTwice:
                        transactionFit.iat[i, HOLDING].append((symbol,open,0))
                    if element.Stage == "Buy" and inStage:
                        transactionFit.iat[i, HOLDING].append((symbol,open,0))
                        buyTwice = True
                    inStage = True
                    continue
                if "Sell" == element.Stage[0:4]:
                    if monday in buyDf.index:
                        open = buyDf.at[monday,'open']
                    else:
                        open = element.close
                    transactionFit.iat[i, HOLDING].append((symbol,open,-1))
                    if buyTwice:
                        transactionFit.iat[i, HOLDING].append((symbol,open,-1))
                    inStage = False
                    buyTwice = False
        #print("Reach #2")
        total = 100
        first = True
        transactionFitCopy = transactionFit
        transactionFitCopy['total'] = 0
        transactionFitCopy.to_csv("onlyShare.csv")
        #print("Reach #3")
        for index, element in transactionFitCopy.iterrows():
            indexNum = transactionFitCopy.index.get_loc(index)
            if first:
                first = False
                transactionFitCopy.iat[indexNum,1] = 100
                # print(i,transactionFitCopy.iat[i,1],"#1")
                continue
            if len(element.holding) == 0:
                transactionFitCopy.iat[indexNum,1] = transactionFitCopy.iat[indexNum-1,1]
                # print(i,transactionFitCopy.iat[i,1],"#2")
                continue
            else:
                prevData = transactionFitCopy.iat[indexNum-1, 0]
                if len(prevData):
                    total = 0
                    removeList = []
                    close = 0
                    for i in range(len(prevData)):
                        for j in range(len(element.holding)):
                            if element.holding[j][0] == prevData[i][0]:
                                close = element.holding[j][1]
                                if element.holding[j][2] == -1:
                                    removeList.append(element.holding[j])
                                break
                        total += close*prevData[i][2]
                    transactionFitCopy.iat[indexNum,1] = total
                    # print(i,transactionFitCopy.iat[indexNum,1],"#3")
                    for delete in removeList:
                        if delete in element.holding:
                            element.holding.remove(delete)
                else:
                    transactionFitCopy.iat[indexNum,1] = transactionFitCopy.iat[indexNum-1,1]
                    # print(i,transactionFitCopy.iat[i,1],"#4")
            if len(element.holding):
                allocation = total/len(element.holding)
            for i in range(len(element.holding)):
                element.holding[i] = (element.holding[i][0],element.holding[i][1],allocation/element.holding[i][1])
        stockHolding  = 0
        transactionFitCopy.to_csv("estimatorTest.csv")
        for i in transactionFitCopy.iterrows():
            stockHolding += len(i[1]['holding'])
        if stockHolding/(transactionFitCopy.shape[0])<(len(tickers)/1000) or transactionFitCopy.iat[-1,TOTAL]<=100:
            print(stockHolding)
            print(transactionFitCopy.iloc[-1]['total'])
            return -1
        return transactionFitCopy.iloc[-1]['total']

# %%
def evalReturn(params,tickerList):
    now = datetime.now()
    now = now.strftime("%Y-%m-%d-%H:%M")
    transaction = pd.read_pickle("transactionTemplate.pkl")
    transaction['holding'] = np.empty((len(transaction), 0)).tolist()
    SectorDict = {
    "Energy":"XLE","Technology":"XLK",
    "Communication Services":"XLC",
    "Consumer Staples":"XLP",
    "Health Care":"XLV",
    "Consumer Cyclical":"XLY",
    "Industrial":"XLI",
    "Utilities":"XLU",
    "Materials":"XLB",
    "Financial":"XLF",
    "Real Estate":"XLRE"}
    sectorDfList = []
    for sector in SectorDict.values():
        sectorDfList.append(pd.read_pickle("stockData/sectorCharts/"+sector+".pkl"))
        goodSectorDf = sectorDfList[0].drop(['open','high','low','adjclose','close','ticker','volume','percent','MA30','MA30Slope','RS'],axis=1)
        goodSectorDf['Sectors'] = [[] for _ in range(len(goodSectorDf))]
        goodSectorDf.index = sectorDfList[0].index
        index = 0
        for date in sectorDfList[0].index:
            listOfSector = []
            for df in sectorDfList:
                try:
                    # print(df.at[date,'MA30Slope'],df.at[date,'RS'])
                    # print(individual[0][9],individual[0][10])
                    if  df.at[date,'MA30Slope'] > params[9] and df.at[date,'RS'] > params[10]:
                        if df.at[date,'close'] > df.at[date,'MA30']:
                            # print(df.at[date,'ticker'])
                            listOfSector.append(df.at[date,'ticker'])
                except: 
                    pass
                # print(listOfSector)
            goodSectorDf.iat[index,0] = set(listOfSector)
            index = index + 1
    result = evalFit(params,tickerList,goodSectorDf)
    return result

# %%
params = [0.46545995582690736, 2.490363482760684, 0.31971683124089534, 0.9429489298680978, 1.074968148668514, 1.2245010557722869, 0.9722725105230703, 0.8140395822362908, 1.288299256208624, 0.9880013050035417, -0.036857127251855436, 0.8904945991051272, 0.9949951868655408, 0.7953917515639831, 0.9837375685920343]
print(evalReturn(params,test))
# Out:
# 5182.510202603558

# %%
params = [0.46545995582690736, 2.490363482760684, 0.31971683124089534, 0.9429489298680978, 1.074968148668514, 1.2245010557722869, 0.9722725105230703, 0.8140395822362908, 1.288299256208624, 0.9880013050035417, -0.036857127251855436, 0.8904945991051272, 0.9949951868655408, 0.7953917515639831, 0.9837375685920343]
print(evalReturn(params,train))
# Out:
# 88159.74865808006

# %%
params = [0.12653685818638938, 0.7357373088138175, 0.0528693027845398, 1.0564618424013552, 1.033172812672914, 1.0725520833868167, 0.9311060920008604, 0.9289610333667836, 1.3664058689819645, 0.9973147969797425, 0.0661717675072317, 0.9602076305810286, 0.997677375390358, 0.8935459147685849, 0.9821336322668753]
print(evalReturn(params,test))
# Out:
# 4695.057827055304

# %%
params = [0.12653685818638938, 0.7357373088138175, 0.0528693027845398, 1.0564618424013552, 1.033172812672914, 1.0725520833868167, 0.9311060920008604, 0.9289610333667836, 1.3664058689819645, 0.9973147969797425, 0.0661717675072317, 0.9602076305810286, 0.997677375390358, 0.8935459147685849, 0.9821336322668753]
print(evalReturn(params,train))
# Out:
# 59154.33640755447

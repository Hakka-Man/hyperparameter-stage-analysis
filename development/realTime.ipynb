# %%
from stage import getStage, fullPrint
import pandas as pd
import datetime
from datetime import date, datetime
import yahoo_fin.stock_info as yf

# %%
coef = [0.12670742563044157, 1.3452537366729918, 0.3412355334740049, 0.9200419740552854, 1.3452226595229195, 1.1040652469472896, 0.8494658205377208, 0.8112883127968283, 1.377102695533595, 0.9876890207638959, -0.07062041016478565, 0.8782739433090022, 1.0107646230781666, 0.8655665054131219, 0.9883863405639555]

# %%
SectorDict = {
    "Energy":"XLE","Technology":"XLK",
    "Communication Services":"XLC",
    "Consumer Staples":"XLP",
    "Health Care":"XLV",
    "Consumer Cyclical":"XLY",
    "Industrial":"XLI",
    "Utilities":"XLU",
    "Materials":"XLB",
    "Financial":"XLF",
    "Real Estate":"XLRE"}
sectorDfList = []
for sector in SectorDict.values():
    sectorDfList.append(pd.read_pickle("stockData/sectorCharts/"+sector+".pkl"))
goodSectorDf = sectorDfList[0].drop(['open','high','low','adjclose','close','ticker','volume','percent','MA30','MA30Slope','RS'],axis=1)
goodSectorDf['Sectors'] = [[] for _ in range(len(goodSectorDf))]
goodSectorDf.index = sectorDfList[0].index
index = 0
for date in sectorDfList[0].index:
    listOfSector = []
    for df in sectorDfList:
        try:
            #print(df.at[date,'MA30Slope'],df.at[date,'RS'])
            #!!!!!!!! or for new params
            #!!!!!!!!
            #!!!!!!!!
            #!!!!!!!!
            if  df.at[date,'MA30Slope'] > coef[9] and df.loc[date,'RS'] > coef[10]:
                if df.at[date,'close'] > df.at[date,'MA30']:
                    #print(df.at[date,'ticker'])
                    listOfSector.append(df.at[date,'ticker'])
        except: 
            pass
        # print(listOfSector)
    goodSectorDf.iat[index,0] = set(listOfSector)
    index = index + 1
    #print(goodSectorDf.at[date,'Sectors'])
fullPrint(goodSectorDf)
# Out:
#                                                       Sectors
# 1999-01-08                                                 {}
# 1999-01-15                                                 {}
# 1999-01-22                                                 {}
# 1999-01-29                                                 {}
# 1999-02-05                                                 {}
# 1999-02-12                                                 {}
# 1999-02-19                                                 {}
# 1999-02-26                                                 {}
# 1999-03-05                                                 {}
# 1999-03-12                                                 {}
# 1999-03-19                                                 {}
# 1999-03-26                                                 {}
# 1999-04-09                                                 {}
# 1999-04-16                                                 {}
# 1999-04-23                                                 {}
# 1999-04-30                                                 {}
# 1999-05-07                                                 {}
# 1999-05-14                                                 {}
# 1999-05-21                                                 {}
# 1999-05-28                                                 {}
# 1999-06-04                                                 {}
# 1999-06-11                                                 {}
# 1999-06-18                                                 {}
# 1999-06-25                                                 {}
# 1999-07-02                                                 {}
# 1999-07-09                                                 {}
# 1999-07-16                                                 {}
# 1999-07-23                                                 {}
# 1999-07-30                                                 {}
# 1999-08-06                                                 {}
# 1999-08-13                                                 {}
# 1999-08-20                               {XLI, XLK, XLB, XLE}
# 1999-08-27                               {XLI, XLK, XLB, XLE}
# 1999-09-03                               {XLI, XLK, XLB, XLE}
# 1999-09-10                                    {XLI, XLK, XLE}
# 1999-09-17                                    {XLI, XLK, XLE}
# 1999-09-24                                              {XLK}
# 1999-10-01                                              {XLK}
# 1999-10-08                                         {XLI, XLK}
# 1999-10-15                                              {XLK}
# 1999-10-22                                              {XLK}
# 1999-10-29                                              {XLK}
# 1999-11-05                                                 {}
# 1999-11-12                                              {XLK}
# 1999-11-19                                              {XLK}
# 1999-11-26                                              {XLK}
# 1999-12-03                                              {XLK}
# 1999-12-10                                                 {}
# 1999-12-17                                                 {}
# 1999-12-31                                                 {}
# 2000-01-07                                                 {}
# 2000-01-14                                                 {}
# 2000-01-21                                                 {}
# 2000-01-28                                                 {}
# 2000-02-04                                                 {}
# 2000-02-11                                                 {}
# 2000-02-18                                                 {}
# 2000-02-25                                                 {}
# 2000-03-03                                                 {}
# 2000-03-10                                                 {}
# 2000-03-17                                                 {}
# 2000-03-24                                                 {}
# 2000-03-31                                                 {}
# 2000-04-07                                                 {}
# 2000-04-14                                                 {}
# 2000-04-28                                                 {}
# 2000-05-05                                                 {}
# 2000-05-12                                                 {}
# 2000-05-19                                              {XLE}
# 2000-05-26                                         {XLF, XLE}
# 2000-06-02                                              {XLK}
# 2000-06-09                                              {XLK}
# 2000-06-16                                         {XLK, XLE}
# 2000-06-23                                         {XLK, XLE}
# 2000-06-30                                              {XLK}
# 2000-07-07                                              {XLK}
# 2000-07-14                                              {XLK}
# 2000-07-21                                    {XLI, XLK, XLE}
# 2000-07-28                               {XLF, XLU, XLE, XLP}
# 2000-08-04                     {XLE, XLP, XLI, XLV, XLF, XLU}
# 2000-08-11                     {XLE, XLP, XLI, XLV, XLF, XLU}
# 2000-08-18                     {XLE, XLP, XLI, XLV, XLF, XLU}
# 2000-08-25                {XLE, XLP, XLI, XLK, XLV, XLF, XLU}
# 2000-09-01                     {XLE, XLP, XLI, XLK, XLF, XLU}
# 2000-09-08                          {XLE, XLP, XLI, XLF, XLU}
# 2000-09-15                          {XLE, XLP, XLI, XLF, XLU}
# 2000-09-22                          {XLE, XLP, XLI, XLF, XLU}
# 2000-09-29                          {XLE, XLP, XLI, XLF, XLU}
# 2000-10-06                          {XLE, XLP, XLI, XLF, XLU}
# 2000-10-13                          {XLE, XLP, XLI, XLF, XLU}
# 2000-10-20                               {XLF, XLU, XLE, XLP}
# 2000-10-27                          {XLE, XLP, XLI, XLF, XLU}
# 2000-11-03                     {XLE, XLP, XLI, XLV, XLF, XLU}
# 2000-11-10                          {XLE, XLP, XLI, XLF, XLU}
# 2000-11-17                          {XLE, XLP, XLI, XLF, XLU}
# 2000-11-24                               {XLI, XLU, XLE, XLP}
# 2000-12-01                          {XLP, XLI, XLF, XLB, XLU}
# 2000-12-08                          {XLP, XLI, XLF, XLB, XLU}
# 2000-12-15                          {XLP, XLI, XLF, XLB, XLU}
# 2000-12-22                     {XLE, XLP, XLI, XLF, XLB, XLU}
# 2000-12-29                {XLE, XLP, XLI, XLY, XLF, XLB, XLU}
# 2001-01-05                {XLE, XLP, XLI, XLY, XLF, XLB, XLU}
# 2001-01-12                {XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-01-19                {XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-01-26           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-02-02           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-02-09                {XLE, XLP, XLV, XLY, XLF, XLB, XLU}
# 2001-02-16                {XLE, XLP, XLV, XLY, XLF, XLB, XLU}
# 2001-02-23                               {XLB, XLU, XLY, XLP}
# 2001-03-02                          {XLE, XLP, XLY, XLB, XLU}
# 2001-03-09                               {XLB, XLY, XLE, XLP}
# 2001-03-16                                         {XLB, XLY}
# 2001-03-23                                              {XLB}
# 2001-03-30                                         {XLB, XLY}
# 2001-04-06                                         {XLB, XLY}
# 2001-04-20                               {XLB, XLE, XLV, XLY}
# 2001-04-27                {XLE, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-05-04                {XLE, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-05-11                     {XLE, XLI, XLV, XLY, XLB, XLU}
# 2001-05-18                {XLE, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-05-25                {XLE, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-06-01                {XLE, XLI, XLV, XLY, XLF, XLB, XLU}
# 2001-06-08                     {XLE, XLI, XLV, XLY, XLF, XLB}
# 2001-06-15                               {XLB, XLE, XLV, XLY}
# 2001-06-22                               {XLF, XLB, XLV, XLY}
# 2001-06-29                               {XLF, XLB, XLV, XLY}
# 2001-07-06                                         {XLB, XLV}
# 2001-07-13                               {XLF, XLB, XLV, XLY}
# 2001-07-20                                    {XLB, XLV, XLY}
# 2001-07-27                                    {XLB, XLV, XLY}
# 2001-08-03                               {XLF, XLB, XLV, XLY}
# 2001-08-10                                         {XLB, XLY}
# 2001-08-17                                         {XLB, XLP}
# 2001-08-24                                    {XLB, XLV, XLP}
# 2001-08-31                                              {XLB}
# 2001-09-07                                                 {}
# 2001-09-21                                                 {}
# 2001-09-28                                                 {}
# 2001-10-05                                              {XLP}
# 2001-10-12                                              {XLP}
# 2001-10-19                                              {XLP}
# 2001-10-26                                              {XLP}
# 2001-11-02                                              {XLP}
# 2001-11-09                                              {XLP}
# 2001-11-16                                    {XLB, XLY, XLP}
# 2001-11-23                                    {XLB, XLY, XLP}
# 2001-11-30                                    {XLB, XLY, XLP}
# 2001-12-07                          {XLP, XLK, XLV, XLY, XLB}
# 2001-12-14                                              {XLY}
# 2001-12-21                                    {XLI, XLY, XLP}
# 2001-12-28                {XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2002-01-04                     {XLI, XLK, XLV, XLY, XLF, XLB}
# 2002-01-11                                    {XLK, XLV, XLY}
# 2002-01-18                                    {XLF, XLV, XLY}
# 2002-01-25                               {XLF, XLB, XLV, XLY}
# 2002-02-01                               {XLB, XLY, XLV, XLP}
# 2002-02-08                                    {XLB, XLV, XLY}
# 2002-02-15                               {XLB, XLY, XLV, XLP}
# 2002-02-22                               {XLB, XLY, XLV, XLP}
# 2002-03-01                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2002-03-08           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2002-03-15                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2002-03-22                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2002-04-05                     {XLE, XLI, XLV, XLY, XLF, XLB}
# 2002-04-12                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2002-04-19                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2002-04-26                          {XLE, XLV, XLY, XLF, XLB}
# 2002-05-03                          {XLE, XLV, XLY, XLF, XLB}
# 2002-05-10                          {XLE, XLV, XLY, XLF, XLB}
# 2002-05-17                          {XLE, XLV, XLY, XLF, XLB}
# 2002-05-24                          {XLE, XLV, XLY, XLF, XLB}
# 2002-05-31                          {XLE, XLV, XLY, XLF, XLB}
# 2002-06-07                                         {XLB, XLV}
# 2002-06-14                                              {XLB}
# 2002-06-21                                              {XLB}
# 2002-06-28                                              {XLB}
# 2002-07-05                                              {XLB}
# 2002-07-12                                                 {}
# 2002-07-19                                                 {}
# 2002-07-26                                                 {}
# 2002-08-02                                                 {}
# 2002-08-09                                                 {}
# 2002-08-16                                                 {}
# 2002-08-23                                                 {}
# 2002-08-30                                                 {}
# 2002-09-06                                                 {}
# 2002-09-13                                                 {}
# 2002-09-20                                                 {}
# 2002-09-27                                                 {}
# 2002-10-04                                                 {}
# 2002-10-11                                                 {}
# 2002-10-18                                              {XLV}
# 2002-10-25                                                 {}
# 2002-11-01                                                 {}
# 2002-11-08                                              {XLV}
# 2002-11-15                                         {XLK, XLV}
# 2002-11-22                                    {XLK, XLV, XLF}
# 2002-11-29                               {XLK, XLB, XLV, XLF}
# 2002-12-06                                         {XLK, XLV}
# 2002-12-13                                              {XLK}
# 2002-12-20                                              {XLK}
# 2002-12-27                                              {XLK}
# 2003-01-03                          {XLE, XLK, XLV, XLF, XLB}
# 2003-01-10                               {XLK, XLB, XLV, XLF}
# 2003-01-17                               {XLK, XLB, XLV, XLF}
# 2003-01-24                                                 {}
# 2003-01-31                                                 {}
# 2003-02-07                                                 {}
# 2003-02-14                                                 {}
# 2003-02-21                                         {XLK, XLE}
# 2003-02-28                                              {XLE}
# 2003-03-07                                              {XLE}
# 2003-03-14                                                 {}
# 2003-03-21                                    {XLK, XLE, XLV}
# 2003-03-28                                    {XLK, XLE, XLV}
# 2003-04-04                                    {XLK, XLE, XLV}
# 2003-04-11                                         {XLE, XLV}
# 2003-04-25                                         {XLK, XLF}
# 2003-05-02                                              {XLK}
# 2003-05-09                                              {XLK}
# 2003-05-16                                         {XLK, XLU}
# 2003-05-23                                         {XLK, XLU}
# 2003-05-30                                         {XLK, XLU}
# 2003-06-06                                         {XLK, XLU}
# 2003-06-13                               {XLF, XLU, XLE, XLY}
# 2003-06-20                               {XLI, XLK, XLU, XLE}
# 2003-06-27                {XLE, XLI, XLV, XLY, XLF, XLB, XLU}
# 2003-07-11                                              {XLU}
# 2003-07-18                                              {XLU}
# 2003-07-25                                                 {}
# 2003-08-01                                                 {}
# 2003-08-08                                         {XLF, XLY}
# 2003-08-15                                              {XLY}
# 2003-08-22                                              {XLY}
# 2003-08-29                                                 {}
# 2003-09-05                                                 {}
# 2003-09-12                                                 {}
# 2003-09-19                                                 {}
# 2003-09-26                                                 {}
# 2003-10-03                                                 {}
# 2003-10-10                                                 {}
# 2003-10-17                                                 {}
# 2003-10-24                                                 {}
# 2003-10-31                                                 {}
# 2003-11-07                                                 {}
# 2003-11-14                                              {XLK}
# 2003-11-21                                              {XLK}
# 2003-11-28                                              {XLK}
# 2003-12-05                                         {XLK, XLB}
# 2003-12-12                                    {XLI, XLK, XLB}
# 2003-12-19                                    {XLI, XLK, XLB}
# 2003-12-26                                    {XLI, XLK, XLB}
# 2004-01-02                                    {XLI, XLK, XLB}
# 2004-01-09                                         {XLK, XLB}
# 2004-01-16                                              {XLK}
# 2004-01-23                                              {XLK}
# 2004-01-30                                    {XLI, XLK, XLB}
# 2004-02-06                     {XLE, XLI, XLK, XLY, XLF, XLB}
# 2004-02-13                {XLE, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-02-20           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-02-27           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-03-05                {XLE, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-03-12           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-03-19           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2004-03-26                {XLE, XLP, XLI, XLY, XLF, XLB, XLU}
# 2004-04-02      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2004-04-16           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2004-04-23      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2004-04-30                     {XLE, XLP, XLI, XLV, XLY, XLU}
# 2004-05-07                               {XLI, XLE, XLV, XLP}
# 2004-05-14                                    {XLE, XLV, XLP}
# 2004-05-21                                    {XLE, XLV, XLP}
# 2004-05-28           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2004-06-04                {XLE, XLP, XLI, XLV, XLY, XLF, XLU}
# 2004-06-18           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2004-06-25           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-07-02                          {XLE, XLP, XLI, XLB, XLU}
# 2004-07-09                          {XLE, XLP, XLI, XLB, XLU}
# 2004-07-16                          {XLE, XLP, XLI, XLB, XLU}
# 2004-07-23                                         {XLI, XLE}
# 2004-07-30                               {XLI, XLU, XLB, XLE}
# 2004-08-06                                         {XLU, XLE}
# 2004-08-13                                         {XLU, XLE}
# 2004-08-20                               {XLI, XLU, XLB, XLE}
# 2004-08-27                          {XLE, XLI, XLF, XLB, XLU}
# 2004-09-03                     {XLE, XLP, XLI, XLF, XLB, XLU}
# 2004-09-10                     {XLE, XLI, XLY, XLF, XLB, XLU}
# 2004-09-17                     {XLE, XLI, XLY, XLF, XLB, XLU}
# 2004-09-24                          {XLE, XLI, XLY, XLB, XLU}
# 2004-10-01                     {XLE, XLI, XLY, XLF, XLB, XLU}
# 2004-10-08                     {XLE, XLI, XLY, XLF, XLB, XLU}
# 2004-10-15                          {XLE, XLI, XLY, XLB, XLU}
# 2004-10-22                          {XLE, XLI, XLY, XLB, XLU}
# 2004-10-29                {XLE, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-11-05           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-11-12           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-11-19           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-11-26           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-12-03                {XLE, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-12-10                {XLE, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-12-17                {XLE, XLI, XLK, XLY, XLF, XLB, XLU}
# 2004-12-31                {XLE, XLI, XLK, XLY, XLF, XLB, XLU}
# 2005-01-07           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2005-01-14           {XLE, XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2005-01-21                {XLE, XLP, XLI, XLY, XLF, XLB, XLU}
# 2005-01-28           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2005-02-04      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2005-02-11      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2005-02-18      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2005-02-25      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2005-03-04      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2005-03-11                {XLE, XLI, XLV, XLY, XLF, XLB, XLU}
# 2005-03-18                          {XLE, XLI, XLY, XLB, XLU}
# 2005-04-01                     {XLE, XLP, XLI, XLV, XLB, XLU}
# 2005-04-08                     {XLE, XLP, XLI, XLV, XLB, XLU}
# 2005-04-15                               {XLU, XLE, XLV, XLP}
# 2005-04-22                                    {XLU, XLE, XLV}
# 2005-04-29                               {XLU, XLE, XLV, XLP}
# 2005-05-06                               {XLU, XLE, XLV, XLP}
# 2005-05-13                                    {XLU, XLE, XLV}
# 2005-05-20                          {XLE, XLP, XLI, XLV, XLU}
# 2005-05-27                {XLE, XLP, XLI, XLK, XLV, XLF, XLU}
# 2005-06-03                     {XLE, XLP, XLI, XLK, XLV, XLU}
# 2005-06-10                          {XLE, XLP, XLK, XLV, XLU}
# 2005-06-17           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2005-06-24                                    {XLU, XLE, XLV}
# 2005-07-01                               {XLU, XLE, XLV, XLF}
# 2005-07-08                     {XLE, XLK, XLV, XLY, XLF, XLU}
# 2005-07-15                {XLE, XLP, XLK, XLV, XLY, XLF, XLU}
# 2005-07-22           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2005-07-29           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2005-08-05                     {XLE, XLK, XLV, XLY, XLF, XLU}
# 2005-08-12                {XLE, XLI, XLK, XLV, XLY, XLF, XLU}
# 2005-08-19                     {XLE, XLK, XLV, XLY, XLF, XLU}
# 2005-08-26                          {XLE, XLK, XLV, XLY, XLU}
# 2005-09-02                          {XLE, XLK, XLV, XLF, XLU}
# 2005-09-09           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2005-09-16                     {XLE, XLI, XLK, XLV, XLF, XLU}
# 2005-09-23                          {XLE, XLK, XLV, XLF, XLU}
# 2005-09-30                {XLE, XLP, XLI, XLK, XLV, XLF, XLU}
# 2005-10-07                                    {XLK, XLU, XLE}
# 2005-10-14                                              {XLE}
# 2005-10-21                                         {XLF, XLE}
# 2005-10-28                                    {XLF, XLE, XLP}
# 2005-11-04                                    {XLK, XLE, XLF}
# 2005-11-11                                    {XLK, XLE, XLF}
# 2005-11-18                                    {XLK, XLE, XLF}
# 2005-11-25                                    {XLK, XLE, XLF}
# 2005-12-02                                    {XLK, XLE, XLF}
# 2005-12-09                     {XLE, XLI, XLK, XLF, XLB, XLU}
# 2005-12-16                     {XLE, XLI, XLK, XLF, XLB, XLU}
# 2005-12-23                {XLE, XLI, XLK, XLV, XLF, XLB, XLU}
# 2005-12-30                {XLE, XLP, XLI, XLK, XLV, XLF, XLB}
# 2006-01-06                     {XLE, XLI, XLK, XLF, XLB, XLU}
# 2006-01-13                     {XLE, XLI, XLK, XLF, XLB, XLU}
# 2006-01-20                {XLE, XLI, XLK, XLV, XLF, XLB, XLU}
# 2006-01-27                          {XLE, XLI, XLK, XLF, XLB}
# 2006-02-03                     {XLE, XLI, XLK, XLV, XLF, XLB}
# 2006-02-10                     {XLE, XLI, XLK, XLV, XLF, XLB}
# 2006-02-17           {XLE, XLP, XLI, XLK, XLV, XLF, XLB, XLU}
# 2006-02-24           {XLE, XLP, XLI, XLK, XLV, XLF, XLB, XLU}
# 2006-03-03           {XLE, XLP, XLI, XLK, XLV, XLF, XLB, XLU}
# 2006-03-10                     {XLP, XLI, XLK, XLV, XLF, XLB}
# 2006-03-17           {XLE, XLP, XLI, XLK, XLV, XLF, XLB, XLU}
# 2006-03-24                {XLE, XLP, XLI, XLK, XLV, XLF, XLB}
# 2006-03-31                     {XLE, XLP, XLI, XLK, XLF, XLB}
# 2006-04-07                          {XLE, XLI, XLK, XLF, XLB}
# 2006-04-21                {XLE, XLP, XLI, XLK, XLY, XLF, XLB}
# 2006-04-28                {XLE, XLP, XLI, XLK, XLY, XLF, XLB}
# 2006-05-05                {XLE, XLP, XLI, XLK, XLY, XLF, XLB}
# 2006-05-12                     {XLE, XLP, XLI, XLY, XLF, XLB}
# 2006-05-19                     {XLE, XLP, XLI, XLY, XLF, XLB}
# 2006-05-26                     {XLE, XLP, XLI, XLY, XLF, XLB}
# 2006-06-02                {XLE, XLP, XLI, XLY, XLF, XLB, XLU}
# 2006-06-09                               {XLI, XLF, XLU, XLP}
# 2006-06-16                                    {XLI, XLU, XLP}
# 2006-06-23                                         {XLI, XLP}
# 2006-06-30                          {XLE, XLP, XLI, XLB, XLU}
# 2006-07-07                          {XLE, XLP, XLI, XLB, XLU}
# 2006-07-14                                    {XLU, XLE, XLP}
# 2006-07-21                                         {XLU, XLP}
# 2006-07-28                          {XLE, XLP, XLV, XLF, XLU}
# 2006-08-04                          {XLE, XLP, XLV, XLF, XLU}
# 2006-08-11                          {XLE, XLP, XLV, XLF, XLU}
# 2006-08-18                          {XLE, XLP, XLV, XLF, XLU}
# 2006-08-25                          {XLE, XLP, XLV, XLF, XLU}
# 2006-09-01                {XLE, XLP, XLK, XLV, XLF, XLB, XLU}
# 2006-09-08                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2006-09-15                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2006-09-22                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2006-09-29                {XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2006-10-06           {XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-10-13           {XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-10-20           {XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-10-27      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-11-03      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-11-10      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-11-17           {XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-11-24      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-12-01      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-12-08           {XLE, XLP, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-12-15           {XLE, XLP, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-12-22      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2006-12-29      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-01-05                {XLP, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-01-12                {XLP, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-01-19                {XLP, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-01-26                {XLP, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-02-02                {XLP, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-02-09                     {XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-02-16                               {XLF, XLK, XLB, XLY}
# 2007-02-23                          {XLI, XLK, XLY, XLB, XLU}
# 2007-03-02                               {XLI, XLU, XLB, XLY}
# 2007-03-09                     {XLI, XLK, XLY, XLF, XLB, XLU}
# 2007-03-16                          {XLI, XLK, XLY, XLB, XLU}
# 2007-03-23                     {XLI, XLK, XLY, XLF, XLB, XLU}
# 2007-03-30                {XLE, XLP, XLI, XLK, XLY, XLB, XLU}
# 2007-04-13                {XLE, XLI, XLK, XLV, XLY, XLB, XLU}
# 2007-04-20      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-04-27           {XLE, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-05-04      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-05-11      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-05-18      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-05-25      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-06-01      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-06-08      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-06-15      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2007-06-22                {XLE, XLP, XLI, XLK, XLV, XLY, XLB}
# 2007-06-29           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2007-07-06           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2007-07-13           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2007-07-20           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2007-07-27                               {XLI, XLK, XLB, XLE}
# 2007-08-03                                    {XLI, XLK, XLE}
# 2007-08-10                               {XLI, XLK, XLE, XLP}
# 2007-08-17                                    {XLI, XLK, XLE}
# 2007-08-24                          {XLE, XLP, XLI, XLK, XLB}
# 2007-08-31                                    {XLI, XLK, XLE}
# 2007-09-07                                    {XLI, XLK, XLE}
# 2007-09-14                          {XLE, XLP, XLI, XLK, XLB}
# 2007-09-21                {XLE, XLP, XLI, XLK, XLV, XLB, XLU}
# 2007-09-28                     {XLE, XLP, XLI, XLK, XLV, XLB}
# 2007-10-05                               {XLI, XLK, XLB, XLE}
# 2007-10-12                               {XLI, XLK, XLB, XLE}
# 2007-10-19                               {XLI, XLK, XLB, XLE}
# 2007-10-26                               {XLI, XLK, XLB, XLE}
# 2007-11-02                               {XLI, XLK, XLB, XLE}
# 2007-11-09                               {XLU, XLB, XLE, XLP}
# 2007-11-16                          {XLE, XLP, XLK, XLV, XLU}
# 2007-11-23                                    {XLU, XLE, XLP}
# 2007-11-30                     {XLE, XLP, XLK, XLV, XLB, XLU}
# 2007-12-07                {XLE, XLP, XLI, XLK, XLV, XLB, XLU}
# 2007-12-14                     {XLE, XLP, XLK, XLV, XLB, XLU}
# 2007-12-21                          {XLE, XLP, XLK, XLB, XLU}
# 2007-12-28                     {XLE, XLP, XLK, XLV, XLB, XLU}
# 2008-01-04                                    {XLU, XLE, XLP}
# 2008-01-11                               {XLU, XLE, XLV, XLP}
# 2008-01-18                                                 {}
# 2008-01-25                                                 {}
# 2008-02-01                                              {XLB}
# 2008-02-08                                                 {}
# 2008-02-15                                                 {}
# 2008-02-22                                         {XLB, XLE}
# 2008-02-29                                         {XLB, XLE}
# 2008-03-07                                                 {}
# 2008-03-14                                              {XLE}
# 2008-03-28                                                 {}
# 2008-04-04                                    {XLB, XLE, XLP}
# 2008-04-11                                         {XLB, XLE}
# 2008-04-18                               {XLI, XLU, XLB, XLE}
# 2008-04-25                                    {XLI, XLB, XLE}
# 2008-05-02                     {XLE, XLP, XLI, XLY, XLB, XLU}
# 2008-05-09                                    {XLI, XLB, XLE}
# 2008-05-16                {XLE, XLP, XLI, XLK, XLY, XLB, XLU}
# 2008-05-23                               {XLU, XLB, XLE, XLP}
# 2008-05-30                {XLE, XLP, XLI, XLK, XLY, XLB, XLU}
# 2008-06-06                                    {XLK, XLB, XLE}
# 2008-06-13                          {XLE, XLP, XLK, XLB, XLU}
# 2008-06-20                                    {XLU, XLB, XLE}
# 2008-06-27                                              {XLE}
# 2008-07-11                                         {XLU, XLE}
# 2008-07-18                                                 {}
# 2008-07-25                                                 {}
# 2008-08-01                                                 {}
# 2008-08-08                                         {XLV, XLP}
# 2008-08-15                               {XLK, XLY, XLV, XLP}
# 2008-08-22                                              {XLP}
# 2008-08-29                                              {XLP}
# 2008-09-05                                              {XLP}
# 2008-09-12                                    {XLY, XLV, XLP}
# 2008-09-19                                                 {}
# 2008-09-26                                                 {}
# 2008-10-03                                                 {}
# 2008-10-10                                                 {}
# 2008-10-17                                                 {}
# 2008-10-24                                                 {}
# 2008-10-31                                                 {}
# 2008-11-07                                                 {}
# 2008-11-14                                                 {}
# 2008-11-21                                                 {}
# 2008-11-28                                                 {}
# 2008-12-05                                                 {}
# 2008-12-12                                                 {}
# 2008-12-19                                                 {}
# 2008-12-26                                                 {}
# 2009-01-02                                                 {}
# 2009-01-09                                                 {}
# 2009-01-16                                                 {}
# 2009-01-23                                                 {}
# 2009-01-30                                                 {}
# 2009-02-06                                                 {}
# 2009-02-13                                                 {}
# 2009-02-20                                                 {}
# 2009-02-27                                                 {}
# 2009-03-06                                                 {}
# 2009-03-13                                                 {}
# 2009-03-20                                                 {}
# 2009-03-27                                                 {}
# 2009-04-03                                              {XLK}
# 2009-04-17                                              {XLK}
# 2009-04-24                                         {XLK, XLY}
# 2009-05-01                                         {XLK, XLY}
# 2009-05-08                {XLE, XLP, XLI, XLK, XLV, XLY, XLB}
# 2009-05-15                          {XLE, XLK, XLV, XLY, XLB}
# 2009-05-22                {XLE, XLP, XLI, XLK, XLV, XLY, XLB}
# 2009-05-29                               {XLK, XLB, XLE, XLY}
# 2009-06-05                               {XLK, XLB, XLE, XLY}
# 2009-06-12                               {XLK, XLB, XLE, XLY}
# 2009-06-19                                    {XLK, XLB, XLY}
# 2009-06-26                                    {XLK, XLB, XLY}
# 2009-07-10                                         {XLK, XLY}
# 2009-07-17                                         {XLK, XLB}
# 2009-07-24                                         {XLK, XLB}
# 2009-07-31                                         {XLK, XLB}
# 2009-08-07                                    {XLK, XLB, XLY}
# 2009-08-14                                         {XLK, XLB}
# 2009-08-21                               {XLF, XLK, XLB, XLY}
# 2009-08-28                               {XLF, XLK, XLB, XLY}
# 2009-09-04                               {XLF, XLK, XLB, XLY}
# 2009-09-11                               {XLF, XLK, XLB, XLY}
# 2009-09-18                          {XLI, XLK, XLY, XLF, XLB}
# 2009-09-25                               {XLF, XLK, XLB, XLY}
# 2009-10-02                          {XLI, XLK, XLY, XLF, XLB}
# 2009-10-09                          {XLI, XLK, XLY, XLF, XLB}
# 2009-10-16                               {XLI, XLF, XLB, XLY}
# 2009-10-23                          {XLI, XLK, XLY, XLF, XLB}
# 2009-10-30                          {XLI, XLK, XLY, XLF, XLB}
# 2009-11-06                          {XLI, XLK, XLY, XLF, XLB}
# 2009-11-13                          {XLI, XLK, XLY, XLF, XLB}
# 2009-11-20           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2009-11-27           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2009-12-04                {XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2009-12-11                          {XLI, XLK, XLV, XLY, XLB}
# 2009-12-18                                    {XLI, XLK, XLY}
# 2010-01-08                          {XLI, XLK, XLY, XLF, XLB}
# 2010-01-15                     {XLI, XLK, XLV, XLY, XLF, XLB}
# 2010-01-22                     {XLI, XLK, XLV, XLY, XLF, XLB}
# 2010-01-29                     {XLP, XLI, XLK, XLV, XLY, XLF}
# 2010-02-05                     {XLE, XLP, XLI, XLK, XLV, XLY}
# 2010-02-12                {XLE, XLP, XLI, XLK, XLV, XLY, XLB}
# 2010-02-19                {XLE, XLI, XLK, XLV, XLY, XLF, XLB}
# 2010-02-26           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2010-03-05           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2010-03-12                {XLE, XLI, XLK, XLV, XLY, XLF, XLB}
# 2010-03-19                     {XLE, XLP, XLI, XLK, XLV, XLY}
# 2010-03-26                          {XLP, XLI, XLK, XLV, XLY}
# 2010-04-09                               {XLI, XLK, XLB, XLY}
# 2010-04-16                                    {XLI, XLK, XLY}
# 2010-04-23                               {XLI, XLK, XLE, XLY}
# 2010-04-30                          {XLE, XLI, XLK, XLY, XLF}
# 2010-05-07                                    {XLI, XLF, XLY}
# 2010-05-14                          {XLP, XLI, XLK, XLY, XLF}
# 2010-05-21                                         {XLI, XLY}
# 2010-05-28                                         {XLI, XLY}
# 2010-06-04                                              {XLY}
# 2010-06-11                                         {XLI, XLY}
# 2010-06-18                               {XLI, XLK, XLU, XLY}
# 2010-06-25                                                 {}
# 2010-07-02                                                 {}
# 2010-07-09                                              {XLU}
# 2010-07-16                                                 {}
# 2010-07-23                     {XLP, XLI, XLK, XLY, XLB, XLU}
# 2010-07-30                                    {XLI, XLB, XLP}
# 2010-08-06                     {XLP, XLI, XLK, XLY, XLB, XLU}
# 2010-08-13                                              {XLU}
# 2010-08-20                                              {XLU}
# 2010-08-27                                              {XLU}
# 2010-09-03                          {XLP, XLI, XLY, XLB, XLU}
# 2010-09-10                          {XLP, XLI, XLY, XLB, XLU}
# 2010-09-17                     {XLP, XLI, XLK, XLY, XLB, XLU}
# 2010-09-24                     {XLP, XLI, XLK, XLY, XLB, XLU}
# 2010-10-01                {XLE, XLP, XLI, XLK, XLY, XLB, XLU}
# 2010-10-08                {XLE, XLP, XLI, XLK, XLY, XLB, XLU}
# 2010-10-15           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2010-10-22                {XLE, XLP, XLI, XLK, XLY, XLB, XLU}
# 2010-10-29           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2010-11-05           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2010-11-12           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2010-11-19           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2010-11-26           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2010-12-03                {XLE, XLP, XLI, XLK, XLY, XLB, XLU}
# 2010-12-10                     {XLE, XLP, XLI, XLK, XLY, XLB}
# 2010-12-17                          {XLE, XLI, XLK, XLY, XLB}
# 2010-12-31                     {XLE, XLP, XLI, XLK, XLY, XLB}
# 2011-01-07                          {XLE, XLI, XLK, XLY, XLB}
# 2011-01-14                          {XLE, XLI, XLK, XLY, XLB}
# 2011-01-21                {XLE, XLP, XLI, XLK, XLY, XLF, XLB}
# 2011-01-28                          {XLE, XLI, XLK, XLY, XLB}
# 2011-02-04                          {XLE, XLI, XLK, XLY, XLB}
# 2011-02-11                          {XLE, XLI, XLK, XLY, XLB}
# 2011-02-18                          {XLE, XLI, XLK, XLY, XLB}
# 2011-02-25                          {XLE, XLI, XLK, XLY, XLB}
# 2011-03-04                          {XLE, XLI, XLK, XLY, XLB}
# 2011-03-11                     {XLE, XLI, XLK, XLY, XLF, XLB}
# 2011-03-18                     {XLE, XLI, XLK, XLY, XLF, XLB}
# 2011-03-25                          {XLE, XLI, XLK, XLY, XLB}
# 2011-04-01                          {XLE, XLI, XLK, XLY, XLB}
# 2011-04-08                          {XLE, XLI, XLK, XLY, XLB}
# 2011-04-15                          {XLE, XLI, XLK, XLY, XLB}
# 2011-04-29                     {XLE, XLI, XLK, XLV, XLY, XLB}
# 2011-05-06                {XLE, XLP, XLI, XLK, XLV, XLY, XLB}
# 2011-05-13                {XLE, XLP, XLI, XLK, XLV, XLY, XLB}
# 2011-05-20                {XLE, XLP, XLI, XLK, XLV, XLY, XLB}
# 2011-05-27                {XLE, XLP, XLI, XLK, XLV, XLY, XLB}
# 2011-06-03                     {XLE, XLP, XLI, XLV, XLY, XLU}
# 2011-06-10                               {XLU, XLE, XLV, XLP}
# 2011-06-17                                    {XLU, XLV, XLP}
# 2011-06-24                                    {XLU, XLV, XLP}
# 2011-07-01           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2011-07-08           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2011-07-15                {XLE, XLP, XLK, XLV, XLY, XLB, XLU}
# 2011-07-22           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2011-07-29                          {XLE, XLP, XLV, XLY, XLU}
# 2011-08-05                                                 {}
# 2011-08-12                                                 {}
# 2011-08-19                                                 {}
# 2011-08-26                                              {XLU}
# 2011-09-02                                              {XLU}
# 2011-09-09                                              {XLU}
# 2011-09-16                                         {XLU, XLP}
# 2011-09-23                                              {XLU}
# 2011-09-30                                              {XLU}
# 2011-10-07                                              {XLU}
# 2011-10-14                               {XLK, XLY, XLU, XLP}
# 2011-10-21                               {XLK, XLY, XLU, XLP}
# 2011-10-28                     {XLE, XLP, XLK, XLV, XLY, XLU}
# 2011-11-04                               {XLK, XLY, XLU, XLP}
# 2011-11-11                     {XLE, XLP, XLK, XLV, XLY, XLU}
# 2011-11-18                                         {XLU, XLP}
# 2011-11-25                                                 {}
# 2011-12-02                     {XLE, XLP, XLI, XLK, XLY, XLU}
# 2011-12-09                {XLE, XLP, XLI, XLK, XLV, XLY, XLU}
# 2011-12-16                                         {XLU, XLP}
# 2011-12-23                {XLE, XLP, XLI, XLK, XLV, XLY, XLU}
# 2011-12-30                {XLE, XLP, XLI, XLK, XLV, XLY, XLU}
# 2012-01-06                {XLE, XLP, XLI, XLK, XLV, XLY, XLU}
# 2012-01-13           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2012-01-20                {XLE, XLP, XLI, XLK, XLV, XLY, XLU}
# 2012-01-27           {XLE, XLP, XLI, XLK, XLV, XLY, XLB, XLU}
# 2012-02-03           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2012-02-10                {XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2012-02-17                {XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2012-02-24                     {XLP, XLI, XLK, XLV, XLY, XLU}
# 2012-03-02                     {XLP, XLI, XLK, XLV, XLY, XLF}
# 2012-03-09                     {XLP, XLI, XLK, XLV, XLY, XLF}
# 2012-03-16                               {XLI, XLF, XLK, XLY}
# 2012-03-23                               {XLI, XLF, XLK, XLY}
# 2012-03-30                               {XLI, XLF, XLK, XLY}
# 2012-04-13                               {XLI, XLF, XLK, XLY}
# 2012-04-20                     {XLP, XLI, XLK, XLV, XLY, XLF}
# 2012-04-27                {XLE, XLI, XLK, XLV, XLY, XLF, XLB}
# 2012-05-04                     {XLI, XLK, XLV, XLY, XLF, XLB}
# 2012-05-11                     {XLP, XLI, XLK, XLV, XLY, XLF}
# 2012-05-18                          {XLP, XLK, XLV, XLY, XLU}
# 2012-05-25                          {XLP, XLK, XLV, XLY, XLU}
# 2012-06-01                                         {XLU, XLP}
# 2012-06-08                          {XLP, XLK, XLV, XLY, XLU}
# 2012-06-15                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2012-06-22                          {XLP, XLK, XLV, XLY, XLF}
# 2012-06-29                          {XLP, XLK, XLV, XLY, XLF}
# 2012-07-06                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2012-07-13                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2012-07-20                          {XLP, XLK, XLV, XLY, XLU}
# 2012-07-27                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2012-08-03                     {XLP, XLI, XLK, XLV, XLY, XLF}
# 2012-08-10                {XLP, XLI, XLK, XLV, XLY, XLF, XLU}
# 2012-08-17                          {XLP, XLK, XLV, XLY, XLF}
# 2012-08-24                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2012-08-31                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2012-09-07                {XLE, XLP, XLK, XLV, XLY, XLF, XLU}
# 2012-09-14           {XLE, XLP, XLK, XLV, XLY, XLF, XLB, XLU}
# 2012-09-21                          {XLP, XLK, XLV, XLY, XLF}
# 2012-09-28                     {XLP, XLK, XLV, XLY, XLF, XLU}
# 2012-10-05      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2012-10-12      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2012-10-19           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2012-10-26           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2012-11-02                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2012-11-09                               {XLI, XLF, XLV, XLY}
# 2012-11-16                                    {XLF, XLV, XLY}
# 2012-11-23                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2012-11-30                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2012-12-07                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2012-12-14                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2012-12-21                     {XLE, XLI, XLV, XLY, XLF, XLB}
# 2012-12-28                          {XLI, XLV, XLY, XLF, XLB}
# 2013-01-04           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-01-11           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-01-18                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2013-01-25                {XLE, XLP, XLI, XLV, XLY, XLF, XLB}
# 2013-02-01           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-02-08           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-02-15           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-02-22           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-03-01           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-03-08      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2013-03-15           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2013-03-22      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2013-04-05      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2013-04-12           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2013-04-19           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2013-04-26           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2013-05-03           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2013-05-10           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2013-05-17           {XLE, XLP, XLI, XLV, XLY, XLF, XLB, XLU}
# 2013-05-24           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-05-31           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-06-07           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-06-14           {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB}
# 2013-06-21                     {XLE, XLP, XLI, XLV, XLY, XLF}
# 2013-06-28                {XLE, XLP, XLI, XLV, XLY, XLF, XLU}
# 2013-07-05                     {XLE, XLP, XLI, XLV, XLY, XLF}
# 2013-07-12                     {XLE, XLP, XLI, XLV, XLY, XLF}
# 2013-07-19                     {XLE, XLP, XLI, XLV, XLY, XLF}
# 2013-07-26                     {XLE, XLP, XLI, XLV, XLY, XLF}
# 2013-08-02                     {XLE, XLP, XLI, XLV, XLY, XLF}
# 2013-08-09                     {XLE, XLP, XLI, XLV, XLY, XLF}
# 2013-08-16                     {XLE, XLP, XLI, XLV, XLY, XLF}
# 2013-08-23                          {XLP, XLI, XLV, XLY, XLF}
# 2013-08-30                          {XLI, XLK, XLV, XLY, XLF}
# 2013-09-06                               {XLI, XLF, XLV, XLY}
# 2013-09-13                               {XLI, XLF, XLV, XLY}
# 2013-09-20                               {XLI, XLF, XLV, XLY}
# 2013-09-27                               {XLI, XLF, XLV, XLY}
# 2013-10-04                               {XLI, XLF, XLV, XLY}
# 2013-10-11                               {XLI, XLF, XLV, XLY}
# 2013-10-18                                    {XLI, XLV, XLY}
# 2013-10-25                               {XLI, XLF, XLV, XLY}
# 2013-11-01                                         {XLI, XLY}
# 2013-11-08                               {XLI, XLF, XLB, XLY}
# 2013-11-15                               {XLI, XLB, XLE, XLY}
# 2013-11-22                          {XLI, XLV, XLY, XLF, XLB}
# 2013-11-29                               {XLI, XLF, XLV, XLY}
# 2013-12-06                                    {XLI, XLV, XLY}
# 2013-12-13                                    {XLI, XLV, XLY}
# 2013-12-20                                    {XLI, XLV, XLY}
# 2013-12-27                               {XLI, XLB, XLV, XLY}
# 2014-01-03                               {XLI, XLB, XLV, XLY}
# 2014-01-10                                    {XLI, XLV, XLY}
# 2014-01-17                               {XLI, XLB, XLV, XLY}
# 2014-01-24                               {XLI, XLK, XLB, XLV}
# 2014-01-31                               {XLI, XLK, XLB, XLV}
# 2014-02-07                               {XLI, XLK, XLB, XLV}
# 2014-02-14                               {XLI, XLK, XLB, XLV}
# 2014-02-21                               {XLI, XLK, XLB, XLV}
# 2014-02-28                          {XLI, XLK, XLV, XLY, XLB}
# 2014-03-07                          {XLI, XLK, XLV, XLY, XLB}
# 2014-03-14                          {XLI, XLK, XLV, XLY, XLB}
# 2014-03-21                     {XLI, XLK, XLV, XLY, XLF, XLB}
# 2014-03-28           {XLE, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2014-04-04      {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2014-04-11                {XLE, XLP, XLI, XLK, XLV, XLB, XLU}
# 2014-04-25           {XLE, XLP, XLI, XLK, XLV, XLF, XLB, XLU}
# ...
# 2017-03-03                     {XLE, XLI, XLK, XLY, XLF, XLB}
# 2017-03-10                          {XLI, XLK, XLY, XLF, XLB}
# 2017-03-17                          {XLI, XLK, XLY, XLF, XLB}
# 2017-03-24                     {XLI, XLK, XLY, XLF, XLB, XLU}
# 2017-03-31                          {XLI, XLK, XLY, XLF, XLB}
# 2017-04-07                          {XLI, XLK, XLY, XLF, XLB}
# 2017-04-21                          {XLI, XLK, XLY, XLF, XLB}
# 2017-04-28                          {XLI, XLK, XLY, XLF, XLB}
# 2017-05-05                          {XLI, XLK, XLY, XLF, XLB}
# 2017-05-12                     {XLI, XLK, XLY, XLF, XLB, XLU}
# 2017-05-19                          {XLI, XLK, XLY, XLF, XLB}
# 2017-05-26                     {XLI, XLK, XLY, XLF, XLB, XLU}
# 2017-06-02                          {XLI, XLK, XLY, XLF, XLB}
# 2017-06-09                     {XLI, XLK, XLV, XLY, XLF, XLB}
# 2017-06-16                {XLP, XLI, XLK, XLY, XLF, XLB, XLU}
# 2017-06-23                          {XLI, XLK, XLV, XLB, XLU}
# 2017-06-30     {XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, XLRE}
# 2017-07-07                               {XLK, XLU, XLV, XLF}
# 2017-07-14                                         {XLK, XLV}
# 2017-07-21                                         {XLK, XLV}
# 2017-07-28                                    {XLK, XLV, XLY}
# 2017-08-04                                    {XLK, XLV, XLY}
# 2017-08-11                          {XLI, XLK, XLV, XLY, XLU}
# 2017-08-18          {XLP, XLI, XLK, XLV, XLF, XLB, XLU, XLRE}
# 2017-08-25               {XLI, XLK, XLV, XLF, XLB, XLU, XLRE}
# 2017-09-01                              {XLK, XLU, XLV, XLRE}
# 2017-09-08               {XLI, XLK, XLV, XLY, XLB, XLU, XLRE}
# 2017-09-15                    {XLI, XLK, XLV, XLB, XLU, XLRE}
# 2017-09-22                {XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2017-09-29                          {XLI, XLK, XLV, XLF, XLB}
# 2017-10-06                     {XLI, XLK, XLV, XLY, XLF, XLB}
# 2017-10-13                    {XLI, XLK, XLV, XLB, XLU, XLRE}
# 2017-10-20                     {XLI, XLK, XLV, XLF, XLB, XLU}
# 2017-10-27                          {XLI, XLK, XLV, XLF, XLB}
# 2017-11-03                     {XLI, XLK, XLV, XLF, XLB, XLU}
# 2017-11-10                     {XLI, XLK, XLV, XLF, XLB, XLU}
# 2017-11-17                     {XLI, XLK, XLV, XLF, XLB, XLU}
# 2017-11-24                     {XLI, XLK, XLV, XLF, XLB, XLU}
# 2017-12-01          {XLI, XLK, XLV, XLY, XLF, XLB, XLU, XLRE}
# 2017-12-08          {XLI, XLK, XLV, XLY, XLF, XLB, XLU, XLRE}
# 2017-12-15                     {XLI, XLK, XLV, XLY, XLF, XLB}
# 2017-12-22                {XLE, XLI, XLK, XLV, XLY, XLF, XLB}
# 2017-12-29                {XLE, XLI, XLK, XLV, XLY, XLF, XLB}
# 2018-01-05                {XLE, XLI, XLK, XLV, XLY, XLF, XLB}
# 2018-01-12                {XLE, XLI, XLK, XLV, XLY, XLF, XLB}
# 2018-01-19                     {XLE, XLI, XLK, XLY, XLF, XLB}
# 2018-01-26                {XLE, XLI, XLK, XLV, XLY, XLF, XLB}
# 2018-02-02                     {XLE, XLI, XLK, XLY, XLF, XLB}
# 2018-02-09                          {XLI, XLK, XLY, XLF, XLB}
# 2018-02-16                          {XLI, XLK, XLY, XLF, XLB}
# 2018-02-23                          {XLI, XLK, XLY, XLF, XLB}
# 2018-03-02                          {XLI, XLK, XLY, XLF, XLB}
# 2018-03-09                          {XLI, XLK, XLY, XLF, XLB}
# 2018-03-16                               {XLI, XLF, XLK, XLY}
# 2018-03-23                                         {XLK, XLY}
# 2018-04-06                                              {XLY}
# 2018-04-13                                    {XLK, XLE, XLY}
# 2018-04-20                          {XLE, XLI, XLK, XLY, XLF}
# 2018-04-27                                    {XLK, XLE, XLY}
# 2018-05-04                                    {XLK, XLE, XLY}
# 2018-05-11                               {XLF, XLK, XLE, XLY}
# 2018-05-18                          {XLE, XLI, XLK, XLY, XLF}
# 2018-05-25                                    {XLK, XLE, XLY}
# 2018-06-01                                    {XLK, XLE, XLY}
# 2018-06-08                               {XLI, XLK, XLE, XLY}
# 2018-06-15                                         {XLK, XLY}
# 2018-06-22                                    {XLK, XLE, XLY}
# 2018-06-29                                    {XLK, XLE, XLY}
# 2018-07-06                                    {XLK, XLE, XLY}
# 2018-07-13                                    {XLK, XLE, XLY}
# 2018-07-20                                    {XLK, XLE, XLY}
# 2018-07-27                               {XLK, XLE, XLV, XLY}
# 2018-08-03                                    {XLK, XLV, XLY}
# 2018-08-10                               {XLK, XLU, XLV, XLY}
# 2018-08-17                         {XLK, XLV, XLY, XLU, XLRE}
# 2018-08-24                         {XLK, XLV, XLY, XLU, XLRE}
# 2018-08-31                         {XLK, XLV, XLY, XLU, XLRE}
# 2018-09-07                         {XLK, XLV, XLY, XLU, XLRE}
# 2018-09-14                    {XLE, XLK, XLV, XLY, XLU, XLRE}
# 2018-09-21               {XLE, XLI, XLK, XLV, XLY, XLU, XLRE}
# 2018-09-28                    {XLE, XLK, XLV, XLY, XLU, XLRE}
# 2018-10-05                     {XLE, XLI, XLK, XLV, XLY, XLU}
# 2018-10-12                                    {XLU, XLV, XLP}
# 2018-10-19                                    {XLU, XLV, XLP}
# 2018-10-26                                         {XLU, XLP}
# 2018-11-02                                    {XLU, XLV, XLP}
# 2018-11-09                              {XLU, XLV, XLRE, XLP}
# 2018-11-16                              {XLU, XLV, XLRE, XLP}
# 2018-11-23                              {XLU, XLV, XLRE, XLP}
# 2018-11-30                              {XLU, XLV, XLRE, XLP}
# 2018-12-07                              {XLU, XLV, XLRE, XLP}
# 2018-12-14                                   {XLU, XLRE, XLP}
# 2018-12-21                                              {XLU}
# 2018-12-28                                                 {}
# 2019-01-04                                                 {}
# 2019-01-11                                                 {}
# 2019-01-18                                              {XLV}
# 2019-01-25                                             {XLRE}
# 2019-02-01                                   {XLU, XLV, XLRE}
# 2019-02-08                              {XLI, XLU, XLRE, XLP}
# 2019-02-15          {XLC, XLP, XLI, XLK, XLV, XLY, XLU, XLRE}
# 2019-02-22     {XLC, XLP, XLI, XLK, XLV, XLY, XLB, XLU, XLRE}
# 2019-03-01  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-03-08               {XLC, XLI, XLK, XLY, XLB, XLU, XLRE}
# 2019-03-15  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-03-22               {XLC, XLP, XLI, XLK, XLY, XLU, XLRE}
# 2019-03-29     {XLC, XLP, XLI, XLK, XLV, XLY, XLB, XLU, XLRE}
# 2019-04-05  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-04-12     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-04-26          {XLC, XLP, XLI, XLK, XLY, XLF, XLU, XLRE}
# 2019-05-03     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-05-10     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-05-17     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-05-24          {XLC, XLP, XLI, XLK, XLY, XLF, XLU, XLRE}
# 2019-05-31                    {XLC, XLP, XLK, XLY, XLU, XLRE}
# 2019-06-07  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-06-14     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-06-21          {XLC, XLP, XLI, XLK, XLY, XLB, XLU, XLRE}
# 2019-06-28               {XLC, XLI, XLK, XLY, XLB, XLU, XLRE}
# 2019-07-05     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-07-12                     {XLC, XLI, XLK, XLY, XLF, XLB}
# 2019-07-19                     {XLC, XLI, XLK, XLY, XLF, XLB}
# 2019-07-26                          {XLC, XLI, XLK, XLY, XLF}
# 2019-08-02               {XLC, XLP, XLI, XLK, XLY, XLF, XLRE}
# 2019-08-09     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-08-16               {XLC, XLP, XLK, XLY, XLB, XLU, XLRE}
# 2019-08-23                         {XLP, XLK, XLY, XLU, XLRE}
# 2019-08-30          {XLC, XLP, XLI, XLK, XLY, XLB, XLU, XLRE}
# 2019-09-06     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-09-13     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-09-20     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-09-27     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-10-04               {XLC, XLP, XLK, XLY, XLF, XLU, XLRE}
# 2019-10-11     {XLC, XLP, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2019-10-18  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-10-25  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-11-01  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-11-08      {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2019-11-15  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-11-22  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-11-29  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-12-06  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2019-12-13      {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU}
# 2019-12-20                {XLC, XLI, XLK, XLV, XLY, XLF, XLB}
# 2019-12-27                          {XLC, XLK, XLV, XLF, XLB}
# 2020-01-03                               {XLK, XLV, XLC, XLF}
# 2020-01-10                               {XLK, XLV, XLC, XLF}
# 2020-01-17                               {XLK, XLV, XLC, XLF}
# 2020-01-24                     {XLC, XLP, XLK, XLV, XLF, XLU}
# 2020-01-31                     {XLC, XLP, XLK, XLV, XLF, XLU}
# 2020-02-07                          {XLC, XLK, XLV, XLF, XLU}
# 2020-02-14                         {XLC, XLK, XLV, XLU, XLRE}
# 2020-02-21                         {XLC, XLK, XLV, XLU, XLRE}
# 2020-02-28                                              {XLK}
# 2020-03-06                                    {XLK, XLU, XLV}
# 2020-03-13                                                 {}
# 2020-03-20                                                 {}
# 2020-03-27                                                 {}
# 2020-04-03                                                 {}
# 2020-04-17                                         {XLK, XLV}
# 2020-04-24                                         {XLK, XLV}
# 2020-05-01                                         {XLK, XLV}
# 2020-05-08                                         {XLK, XLV}
# 2020-05-15                                         {XLK, XLV}
# 2020-05-22                                         {XLK, XLV}
# 2020-05-29                                         {XLK, XLV}
# 2020-06-05                                              {XLK}
# 2020-06-12                                              {XLK}
# 2020-06-19                                              {XLK}
# 2020-06-26                                              {XLK}
# 2020-07-10                                              {XLK}
# 2020-07-17                                              {XLK}
# 2020-07-24                                              {XLK}
# 2020-07-31                                              {XLK}
# 2020-08-07                                              {XLK}
# 2020-08-14                                              {XLK}
# 2020-08-21                                              {XLK}
# 2020-08-28                                         {XLK, XLY}
# 2020-09-04                                         {XLK, XLY}
# 2020-09-11                                    {XLK, XLB, XLY}
# 2020-09-18                                    {XLK, XLB, XLY}
# 2020-09-25                                         {XLK, XLY}
# 2020-10-02                                         {XLK, XLY}
# 2020-10-09                                         {XLK, XLY}
# 2020-10-16                                         {XLK, XLY}
# 2020-10-23                                    {XLK, XLB, XLY}
# 2020-10-30                                    {XLK, XLB, XLY}
# 2020-11-06                                    {XLK, XLB, XLY}
# 2020-11-13                                    {XLK, XLB, XLY}
# 2020-11-20                          {XLC, XLI, XLK, XLY, XLB}
# 2020-11-27                          {XLC, XLI, XLK, XLY, XLB}
# 2020-12-04                               {XLI, XLK, XLB, XLY}
# 2020-12-11                          {XLC, XLI, XLK, XLY, XLB}
# 2020-12-18                          {XLI, XLK, XLY, XLF, XLB}
# 2021-01-08                          {XLI, XLK, XLY, XLF, XLB}
# 2021-01-15                          {XLI, XLK, XLY, XLF, XLB}
# 2021-01-22                                              {XLK}
# 2021-01-29                                         {XLK, XLY}
# 2021-02-05                                         {XLK, XLY}
# 2021-02-12                                    {XLF, XLC, XLY}
# 2021-02-19                {XLE, XLC, XLI, XLK, XLY, XLF, XLB}
# 2021-02-26                {XLE, XLC, XLI, XLK, XLY, XLF, XLB}
# 2021-03-05                     {XLE, XLC, XLI, XLK, XLF, XLB}
# 2021-03-12                {XLE, XLC, XLI, XLK, XLY, XLF, XLB}
# 2021-03-19                {XLE, XLC, XLI, XLK, XLY, XLF, XLB}
# 2021-03-26                {XLE, XLC, XLI, XLK, XLY, XLF, XLB}
# 2021-04-09                {XLE, XLC, XLI, XLK, XLY, XLF, XLB}
# 2021-04-16     {XLE, XLC, XLI, XLK, XLY, XLF, XLB, XLU, XLRE}
# 2021-04-23           {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB}
# 2021-04-30                {XLE, XLC, XLI, XLK, XLY, XLF, XLB}
# 2021-05-07                {XLE, XLC, XLI, XLK, XLY, XLF, XLB}
# 2021-05-14     {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-05-21          {XLE, XLC, XLI, XLK, XLV, XLF, XLB, XLRE}
# 2021-05-28     {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-06-04     {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-06-11          {XLE, XLC, XLI, XLK, XLV, XLF, XLB, XLRE}
# 2021-06-18          {XLE, XLC, XLI, XLK, XLV, XLF, XLB, XLRE}
# 2021-06-25     {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-07-02          {XLE, XLC, XLI, XLK, XLY, XLF, XLB, XLRE}
# 2021-07-09     {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-07-16     {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-07-23          {XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-07-30     {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-08-06     {XLE, XLC, XLI, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-08-13  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2021-08-20  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2021-08-27  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2021-09-03  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2021-09-10  {XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2021-09-17          {XLC, XLP, XLK, XLV, XLY, XLF, XLU, XLRE}
# 2021-09-24          {XLE, XLC, XLP, XLK, XLV, XLY, XLF, XLRE}
# 2021-10-01               {XLE, XLC, XLK, XLV, XLY, XLF, XLRE}
# 2021-10-08               {XLE, XLC, XLK, XLV, XLY, XLF, XLRE}
# 2021-10-15  {XLE, XLC, XLP, XLI, XLK, XLV, XLY, XLF, XLB, ...
# 2021-10-22  {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2021-10-29                    {XLE, XLK, XLV, XLY, XLF, XLRE}
# 2021-11-05               {XLE, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-11-12               {XLE, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-11-19                    {XLE, XLK, XLV, XLY, XLF, XLRE}
# 2021-11-26               {XLE, XLK, XLV, XLY, XLF, XLB, XLRE}
# 2021-12-03                         {XLE, XLK, XLV, XLY, XLRE}
# 2021-12-10                                   {XLK, XLRE, XLY}
# 2021-12-17                    {XLP, XLK, XLV, XLY, XLU, XLRE}
# 2021-12-31                    {XLP, XLK, XLV, XLY, XLU, XLRE}
# 2022-01-07  {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2022-01-14  {XLE, XLP, XLI, XLK, XLV, XLY, XLF, XLB, XLU, ...
# 2022-01-21                                    {XLU, XLE, XLP}
# 2022-01-28                               {XLF, XLU, XLE, XLP}
# 2022-02-04                               {XLF, XLU, XLE, XLP}
# 2022-02-11                                    {XLF, XLE, XLP}
# 2022-02-18                                    {XLF, XLE, XLP}
# 2022-02-25                                    {XLF, XLE, XLP}
# 2022-03-04                                    {XLU, XLE, XLP}
# 2022-03-11                                         {XLU, XLE}
# 2022-03-18                {XLE, XLP, XLI, XLV, XLF, XLB, XLU}
# 2022-03-25                {XLE, XLP, XLI, XLV, XLF, XLB, XLU}
# 2022-04-01                    {XLE, XLP, XLV, XLB, XLU, XLRE}
# 2022-04-08                    {XLE, XLP, XLV, XLB, XLU, XLRE}

# %%
# removeList = []
# nasdaqList = pd.read_pickle("stockData/tickerList.pkl")
# for stock in nasdaqList:
#     try:
#         df = getStage(stock, coef,goodSectorDf)
#         if df.empty:
#             removeList.append(stock)
#     except:
#         removeList.append(stock)

# %%
# import pickle
# for removeItem in removeList:
#     nasdaqList.remove(removeItem)
# listOfTickerObject = open('stockData/tickerListpkl', 'wb')
# pickle.dump(nasdaqList, listOfTickerObject)
# listOfTickerObject.close()

# %%
# Open a file
nasdaqList = pd.read_pickle("stockData/tickerList.pkl")
result = open("Testdata/Realtime/result"+date.today().strftime('%Y-%m-%d')+".txt", "w")
buyList = []
holdList = []
sellList = []
portfolio = []
for symbol in nasdaqList:
    df = getStage(symbol,coef,goodSectorDf)
    shares = 0
    sharesSPY = 0
    if df.empty:
        continue
    if df.iloc[-1].Stage=="Buy":
        print(symbol," buy ",df.iloc[-1].support * coef[7])
        result.write(symbol+" buy " + str(df.iloc[-1].support * coef[7]) + "\n")
        buyList.append(symbol)
        portfolio.append(tuple((symbol, df.iloc[-1].close)))
    elif df.iloc[-1].Stage=="Stage 2":
        print(symbol," hold ",df.iloc[-1].support * coef[7])
        result.write(symbol+" hold " + str(df.iloc[-1].support * coef[7]) + "\n")
        holdList.append(holdList)
        portfolio.append(tuple((symbol, df.iloc[-1].close)))
    elif df.iloc[-1].Stage[0:4]=="Sell":
        print(symbol+" sell")
        result.write(symbol+" sell\n")
        sellList.append(sellList)
result.close()

# %%
##CURRENT BALANCE
balance = 100
allocation = balance / len(portfolio)
for ticker, close in portfolio:
    print(ticker, allocation / close, close)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/1q/w3g5nkks29g3kjdwmq1lssj00000gn/T/ipykernel_2619/3272274215.py in <module>
#       1 ##CURRENT BALANCE
#       2 balance = 100
# ----> 3 allocation = balance / len(portfolio)
#       4 for ticker, close in portfolio:
#       5     print(ticker, allocation / close, close)
#
# ZeroDivisionError: division by zero

# %%
print(buyList)
# Out:
# []

# %%
getStage("SAMG", coef, goodSectorDf)
# Out:
#                 close                                           Stage  \
# 2013-06-28  12.000000
# 2013-07-05  11.590000   volume -0.4776714513556619 1.1421709856192384
# 2013-07-12  12.650000   volume -0.6259541984732824 1.1421709856192384
# 2013-07-19  12.260000      RS -1.1878897336408405 0.27350824408318475
# 2013-07-26  14.060000  volume -0.13807982740021574 1.1421709856192384
# ...               ...                                             ...
# 2022-03-04  16.850000             bad sector XLF{'XLU', 'XLP', 'XLE'}
# 2022-03-11  17.990000                    bad sector XLF{'XLU', 'XLE'}
# 2022-03-18  19.700001                                         bearish
# 2022-03-25  21.910000                                             Buy
# 2022-04-01  20.219999      Sell 19.700000762939453 1.0764846753295985
#
#               support
# 2013-06-28   0.000000
# 2013-07-05   0.000000
# 2013-07-12   0.000000
# 2013-07-19   0.000000
# 2013-07-26   0.000000
# ...               ...
# 2022-03-04   0.000000
# 2022-03-11   0.000000
# 2022-03-18   0.000000
# 2022-03-25  19.700001
# 2022-04-01   0.000000
#
# [442 rows x 3 columns]
